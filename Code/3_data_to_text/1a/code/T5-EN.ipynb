# %% [markdown]
# #**Step 1: Installazione, caricamento delle librerie e definizione delle variabili**

# %%
# !pip install transformers
# !pip install sentencepiece
# !pip install accelerate -U

#!pip install evaluate
#!pip install bert_score
#!pip install torchmetrics
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.40.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.14.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.2.2)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (0.1.99)
# Collecting accelerate
#   Downloading accelerate-0.30.1-py3-none-any.whl (302 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.6/302.6 kB 4.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (24.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.2.1+cu121)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.20.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.4.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.14.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (4.11.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.19.3 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2.2.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.10.0->accelerate)
#   Using cached nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (4.66.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, accelerate
# Successfully installed accelerate-0.30.1 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.1.105

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from torch.utils.data import Dataset
from transformers import T5ForConditionalGeneration, T5Tokenizer, T5Config, DataCollatorForSeq2Seq, Seq2SeqTrainingArguments, Seq2SeqTrainer
#from evaluate import load
#from torchmetrics.text import TranslationEditRate

# %%
percentuale_dataset = 1
dataset_type = ""
model_name = "t5-large"

# %% [markdown]
# #**Step 2: Collegamento a drive**

# %%
from google.colab import drive
drive.mount('/content/drive')

# change this to match your path
data_path_models = "./drive/MyDrive/Colab Notebooks/WebNLG-IT/Esperimento 1a/Models"
data_path_data = "./drive/MyDrive/Colab Notebooks/WebNLG-IT/Esperimento 1a/Datasets"
# Out:
# Mounted at /content/drive

# %% [markdown]
# #**Step 3: Importazione dei dataset**

# %%
class CustomDataset(Dataset):
    def __init__(self, X, y, tokenizer):
        self.X = X
        self.y = y
        self.tokenizer = tokenizer

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        input_text = self.X[idx]
        target_text = self.y[idx]

        input_encoding = self.tokenizer(input_text, padding='max_length', truncation=True, max_length=128, return_tensors='pt')
        target_encoding = self.tokenizer(target_text, padding='max_length', truncation=True, max_length=128, return_tensors='pt')

        return {
            'input_ids': input_encoding['input_ids'].squeeze(),
            'attention_mask': input_encoding['attention_mask'].squeeze(),
            'labels': target_encoding['input_ids'].squeeze()
        }

# carico il dataset
trainset = pd.read_csv(f'{data_path_data}/WebNLG-EN/train.csv')
devset = pd.read_csv(f'{data_path_data}/WebNLG-EN/dev.csv')

# %%
# ottengo un sottoinsieme del dataset di partenza
subset_trainset = trainset.sample(frac=percentuale_dataset, random_state=42)
subset_devset = devset.sample(frac=percentuale_dataset, random_state=42)

# train
X_train = subset_trainset['triple'].values.tolist()
y_train = subset_trainset['sentence'].values.tolist()

# dev
X_val = subset_devset['triple'].values.tolist()
y_val = subset_devset['sentence'].values.tolist()

# %%
subset_trainset.head()
# Out:
#                                                   triple  \
# 5038                 A-Rosa_Luna shipOrdered 2004-01-22
# 5864          Aaron_S._Daggett birthPlace Greene,_Maine
# 30896  Houston_Texans city Texas Houston_Texans city ...
# 14789  Al_Asad_Airbase location "Al Anbar Province, I...
# 8014   Antwerp_International_Airport cityServed Antwe...
#
#                                                 sentence
# 5038   The A-Rosa Luna ship was ordered on January 22...
# 5864   The birth place of Aaron S. Daggett is Greene,...
# 30896  Akeem Dent, who debuted with the Atlanta Falco...
# 14789  The Al Asad Airbase is situated in the Al Anba...
# 8014   Bart De Wever is the mayor of Antwerp, which i...

# %%
len(X_train)
# Out:
# 35426

# %% [markdown]
# #**Step 4: Caricamento del modello**

# %%
# Load the T5 model, tokenizer, and configuration
model = T5ForConditionalGeneration.from_pretrained(model_name)
tokenizer = T5Tokenizer.from_pretrained(model_name)
config = T5Config.from_pretrained(model_name)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.95G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
# Create the custom datasets
train_dataset = CustomDataset(X_train, y_train, tokenizer)
val_dataset = CustomDataset(X_val, y_val, tokenizer)

# %%
# Set up the data collator, training arguments, and trainer
data_collator = DataCollatorForSeq2Seq(
    tokenizer=tokenizer,
    model=model,
    label_pad_token_id=tokenizer.pad_token_id
)

training_args = Seq2SeqTrainingArguments(
    output_dir="./results",
    #per_device_train_batch_size=2,
    #per_device_eval_batch_size=2,
    num_train_epochs=2,
    logging_dir="./logs",
    evaluation_strategy="steps",  # Calcolo della validation loss ad ogni epoca
    save_strategy="steps",  # Checkpoint del modello ad ogni epoca
    save_total_limit=3,  # Limita il numero di checkpoint salvati
    load_best_model_at_end=True,  # Carica il modello migliore al termine dell'addestramento
    metric_for_best_model="eval_loss",  # Sceglie la metrica per determinare il miglior modello
    greater_is_better=False,  # Indica se un valore più alto della metrica è migliore o no
    logging_steps=500,
    eval_steps=500,  # Numero di passaggi prima di valutare il modello
    # Aggiungi eventuali altri argomenti di training qui
)

# %%
trainer = Seq2SeqTrainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
    data_collator=data_collator,
    tokenizer=tokenizer,
)

# Fine-tune the model
trainer.train()
# Out:
#     <div>
#
#       <progress value='8858' max='8858' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [8858/8858 1:55:40, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.802500</td>
#       <td>0.185287</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.198400</td>
#       <td>0.167501</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.184400</td>
#       <td>0.158001</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.179700</td>
#       <td>0.153904</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.169500</td>
#       <td>0.149495</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.162100</td>
#       <td>0.145926</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.162300</td>
#       <td>0.142910</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.156000</td>
#       <td>0.140978</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.156100</td>
#       <td>0.140052</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.141600</td>
#       <td>0.138825</td>
#     </tr>
#     <tr>
#       <td>5500</td>
#       <td>0.142600</td>
#       <td>0.137229</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>0.140900</td>
#       <td>0.136149</td>
#     </tr>
#     <tr>
#       <td>6500</td>
#       <td>0.145200</td>
#       <td>0.135296</td>
#     </tr>
#     <tr>
#       <td>7000</td>
#       <td>0.141700</td>
#       <td>0.134423</td>
#     </tr>
#     <tr>
#       <td>7500</td>
#       <td>0.141300</td>
#       <td>0.133612</td>
#     </tr>
#     <tr>
#       <td>8000</td>
#       <td>0.141300</td>
#       <td>0.133147</td>
#     </tr>
#     <tr>
#       <td>8500</td>
#       <td>0.142100</td>
#       <td>0.132692</td>
#     </tr>
#   </tbody>
# </table><p>
# There were missing keys in the checkpoint model loaded: ['encoder.embed_tokens.weight', 'decoder.embed_tokens.weight', 'lm_head.weight'].
# TrainOutput(global_step=8858, training_loss=0.19235299343609547, metrics={'train_runtime': 6942.4606, 'train_samples_per_second': 10.206, 'train_steps_per_second': 1.276, 'total_flos': 3.8349482754048e+16, 'train_loss': 0.19235299343609547, 'epoch': 2.0})

# %%
# salvataggio del modello
model.save_pretrained(f'{data_path_models}/{model_name}_en_2epoch')
tokenizer.save_pretrained(f'{data_path_models}/{model_name}_en_2epoch')
# Out:
# ('./drive/MyDrive/Colab Notebooks/WebNLG-IT/Esperimento 1a/Models/t5-large_en_2epoch/tokenizer_config.json',
#  './drive/MyDrive/Colab Notebooks/WebNLG-IT/Esperimento 1a/Models/t5-large_en_2epoch/special_tokens_map.json',
#  './drive/MyDrive/Colab Notebooks/WebNLG-IT/Esperimento 1a/Models/t5-large_en_2epoch/spiece.model',
#  './drive/MyDrive/Colab Notebooks/WebNLG-IT/Esperimento 1a/Models/t5-large_en_2epoch/added_tokens.json')

# %% [markdown]
# #**Step 5: generazione frasi del modello creato**

# %%
model1 = T5ForConditionalGeneration.from_pretrained(f'{data_path_models}/{model_name}_en_2epoch')
tokenizer1 = T5Tokenizer.from_pretrained(f'{data_path_models}/{model_name}_en_2epoch')
print(f'{data_path_models}/{model_name}_en_2epoch')
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# ./drive/MyDrive/Colab Notebooks/WebNLG-IT/Esperimento 1a/Models/t5-large_en_2epoch

# %%
def generate_text(input_rdf, max_length=128):
  input_text = f"{input_rdf}"
  input_ids = tokenizer1.encode(input_text, return_tensors="pt")

  # Imposta il parametro max_length per controllare la lunghezza dell'output generato
  output_ids = model1.generate(input_ids, max_length=max_length)

  output_text = tokenizer1.decode(output_ids[0], skip_special_tokens=True)
  return output_text

# %%
testset = pd.read_csv(f'{data_path_data}/WebNLG-EN/test.csv')

# ottengo un sottoinsieme del testset di partenza
subset_testset = testset.sample(frac=percentuale_dataset, random_state=42)

# test
X_test = subset_testset['triple'].values.tolist()
y_test = subset_testset['sentence'].values.tolist()

len(X_test)
# Out:
# 7305

# %%
subset_testset.head()
# Out:
#                                                  triple  \
# 7061  11th_Mississippi_Infantry_Monument category Co...
# 4553  Bananaman broadcastedBy BBC BBC city Broadcast...
# 6504                  Karlsruhe postalCode 76131–76229
# 1918                Turkish_people religion Irreligion
# 5227  ENAIRE city Madrid Adolfo_Suárez_Madrid–Baraja...
#
#                                                sentence
# 7061  A monument to the 11th Mississippi Infantry, w...
# 4553  Bill Oddie stars in a BBC programme called Ban...
# 6504     The postal codes of Karlsruhe are 76131–76229.
# 1918               Some Turkish people are irreligious.
# 5227  The Adolfo Suarez Madrid-Barajas airport is op...

# %%
triple = []
predicted = []
actuals = []

i = 0
for tripla in X_test:
  if i < 1010:
    triple.append(tripla)
    prediction = generate_text(tripla, len(y_test[i]) * 1.2)
    predicted.append(prediction)
    actuals.append(y_test[i])

    print(f'{i}/{len(X_test)-1}')
    print('tripla: ', tripla)
    print('actual: ', y_test[i])
    print('predicted: ', prediction)
    print('\n')

    df = pd.DataFrame(list(zip(triple, predicted, actuals)), columns =['triple', 'predicted', 'actuals'])
    df.to_csv(f'{data_path_models}/{model_name}_en_2epoch_decoding.csv', index=False)

  i += 1
# Out:
# Output streaming troncato alle ultime 5000 righe.
#
#
# 177/7304
# tripla:  Bootleg_Series_Volume_1:_The_Quine_Tapes precededBy Squeeze_(The_Velvet_Underground_album) Bootleg_Series_Volume_1:_The_Quine_Tapes recordLabel Polydor_Records Bootleg_Series_Volume_1:_The_Quine_Tapes recordLabel Universal_Music_Group Bootleg_Series_Volume_1:_The_Quine_Tapes recordedIn United_States Bootleg_Series_Volume_1:_The_Quine_Tapes recordedIn St._Louis,_Missouri Bootleg_Series_Volume_1:_The_Quine_Tapes releaseDate 2001-10-16 Bootleg_Series_Volume_1:_The_Quine_Tapes runtime 230.05
# actual:  After releasing their album Squeeze, music group the Velvet Underground produced and released rock music album Bootleg Series Volume 1: The Quine Tapes, which they recorded in St Louis Missouri, USA The album was released on 2001-10-16 under the Polydor and Universal Music Group record labels and has a total run time of 230:05 minutes.
# predicted:  The Bootleg Series Volume 1: The Quinine Tapes was recorded in St. Louis, Missouri, United States and was released on 16th October 2001. It was preceded by Squeeze and was recorded by the Universal Music Group. The album has a runtime of 230.05 minutes.
#
#
# 178/7304
# tripla:  Lady_Anne_Monson birthDate 1726-01-01 Lady_Anne_Monson birthPlace Darlington
# actual:  Lady Anne Monson was born in Darlington on January 1st,1726.
# predicted:  Lady Anne Monson was born in Darlington on January 1, 1726.
#
#
# 179/7304
# tripla:  Aaron_Turner genre Black_metal Aaron_Turner instrument Electric_guitar
# actual:  Aaron Turner the Black metal musician plays electric guitar.
# predicted:  Aaron Turner plays the electric guitar and performs black metal music.
#
#
# 180/7304
# tripla:  India populationTotal 1293057000
# actual:  The total population of India is 1,293,057,000.
# predicted:  The total population of India is 1293057000.
#
#
# 181/7304
# tripla:  Turn_Me_On_(album) genre Noise_rock Noise_rock musicFusionGenre Noise_pop
# actual:  The album Turn Me On is an example of the genre known as noise rock, a fusion genre having elements of noise pop among other things.
# predicted:  Turn Me On is a noise rock album. Noise pop is a fusion genre of noise rock.
#
#
# 182/7304
# tripla:  Anatole_de_Grunwald birthPlace Saint_Petersburg English_Without_Tears writer Anatole_de_Grunwald
# actual:  English Without Tears is written by Anatole de Grunwald, who was born in Saint Petersburg.
# predicted:  The writer of English Without Tears, Anatole de Grunwald, was born in Saint Petersburg.
#
#
# 183/7304
# tripla:  Detroit areaTotal 370.03 Pontiac_Rageous assembly Detroit
# actual:  The Pontiac Rageous was assembled in Detroit, which has a total area of 370.03 square kilometers.
# predicted:  The Pontiac Rageous was assembled in Detroit, which has a total area of 370.03.
#
#
# 184/7304
# tripla:  Death_on_a_Factory_Farm broadcastedBy HBO Death_on_a_Factory_Farm director Tom_Simon Death_on_a_Factory_Farm editor Geof_Bartz Death_on_a_Factory_Farm musicComposer Jamie_Lawrence Death_on_a_Factory_Farm producer Tom_Simon Death_on_a_Factory_Farm runtime 83.0
# actual:  Tom Simon directed and produced the 83 minute movie Death on a Factory Farm which was released by HBO. Jamie Lawrence wrote the music for the movie which Geof Bartz edited.
# predicted:  The HBO series Death on a Factory Farm, which was created by Jamie Lawrence and Tom Simon, was broadcasted on HBO. It was edited by Geof Bartz and has a runtime of 83.0.
#
#
# 185/7304
# tripla:  Justin_Whalin birthPlace San_Francisco
# actual:  Justin Whalin was born in San Francisco.
# predicted:  Justin Whale was born in San Francisco.
#
#
# 186/7304
# tripla:  Bill_Oddie birthPlace Rochdale Bananaman broadcastedBy BBC BBC city Broadcasting_House Bananaman creator Steve_Bright Bananaman starring Bill_Oddie
# actual:  Bananaman, a film starring Rochdale native Bill Oddie, is created by Steve Bright. The show was filmed at the BBC, located in the Broadcasting House in London.
# predicted:  Bill Oddie was born in Rochdale and starred in Bananaman which was broadcast by the BBC which is based at Broadcasting House. Bananaman was created by Steve Bright and was broadcast by the BBC.
#
#
# 187/7304
# tripla:  Lionsgate keyPerson Jon_Feltheimer
# actual:  One of the key people in Lionsgate is Jon Feltheimer.
# predicted:  Jon Feltheimer is a key person at Lionsgate.
#
#
# 188/7304
# tripla:  Olga_Bondareva deathDate 1991-12-09 Olga_Bondareva professionalField Economics Olga_Bondareva professionalField Mathematics
# actual:  Olga Bondareva, an economist that was a known professional in the field of mathematics, died on December 9, 1991.
# predicted:  Olga Bondareva, who died on 9th December 1991, worked in the field of Economics and Mathematics.
#
#
# 189/7304
# tripla:  The_Fellowship_of_the_Ring precededBy The_Hobbit The_Hobbit releaseDate 1937-09-21
# actual:  Published on September 21, 1937, The Hobbit precedes The Fellowship of the Ring.
# predicted:  The Fellowship of the Ring was preceded by The Hobbit which was released on September 21st 1937.
#
#
# 190/7304
# tripla:  Istanbul utcOffset +2
# actual:  The UTC offset for Istanbul is +2.
# predicted:  Istanbul has a UTC offset of +2.
#
#
# 191/7304
# tripla:  Campeonato_Brasileiro_Série_C champions Vila_Nova_Futebol_Clube Agremiação_Sportiva_Arapiraquense fullName "Agremiação Sportiva Arapiraquense" Agremiação_Sportiva_Arapiraquense league Campeonato_Brasileiro_Série_C Agremiação_Sportiva_Arapiraquense numberOfMembers 17000
# actual:  Agremiação Sportiva Arapiraquense is a club of 17000 members in the Campeonato Brasileiro Série C league along with the Vila Nova Futebol Clube.
# predicted:  Agremiaço Sportiva Arapiraquense, full name "Agremiaço Sportiva Arapiraquense", has 17000 members and play in the Campeonato Brasileiro Série C league. Vila Nova Futebol Clube are the champions of the league.
#
#
# 192/7304
# tripla:  Pontiac_Rageous assembly Michigan Pontiac_Rageous assembly Detroit Pontiac_Rageous manufacturer Pontiac Pontiac parentCompany General_Motors
# actual:  The Pontiac Rageous was a car manufactured by Pontiac, whose parent company is General Motors. The Pontiac Rageous was assembled in Detroit, Michigan.
# predicted:  Pontiac, whose parent company is General Motors, is the manufacturer of the Pontiac Rage. The Pontiac Rageous is assembled in Detroit, Michigan.
#
#
# 193/7304
# tripla:  Mermaid_(Train_song) genre Pop_rock Mermaid_(Train_song) musicalBand Train_(band) Mermaid_(Train_song) recordLabel Columbia_Records Mermaid_(Train_song) runtime 3.16
# actual:  Written by the Band Train and released by Columbia Records, Mermaid is a pop rock song with a total runtime of three minutes and sixteen seconds.
# predicted:  The musical band Train performs the song Mermaid (Train song) which is a pop rock song. The song is recorded by Columbia Records and has a runtime of 3.16.
#
#
# 194/7304
# tripla:  Bootleg_Series_Volume_1:_The_Quine_Tapes artist The_Velvet_Underground
# actual:  Music group the Velvet Underground released album Bootleg Series Volume 1: The Quine Tapes.
# predicted:  The Bootleg Series Volume 1: The Quine Tapes was created by The Velvet Underground.
#
#
# 195/7304
# tripla:  English_Without_Tears director Harold_French English_Without_Tears editing Alan_Jaggs English_Without_Tears releaseDate 1944-07-28
# actual:  English without tears was released on 1944-07-28, directed by Harold French and edited by Alan Jaggs.
# predicted:  English Without Tears was directed by Harold French and edited by Alan Jaggs and released on 28 July 1944.
#
#
# 196/7304
# tripla:  Gdynia,_Poland foundingDate 1926-02-10
# actual:  The founding date of Gdynia in Poland was 1926-02-10 .
# predicted:  Gdynia, Poland was founded on 10 February 1926.
#
#
# 197/7304
# tripla:  Cecil_Parker birthYear 1897 It's_Great_to_Be_Young_(1956_film) starring Cecil_Parker
# actual:  It's Great to Be Young starred Cecil Parker, who was born in 1897.
# predicted:  Cecil Parker was born in 1897 and starred in It's Great to Be Young (1956 film).
#
#
# 198/7304
# tripla:  Ciudad_Ayala type City
# actual:  Ciudad Ayala is a city.
# predicted:  Ciudad Ayala is a city.
#
#
# 199/7304
# tripla:  Piotr_Hallmann birthPlace Gdynia,_Poland Piotr_Hallmann weight 70.308
# actual:  Piotr Hallmann weighs 70.308 kg and was born in Gdynia, Poland.
# predicted:  Piotr Hallmann was born in Gdynia, Poland and weighs 70.308.
#
#
# 200/7304
# tripla:  Acharya_Institute_of_Technology affiliation Visvesvaraya_Technological_University Acharya_Institute_of_Technology campus "In Soldevanahalli, Acharya Dr. Sarvapalli Radhakrishnan Road, Hessarghatta Main Road, Bangalore – 560090." Acharya_Institute_of_Technology director "Dr. G. P. Prabhukumar" All_India_Council_for_Technical_Education location Mumbai Acharya_Institute_of_Technology state Karnataka Acharya_Institute_of_Technology wasGivenTheTechnicalCampusStatusBy All_India_Council_for_Technical_Education
# actual:  The Acharya Institute of Technology is based in the state of Karnataka, the institute’s director is Dr. G. P. Prabhukumar and it is affiliated with the Visvesvaraya Technological University. The All India Council for Technical Education which is located in Mumbai gave the institute Technical Campus status. The address of the campus is: Soldevanahalli, Acharya Dr. Sarvapalli Radhakrishnan Road, Hessarghatta Main Road, Bangalore - 560090.
# predicted:  The Acharya Institute of Technology is located in Soldevanahalli, Acharya Dr. Sarvapalli Radhakrishnan Road, Hessarghatta Main Road, Bangalore – 560090, Karnataka. Its director is Dr. G. P. Prabhukumar and it was given the 'Technical Campus' status by the All India Council for Technical Education in Mumbai. The Institute is affiliated with the Visvesvaraya Technological University.
#
#
# 201/7304
# tripla:  Liselotte_Grschebina birthDate 1908-05-02 Liselotte_Grschebina birthPlace Karlsruhe Liselotte_Grschebina birthPlace German_Empire Liselotte_Grschebina deathDate 1994-06-14
# actual:  Liselotte Grschebina was born in Karlsruhe, in the German Empire, on May 2, 1908, and died on June 14, 1994.
# predicted:  Liselotte Grschebina was born in Karlsruhe, German Empire on May 2, 1908 and died on June 14, 1994.
#
#
# 202/7304
# tripla:  Chinabank location Philippines
# actual:  Chinabank's location is the Philippines.
# predicted:  Chinabank is located in the Philippines.
#
#
# 203/7304
# tripla:  Super_Capers budget 2000000.0 Super_Capers director Ray_Griggs_(director) Super_Capers gross 30955.0 Super_Capers runtime 98.0 Super_Capers starring Michael_Rooker Super_Capers starring Tom_Sizemore Super_Capers writer Ray_Griggs_(director)
# actual:  Super Capers is a 98 minute movie written and directed by Ray Griggs. It starts Michael Rooker and Tom Sizemore . The budget was $2,000,000 while the income was only $30,955.
# predicted:  Super Capers, starring Tom Sizemore and Michael Roker, has a runtime of 98 minutes and a budget of 2000000.0. It was written by Ray Giles and directed by Ray Giles. Its gross is 30955.0.
#
#
# 204/7304
# tripla:  Darinka_Dentcheva almaMater Humboldt_University Darinka_Dentcheva birthDate 1958-01-01 Darinka_Dentcheva citizenship United_States Darinka_Dentcheva influencedBy Andrzej_Piotr_Ruszczyński Darinka_Dentcheva knownFor Stochastic_programming Darinka_Dentcheva professionalField Mathematical_optimization Darinka_Dentcheva residence New_Jersey
# actual:  American mathematician Darinka Dentcheva was born on January 1, 1958. Dentcheva graduated from Humboldt University in Berlin, Germany. Influenced by fellow mathematician, Andrzej Piotr Ruszczyński, Dentcheva made contributions to the field of mathematical optimization, in particular, Stochastic programming. She resides in New Jersey.
# predicted:  Darinka Dentcheva was born on January 1, 1958 in New Jersey, USA. He attended Humboldt University and is known for his work in Stochastic programming and Mathematical optimization. He was influenced by Andrzej Piotr Ruszczyski.
#
#
# 205/7304
# tripla:  GMA_New_Media product Online_Game
# actual:  GMA New Media is a company that offers online games products.
# predicted:  GMA New Media produces online games.
#
#
# 206/7304
# tripla:  Mermaid_(Train_song) genre Reggae Mermaid_(Train_song) writer Amund_Bjørklund
# actual:  The Train song Mermaid, written by Amund Bjørklund, is in the reggae genre.
# predicted:  The song Mermaid is a reggae song written by Amund Bjrklund.
#
#
# 207/7304
# tripla:  Take_It_Off! precededBy Turn_Me_On_(album)
# actual:  The album Take It Off! was preceded by the album titled Turn Me On.
# predicted:  Take It Off! was preceded by Turn Me On.
#
#
# 208/7304
# tripla:  Bionico country Mexico Bionico course Dessert Dessert dishVariation Sandesh_(confectionery)
# actual:  Bionico, Sandesh are both dessert food found in Mexico.
# predicted:  Sandesh is a dessert, as is Bionico which is a food found in Mexico.
#
#
# 209/7304
# tripla:  Trane location Ireland
# actual:  The company Trane is in Ireland.
# predicted:  Trane is located in Ireland.
#
#
# 210/7304
# tripla:  Campeonato_Brasileiro_Série_C champions Vila_Nova_Futebol_Clube Campeonato_Brasileiro_Série_C country Brazil Agremiação_Sportiva_Arapiraquense fullName "Agremiação Sportiva Arapiraquense" Agremiação_Sportiva_Arapiraquense ground Estádio_Municipal_Coaracy_da_Mata_Fonseca Agremiação_Sportiva_Arapiraquense league Campeonato_Brasileiro_Série_C Estádio_Municipal_Coaracy_da_Mata_Fonseca location Arapiraca
# actual:  Estádio Municipal Coaracy da Mata Fonseca is the name of the ground of Agremiação Sportiva Arapiraquense located in Arapiraca and their full name as "Agremiação Sportiva Arapiraquense". Agremiação Sportiva Arapiraquense play in the Brazil Campeonato Brasileiro Série C league in which Vila Nova Futebol Clube is the champion.
# predicted:  Agremiaço Sportiva Arapiraquense's full name is "Agremiaço Sportiva Arapiraquense". Their ground is the Estadio Municipal Coaracy da Mata Fonseca in Arapiraca, Brazil. They play in the Campeonato Brasileiro Série C league, the champions of which are Vila Nova Futebol Clube.
#
#
# 211/7304
# tripla:  Lady_Anne_Monson nationality Kingdom_of_England Lady_Anne_Monson residence India Lady_Anne_Monson spouse George_Monson
# actual:  Lady Anne Monson, an Englishwoman residing in India, is married to George Monson.
# predicted:  Lady Anne Monson is a national of the Kingdom of England and lives in India. She is married to George Monson.
#
#
# 212/7304
# tripla:  It's_Great_to_Be_Young_(1956_film) cinematography Gilbert_Taylor
# actual:  It's Great to Be Young is in Gilbert Taylor's cinematography.
# predicted:  Gilbert Taylor was the cinematographer of It's Great to Be Young (1956 film).
#
#
# 213/7304
# tripla:  Alan_B._Miller_Hall architect Robert_A._M._Stern Alan_B._Miller_Hall completionDate 2009-06-01 Alan_B._Miller_Hall owner College_of_William_&_Mary
# actual:  The College of William and Mary is the owner of the Alan B. Miller Hall (completed on June 1st, 2009). Robert A. M. Stern was the architect.
# predicted:  The College of William and Mary is the owner of Alan B. Miller Hall which was designed by Robert A.M. Stern and completed on 1 June 2009.
#
#
# 214/7304
# tripla:  United_States leaderTitle "Vice President" Darinka_Dentcheva residence United_States
# actual:  One of the leaders of the United States, where Darinka Dentcheva resides, is the Vice President.
# predicted:  Darinka Dentcheva lives in the United States, where the leader is called the Vice President.
#
#
# 215/7304
# tripla:  Mermaid_(Train_song) genre Pop_rock Mermaid_(Train_song) recordLabel Columbia_Records
# actual:  The Train song Mermaid in Columbia Records belongs to pop rock.
# predicted:  Mermaid is a pop rock song recorded by Columbia Records.
#
#
# 216/7304
# tripla:  MotorSport_Vision city Longfield MotorSport_Vision city Kent Bedford_Aerodrome location Thurleigh Bedford_Aerodrome operatingOrganisation MotorSport_Vision Bedford_Aerodrome runwayLength 1095.0
# actual:  MotorSport Vision is based in the city of Longfield, Kent and operates The Bedford Aerodrome in Thurleigh, which has a runway length of 1095.
# predicted:  Bedford Aerodrome is located in Thurleigh and operated by MotorSport Vision. The organization is located in Longfield, Kent and has a runway length of 1095.0.
#
#
# 217/7304
# tripla:  Olga_Bondareva birthDate 1937-04-27 Olga_Bondareva birthName "Olga Nikolaevna Bondareva" Olga_Bondareva birthPlace Leningrad,_USSR
# actual:  Olga Bondareva was born on April 27th, 1937, in Leningrad, which was then part of the USSR. Her given name at birth was "Olga Nikolaevna Bondareva".
# predicted:  Olga Bondareva was born in Leningrad, USSR on 27 April 1937. Her birth name is Olga Nikolaevna Bondareva.
#
#
# 218/7304
# tripla:  Expect_a_Miracle followedBy Afterplay_(Brian_Kelly_album) Expect_a_Miracle genre Instrumental_music
# actual:  Expect a Miracle an instrumental music genre , was followed by Brian Kelly's Afterplay album.
# predicted:  Expect a Miracle is an instrumental music album which was followed by Afterplay.
#
#
# 219/7304
# tripla:  Liselotte_Grschebina deathDate 1994-06-14 Liselotte_Grschebina deathPlace Israel
# actual:  Liselotte Grschebina died on June 14, 1994 in Israel.
# predicted:  Liselotte Grschebina died in Israel on 14th June 1994.
#
#
# 220/7304
# tripla:  ENAIRE city Madrid Adolfo_Suárez_Madrid–Barajas_Airport elevationAboveTheSeaLevel 610.0 Adolfo_Suárez_Madrid–Barajas_Airport location Alcobendas Adolfo_Suárez_Madrid–Barajas_Airport operatingOrganisation ENAIRE Adolfo_Suárez_Madrid–Barajas_Airport runwayLength 4349.0 Adolfo_Suárez_Madrid–Barajas_Airport runwayName "14L/32R"
# actual:  Adolfo Suárez Madrid–Barajas Airport is located in Alcobendas, 610 meters above sea level. This airport is operated by ENAIRE, which is located in Madrid, Spain. The runway is named 14L/32R and is 4,349 meters long.
# predicted:  Adolfo Suárez Madrid–Barajas Airport is located in Alcobendas and is operated by ENAIRE. The airport is 610 metres above sea level and has a runway named 14L/32R which is 4349 metres long. The airport is located in Madrid and is operated by ENAIRE.
#
#
# 221/7304
# tripla:  ALCO_RS-3 buildDate "May 1950 - August 1956" ALCO_RS-3 length 17068.8 (millimetres) ALCO_RS-3 powerType Diesel-electric_transmission
# actual:  The ALCO RS-3 had a diesel-electric transmission, measured 17068.8 (millimetres) in length and was produced between May 1950 and August 1956.
# predicted:  The ALCO RS-3 was built between May 1950 and August 1956 and is 17068.8 millimetres long. It has a diesel-electric transmission.
#
#
# 222/7304
# tripla:  11th_Mississippi_Infantry_Monument established 2000 Adams_County,_Pennsylvania hasToItsSouthwest Frederick_County,_Maryland 11th_Mississippi_Infantry_Monument location Adams_County,_Pennsylvania
# actual:  The 11th Mississippi Infantry Monument in Adams County, Pennsylvania, which was established in the year 2000. Frederick County, Maryland is located to the southwest of Adams County, Pennsylvania.
# predicted:  The 11th Mississippi Infantry Monument was established in 2000 and is located in Adams County, Pennsylvania. Adams County is southwest of Frederick County, Maryland.
#
#
# 223/7304
# tripla:  Abraham_A._Ribicoff birthPlace United_States Abraham_A._Ribicoff inOfficeWhilePresident John_F._Kennedy Abraham_A._Ribicoff nationality American Abraham_A._Ribicoff party Democratic_Party_(United_States) Abraham_A._Ribicoff spouse "Ruth Ribicoff"
# actual:  Abraham A. Ribicoff was of American nationality and was a member of the United States Democratic Party. He was born in the United States and was married to Ruth Ribicoff. During John F. Kennedy’s presidency, Abraham was also in office.
# predicted:  American Abraham A. Ribicoff was married to Ruth Ribicoff and was a member of the Democratic Party in the United States. He was in office while John F. Kennedy was President.
#
#
# 224/7304
# tripla:  Mermaid_(Train_song) musicalBand Train_(band) Train_(band) recordLabel Warner_Music_Group Mermaid_(Train_song) recordLabel Columbia_Records
# actual:  The record label Columbia Records released the song Mermaid by the musical band Train. The band Train were signed to the record label Warner Music Group.
# predicted:  Mermaid is a song by the band Train, which is signed to Columbia Records and Warner Music Group.
#
#
# 225/7304
# tripla:  Turn_Me_On_(album) precededBy Let_It_Breed Let_It_Breed precededBy Love_American_Style_(album) Turn_Me_On_(album) runtime 35.1
# actual:  Following the albums, Let it Breed and Love American Style, Turn me on was released at a length of 35 minutes and 10 seconds.
# predicted:  Turn Me On is preceded by Let It Breed and Love American Style. It has a runtime of 35.1.
#
#
# 226/7304
# tripla:  Nord_(Year_of_No_Light_album) followedBy Live_at_Roadburn_2008_(Year_of_No_Light_album) Nord_(Year_of_No_Light_album) genre Sludge_metal Nord_(Year_of_No_Light_album) genre Post-metal Nord_(Year_of_No_Light_album) releaseDate 2006-09-06
# actual:  Year of No Light followed their album Nord, released on 06-09-2006, with the album Live at Roadburn 2008. The album is in the genres of sludge metal and post metal.
# predicted:  The album, Year of No Light, was released on September 6th 2006 and was followed by Live at Roadburn 2008. The album is a sludge metal album and is a post-metal album.
#
#
# 227/7304
# tripla:  AmeriGas city King_of_Prussia,_Pennsylvania AmeriGas country United_States AmeriGas industry Energy_industry AmeriGas netIncome 211200000 AmeriGas operatingIncome 380700000 AmeriGas regionServed United_States
# actual:  Located in King of Prussia, Pennsylvania, AmeriGas is an energy company that serves the United States. AmeriGas has an operating income of $380,700,000 and net income of $211,200,000.
# predicted:  AmeriGas is a company in the energy industry that serves the United States. The company is located in King of Prussia, Pennsylvania and has a net income of 211200000 and an operating income of 380700000.
#
#
# 228/7304
# tripla:  It's_Great_to_Be_Young_(1956_film) cinematography Gilbert_Taylor It's_Great_to_Be_Young_(1956_film) gross 282838.0 It's_Great_to_Be_Young_(1956_film) runtime 94.0 It's_Great_to_Be_Young_(1956_film) starring John_Mills
# actual:  It's Great to Be Young is a 1956 film in which John Mills played a lead role. The film featured Gilbert Taylor as a cinematographer, and it received £282,838. The duration of the film is around 94 minutes.
# predicted:  It's Great to Be Young (1956 film) starred John Mills and was directed by Gilbert Taylor. It has a runtime of 94 minutes and a gross of 282838.0.
#
#
# 229/7304
# tripla:  Saint_Petersburg leader Georgy_Poltavchenko
# actual:  The leader of Saint Petersburg is Georgy Poltavchenko.
# predicted:  Georgy Poltavchenko is the leader of Saint Petersburg.
#
#
# 230/7304
# tripla:  11th_Mississippi_Infantry_Monument category Contributing_property 11th_Mississippi_Infantry_Monument established 2000 Adams_County,_Pennsylvania hasToItsNorth Cumberland_County,_Pennsylvania Adams_County,_Pennsylvania hasToItsWest Franklin_County,_Pennsylvania 11th_Mississippi_Infantry_Monument location Adams_County,_Pennsylvania
# actual:  The location of the 11th Mississippi Infantry Monument, built in 2000, is Adams County, Pennsylvania which has Franklin County, Pennsylvania to the west and Cumberland County, Pennsylvania to the north. This monument is classified as a Contributing Property.
# predicted:  The 11th Mississippi Infantry Monument is located in Adams County, Pennsylvania. It was established in 2000 and is categorised as a contributing property. Adams County has Franklin County to its west and Cumberland County to its north.
#
#
# 231/7304
# tripla:  Alan_B._Miller_Hall address "101 Ukrop Way" Alan_B._Miller_Hall architect Robert_A._M._Stern Alan_B._Miller_Hall currentTenants Mason_School_of_Business Alan_B._Miller_Hall owner College_of_William_&_Mary
# actual:  Alan B. Miller Hall, which was designed by Robert A.M. Stern is situated at 101 Ukrop Way. It is owned by The College of William and Mary and The Mason School of Business are the current tenants.
# predicted:  The College of William and Mary is the owner of Alan B. Miller Hall, which is located at 101 Ukrop Way and was designed by Robert A.M. Stern. The current tenants are the Mason School of Business.
#
#
# 232/7304
# tripla:  The_Velvet_Underground activeYearsStartYear 1964-01-01
# actual:  The Velvet Underground started performing in 1964.
# predicted:  The Velvet Underground began its career on January 1, 1964.
#
#
# 233/7304
# tripla:  Super_Capers starring Michael_Rooker Super_Capers starring Tom_Sizemore
# actual:  Tom Sizemore stars in Super Capers which starred Michael Rooker.
# predicted:  Tom Sizemore and Michael Roker starred in Super Capers.
#
#
# 234/7304
# tripla:  Bananaman broadcastedBy BBC Bananaman creator Steve_Bright Bananaman firstAired "1983-10-03"
# actual:  Bananaman, the TV series, was created by Steve Bright and first aired on the BBC on 03/10/1983.
# predicted:  Bananaman was first broadcast by the BBC on 3 October 1983 and was created by Steve Bright.
#
#
# 235/7304
# tripla:  Aaron_Turner activeYearsStartYear 1995 Aaron_Turner associatedBand/associatedMusicalArtist Lotus_Eaters_(band) Aaron_Turner genre Post-metal Aaron_Turner instrument Electric_guitar Aaron_Turner origin Massachusetts
# actual:  Aaron Turner is a post-metal musician from Massachusetts who plays the electric guitar. He started performing in 1995 and is a musician in the Lotus Eaters band.
# predicted:  Aaron Turner, who is from Massachusetts, started performing in 1995. He plays post-metal music and plays electric guitar for the Lotus Eaters band.
#
#
# 236/7304
# tripla:  Gdynia,_Poland timeZone Central_European_Summer_Time
# actual:  Gdynia, Poland is in the Central European Summer Time zone.
# predicted:  Gdynia, Poland is in the Central European Summer Time zone.
#
#
# 237/7304
# tripla:  Nie_Haisheng birthPlace Hubei Nie_Haisheng nationality People's_Republic_of_China
# actual:  Nie Haisheng was born in Hubei province and is a citizen of the people's Republic of China.
# predicted:  Nie Haisheng was born in Hubei and is a national of the People's Republic of China.
#
#
# 238/7304
# tripla:  Lady_Anne_Monson birthDate 1726-01-01
# actual:  Lady Anne Monson was born on January 1, 1726.
# predicted:  Lady Anne Monson was born on January 1, 1726.
#
#
# 239/7304
# tripla:  Alan_Shepard award Distinguished_Service_Medal_(United_States_Navy) Alan_Shepard birthDate "1923-11-18" Alan_Shepard birthPlace New_Hampshire Alan_Shepard deathPlace California Alan_Shepard nationality United_States Alan_Shepard servedAsChiefOfTheAstronautOfficeIn 1963 Alan_Shepard status "Deceased"
# actual:  Prior to his death in California, Alan Shepard was born on November 18, 1923 in New Hampshire, United States. He served as Chief of the Astronaut Office in 1963 and was awarded the Distinguished Service Medal by the United States Navy.
# predicted:  Alan Shepard was born on November 18, 1923 in New Hampshire. He was a US national and served as Chief of the Astronaut Office in 1963. He was awarded the Distinguished Service Medal by the US Navy. He died in California.
#
#
# 240/7304
# tripla:  Ciudad_Ayala elevationAboveTheSeaLevel 1147.0 Ciudad_Ayala governmentType Council-manager_government Ciudad_Ayala leader Juan_Nolasco Ciudad_Ayala type City
# actual:  Ciudad Ayala is a city with an elevation of 1147.0 above sea level. It uses a type of government called council-manager government, and the leader is named Juan Nolasco.
# predicted:  Juan Nolasco is the leader of Ciudad Ayala, which is 1147.0 above sea level. The city is governed by a council-manager government.
#
#
# 241/7304
# tripla:  Darinka_Dentcheva knownFor Stochastic_programming Darinka_Dentcheva professionalField Mathematical_optimization
# actual:  Darinka Dentcheva was a mathematical optimization professional, and known for Stochastic programming.
# predicted:  Darinka Dentcheva is a mathematic optimization specialist who is known for his work in stochastic programming.
#
#
# 242/7304
# tripla:  Bananaman broadcastedBy BBC BBC city Broadcasting_House Bananaman firstAired "1983-10-03" BBC foundedBy John_Reith,_1st_Baron_Reith Bananaman starring Bill_Oddie
# actual:  First aired in October of 1983, the show Bananaman starred Bill Oddie. It was broadcast by the BBC, which was founded by John Reith and has its headquarters at Broadcasting House.
# predicted:  Bananaman was first broadcast by the BBC on 3 October 1983. The BBC was founded by John Reith, 1st Baron Reith and is based at Broadcasting House. Bill Oddie starred in Bananaman.
#
#
# 243/7304
# tripla:  Train_(band) formerBandMember Johnny_Colt Train_(band) formerBandMember Charlie_Colin Mermaid_(Train_song) musicalBand Train_(band)
# actual:  Johnny Colt and Charlie Colin are former members of the band train, who own the song, Mermaid.
# predicted:  Mermaid is a train song performed by the band Train, which has Johnny Colt as a former member and Charlie Colin as a former member.
#
#
# 244/7304
# tripla:  Ciudad_Ayala isPartOf Morelos Morelos leaderTitle Governor
# actual:  Ciudad Ayala is part of Morelos, and the Governor is one of the leaders of the state of Morelos.
# predicted:  Ciudad Ayala is part of Morelos, where the leader is the Governor.
#
#
# 245/7304
# tripla:  Kingdom_of_England dissolutionYear 1707
# actual:  The year of the dissolution of the Kingdom of England was 1707.
# predicted:  The Kingdom of England was dissolution in 1707.
#
#
# 246/7304
# tripla:  Bananaman broadcastedBy BBC BBC city Broadcasting_House Bananaman starring Bill_Oddie
# actual:  Bill Oddie starred in Bananaman which was broadcast by the BBC who are based in the Broadcasting House, London.
# predicted:  Bananaman, starring Bill Oddie, was broadcast by the BBC, which is based at Broadcasting House.
#
#
# 247/7304
# tripla:  Mermaid_(Train_song) album California_37_(Train_album) Mermaid_(Train_song) followedBy Imagine_(John_Lennon_song) Mermaid_(Train_song) producer Espionage_(production_team)
# actual:  Train's song Imagine came after a song from their California 37 album, titled Mermaid, which was produced by the production team Espionage.
# predicted:  The song Mermaid, which was produced by Espionage, was followed by Imagine and California 37.
#
#
# 248/7304
# tripla:  Punk_blues stylisticOrigin Garage_rock
# actual:  Punk blues' origin is garage rock.
# predicted:  Punk blues originated from garage rock.
#
#
# 249/7304
# tripla:  Lady_Anne_Monson birthPlace Darlington Lady_Anne_Monson deathDate 1776-02-18
# actual:  Lady Anne Monson, who was born in Darlington, died on February 18th, 1776.
# predicted:  Lady Anne Monson was born in Darlington and died on 18 February 1776.
#
#
# 250/7304
# tripla:  Bedford_Aerodrome cityServed Bedford_Autodrome Bedford_Aerodrome icaoLocationIdentifier EGBF Bedford_Aerodrome operatingOrganisation MotorSport_Vision Bedford_Aerodrome runwayLength 1095.0
# actual:  Bedford Aerodrome has a runway length of 1095 and has served the Bedford Autodrome. The aerodrome has an operating organization that is called the MotorSport Vision. The ICAO location identifier for Bedford Aerodrome is EGBF.
# predicted:  Bedford Aerodrome, which serves Bedford Autodrome, is operated by MotorSport Vision and has a runway length of 1095.0. The ICAO location identifier of Bedford Aerodrome is EGBF.
#
#
# 251/7304
# tripla:  Olga_Bondareva deathPlace Saint_Petersburg Saint_Petersburg leaderTitle Governor
# actual:  Saint Petersburg, whose leader is known as the Governor, was the death place of Olga Bondareva.
# predicted:  Olga Bondareva died in Saint Petersburg, where the leader is the Governor.
#
#
# 252/7304
# tripla:  Al_Asad_Airbase operatingOrganisation United_States_Air_Force United_States_Air_Force transportAircraft Boeing_C-17_Globemaster_III
# actual:  Al Asad Airbase is operated by the United States Air Force which has a Boeing C-17 Globemaster III transport aircraft.
# predicted:  The Boeing C-17 Globemaster III is a transport aircraft in the United States Air Force which operates Al Asad airbase.
#
#
# 253/7304
# tripla:  Live_at_Roadburn_2008_(Year_of_No_Light_album) recordDate 2008-04-19
# actual:  Year of No Light's "Live at the Roadburn 2008" album was recorded on April 19, 2008.
# predicted:  The album Year of No Light, Live at Roadburn 2008, was recorded on April 19th 2008.
#
#
# 254/7304
# tripla:  University_of_Cambridge viceChancellor Leszek_Borysiewicz
# actual:  The Vice Chancellor of the University of Cambridge is Leszek Borysiewicz.
# predicted:  Leszek Borysiewicz is the vice Chancellor of the University of Cambridge.
#
#
# 255/7304
# tripla:  Israel officialLanguage Modern_Hebrew
# actual:  The official language of Israel is modern Hebrew.
# predicted:  Modern Hebrew is the official language of Israel.
#
#
# 256/7304
# tripla:  Aleksandr_Prudnikov birthDate 1989-02-24 Aleksandr_Prudnikov club FC_Terek_Grozny Aleksandr_Prudnikov currentclub FC_Amkar_Perm FC_Terek_Grozny ground Grozny Aleksandr_Prudnikov youthclub FC_Spartak_Moscow
# actual:  Aleksandr Prudnikov was born on February 24, 1989 and played for FC Spartak Moscow's youth team. He now plays for FC Terek Grozny, located in Grozny, and his current club is FC Amkar Perm.
# predicted:  Aleksandr Prudnikov was born on 24 February 1989 and he plays for FC Amkar Perm. He also played for FC Terek Grozny whose ground is in Grozny. He also played for FC Spartak Moscow youth team.
#
#
# 257/7304
# tripla:  Pontiac_Rageous assembly Michigan Pontiac_Rageous assembly Detroit Pontiac_Rageous bodyStyle Coupe
# actual:  The Pontiac Rageous coupe was assembled in Detroit, Michigan.
# predicted:  The Pontiac Rage is a coupe made in Detroit, Michigan.
#
#
# 258/7304
# tripla:  Olga_Bondareva almaMater Leningrad_State_University Olga_Bondareva knownFor Bondareva–Shapley_theorem
# actual:  Olga Bondareva studied at Leningrad State University, where she was known for the Bondareva-Shapley theorem.
# predicted:  Olga Bondareva-Shapley theorem is known for her Alma mater Leningrad State University.
#
#
# 259/7304
# tripla:  Turn_Me_On_(album) genre Noise_rock
# actual:  The genre of the Turn Me On album is noise rock.
# predicted:  Turn Me On is a noise rock album.
#
#
# 260/7304
# tripla:  1147_Stavropolis rotationPeriod 20378.5
# actual:  The asteroid 1147 Stavropolis has a rotation period of 20378.5.
# predicted:  1147 Stavropolis has a rotation period of 20378.5.
#
#
# 261/7304
# tripla:  John_Mills deathYear 2005
# actual:  John Mills died in 2005.
# predicted:  John Mills died in 2005.
#
#
# 262/7304
# tripla:  Andrzej_Piotr_Ruszczyński influencedBy Darinka_Dentcheva
# actual:  Andrzej Piotr Ruszczyński is influenced by Darinka Dentcheva.
# predicted:  Andrzej Piotr Ruszczyski was influenced by Darinka Dentcheva.
#
#
# 263/7304
# tripla:  Bananaman broadcastedBy BBC BBC city Broadcasting_House Bananaman firstAired "1983-10-03" Bananaman starring Bill_Oddie
# actual:  Bananaman first aired on 3rd October 1983 and was broadcast by the BBC based at Broadcasting House in London. One of the stars of the show was Bill Oddie.
# predicted:  Bananaman was first broadcast by the BBC on 3 October 1983 from Broadcasting House in London. Bill Oddie starred in the series.
#
#
# 264/7304
# tripla:  1147_Stavropolis apoapsis 418476000000.0 1147_Stavropolis epoch 31 July 2016 (JD2457600.5) 1147_Stavropolis periapsis 260855000000.0
# actual:  The epoch of 1147 Stavropolis is 31 July 2016 (JD2457600.5). Its periapsis is 260855000000.0 and the apoapsis of the asteroid is 418476000000.0 A.U.
# predicted:  1147 Stavropolis has an epoch date of 31 July 2016 (JD2457600.5) and an apoapsis of 418476000000.0. Its periapsis is 260855000000.0.
#
#
# 265/7304
# tripla:  Grigory_Neujmin deathDate 1946-12-17
# actual:  Grigory Neujmin died on Dec 17, 1946.
# predicted:  Grigory Neujmin died on 1946-12-17.
#
#
# 266/7304
# tripla:  1147_Stavropolis absoluteMagnitude 11.5 1147_Stavropolis apoapsis 418476000000.0 1147_Stavropolis discovered 1929-06-11 1147_Stavropolis discoverer Grigory_Neujmin 1147_Stavropolis epoch 31 July 2016 (JD2457600.5) 1147_Stavropolis orbitalPeriod 1249.6 1147_Stavropolis rotationPeriod 20378.5
# actual:  The asteroid 1147 Stavropolis was discovered, by Grigory Neujmin, on the 11th of June 1229. It has an apoapsis of 418476000000.0, an orbital period of 1249.6 days, an absolute magnitude of 11.5, a rotation period of 20378.5. It's epoch is 31 July 2016 (Julian Day 2457600.5).
# predicted:  Grigory Neujmin discovered 1147 Stavropolis on June 11th 1929. It has an epoch date of 31 July 2016 and an orbital period of 1249.6. It has a rotation period of 20378.5 and an absolute magnitude of 11.5 and an apoapsis of 418476000000.0.
#
#
# 267/7304
# tripla:  Ciudad_Ayala country Mexico Ciudad_Ayala elevationAboveTheSeaLevel 1147.0 Ciudad_Ayala leaderTitle Governator Ciudad_Ayala populationDensity 1604.0 Ciudad_Ayala timeZone Pacific_Daylight_Time
# actual:  Ciudad Ayala is located in Mexico and has a population density of 1604. The city stands 1147 m above sea level. The Governator is the leader of Ciudad Ayala located in the Pacific Daylight time zone.
# predicted:  Ciudad Ayala is located in Mexico and is 1147.0 above sea level. The Governator leads Ciudad Ayala and the population density is 1604.0. The time zone of Ciudad Ayala is Pacific Daylight Time.
#
#
# 268/7304
# tripla:  Super_Capers director Ray_Griggs_(director) Super_Capers gross 30955.0 Super_Capers starring Adam_West Super_Capers writer Ray_Griggs_(director)
# actual:  Super Capers made $30,955 and starred infamous actor, Adam West. It was written and directed by Ray Griggs.
# predicted:  Super Capers, starring Adam West, was written by Ray Giles and directed by Ray Giles. It has a gross of 30955.0.
#
#
# 269/7304
# tripla:  Akeem_Ayers debutTeam Tennessee_Titans Akeem_Ayers draftPick "39"
# actual:  Akeem Ayers is draft pick 39 for debut team Tennessee Titans.
# predicted:  Akeem Ayers made his debut for the Tennessee Titans and was drafted 39th.
#
#
# 270/7304
# tripla:  Olga_Bondareva almaMater Leningrad_State_University Olga_Bondareva birthDate 1937-04-27 Olga_Bondareva birthName "Olga Nikolaevna Bondareva" Olga_Bondareva birthPlace Leningrad,_USSR Olga_Bondareva knownFor Bondareva–Shapley_theorem
# actual:  Olga Bondareva (born Olga Nikolaevna Bondareva, on April 27, 1937, in Leningrad, USSR) graduated from Leningrad State University and is known for Bondareva-Shapley theorem.
# predicted:  Olga Nikolaevna Bondareva was born in Leningrad, USSR on 27 April 1937. She was known for the Bondareva-Shapley theorem and her Alma mater was Leningrad State University.
#
#
# 271/7304
# tripla:  Acharya_Institute_of_Technology academicStaffSize "~500" Acharya_Institute_of_Technology affiliation Visvesvaraya_Technological_University Acharya_Institute_of_Technology campus "In Soldevanahalli, Acharya Dr. Sarvapalli Radhakrishnan Road, Hessarghatta Main Road, Bangalore – 560090." Visvesvaraya_Technological_University city Belgaum Acharya_Institute_of_Technology director "Dr. G. P. Prabhukumar" All_India_Council_for_Technical_Education location Mumbai Acharya_Institute_of_Technology wasGivenTheTechnicalCampusStatusBy All_India_Council_for_Technical_Education
# actual:  The Acharya Institute of Technology campus is located in Soldevanahalli, Acharya Dr. Sarvapalli Radhakrishnan Road, Hessarghatta Main Road, Bangalore – 560090. The Institute, which is affiliated with Visvesvaraya Technological University in Belgaum, employs about 500 academic staff. The director is Dr. G. P. Prabhukumar. Acharya Institute of Technology was given the Technical Campus status by the All India Council for Technical Education, which is located in Mumbai.
# predicted:  The Acharya Institute of Technology is located in Soldevanahalli, Acharya Dr. Sarvapalli Radhakrishnan Road, Hessarghatta Main Road, Bangalore – 560090. It was given the 'Technical Campus' status by the All India Council for Technical Education in Mumbai. The Institute has 500 academic staff and is affiliated with the Visvesvaraya Technological University in Belgaum.
#
#
# 272/7304
# tripla:  Imagine_(John_Lennon_song) certification FIMI Mermaid_(Train_song) followedBy Imagine_(John_Lennon_song) Imagine_(John_Lennon_song) musicalArtist John_Lennon Mermaid_(Train_song) producer Espionage_(production_team)
# actual:  Train followed Mermaid with Imagine is a song by musical artist John Lennon, which has a FIMI certification. It was produced by the production team Espionage.
# predicted:  The musical artist John Lennon is the musical artist Imagine. The song was produced by Espionage and was followed by Mermaid (Train song). Imagine was certified by FIMI.
#
#
# 273/7304
# tripla:  France governmentType Unitary_state
# actual:  France has a unitary state form of government.
# predicted:  France is a unitary state.
#
#
# 274/7304
# tripla:  Bedford_Aerodrome elevationAboveTheSeaLevel 83.2104 Bedford_Aerodrome runwayName "08/26" Bedford_Aerodrome runwaySurfaceType Concrete
# actual:  The Bedford Aerodrome runway name is 08/26, and it is made of concrete. The aerodrome is 83.2104 metres above sea level.
# predicted:  The Bedford Aerodrome is 83.22104 metres above sea level and has a runway named 08/26 made of concrete.
#
#
# 275/7304
# tripla:  Turn_Me_On_(album) artist The_Honeymoon_Killers_(American_band) Turn_Me_On_(album) precededBy Let_It_Breed Turn_Me_On_(album) producer The_Honeymoon_Killers_(American_band) Turn_Me_On_(album) runtime 35.1
# actual:  The self-produced album Turn Me On by the American band The Honeymoon Killers has a total runtime of 35 minutes 10 seconds and was preceded by the Let it Breed album.
# predicted:  The Honeymoon Killers, an American band, produced the album Turn Me On which was preceded by Let It Breed. The album has a runtime of 35.1 and was produced by The Honeymoon Killers.
#
#
# 276/7304
# tripla:  Bionico country Mexico Bionico course Dessert Bionico region Guadalajara
# actual:  The dessert called Bionico can be found in Guadalajara, Mexico.
# predicted:  Bionico is a dessert found in the Guadalajara region of Mexico.
#
#
# 277/7304
# tripla:  Max_Benedict deathPlace London It's_Great_to_Be_Young_(1956_film) editing Max_Benedict It's_Great_to_Be_Young_(1956_film) starring John_Mills It's_Great_to_Be_Young_(1956_film) starring Cecil_Parker
# actual:  It’s Great to Be Young was a movie edited by Max Benedict. It stars John Mills and Cecil Parker and it was released in 1956. Max Benedict passed away in London.
# predicted:  It's Great to Be Young (1956 film) starred John Mills and Cecil Parker. Max Benedict was the editor of the film and died in London.
#
#
# 278/7304
# tripla:  The_Honeymoon_Killers_(American_band) genre Noise_rock
# actual:  The genre of the Honeymoon Killers is noise rock.
# predicted:  The Honeymoon Killers are an American band whose genre is noise rock.
#
#
# 279/7304
# tripla:  McVeagh_of_the_South_Seas director Harry_Carey_(actor_born_1878)
# actual:  Harry Carey was an actor born in 1878 and was the director of 'McVeagh of the South Seas'
# predicted:  Harry Carey, who was born in 1868, was the director of McVeagh of the South Seas.
#
#
# 280/7304
# tripla:  English_Without_Tears cinematography Bernard_Knowles English_Without_Tears editing Alan_Jaggs English_Without_Tears musicComposer Nicholas_Brodszky English_Without_Tears producer Anatole_de_Grunwald English_Without_Tears writer Anatole_de_Grunwald
# actual:  The music for the movie "English Without Tears" was composed by Nicholas Brodszky, whereas the movie was edited by Alan Jaggs, produced and written by Anatole de Grunwald, while Bernard Knowles did the cinematography.
# predicted:  English Without Tears was written by Anatole de Gruwald and produced by Bernard Knowles. It was edited by Alan Jaggs and Nicholas Brodszky was a composer.
#
#
# 281/7304
# tripla:  Alan_B._Miller_Hall address "101 Ukrop Way" Alan_B._Miller_Hall architect Robert_A._M._Stern Alan_B._Miller_Hall buildingStartDate "30 March 2007" Alan_B._Miller_Hall completionDate 2009-06-01 Mason_School_of_Business country United_States Alan_B._Miller_Hall currentTenants Mason_School_of_Business
# actual:  The construction of Alan B. Miller Hall lasted from March 30th, 2007 to June 1st, 2009. Robert A. M. Stern designed the building. Alan B. Miller Hall is located at 101 Ukrop Way, and the current tenant is the Mason School of Business, which is located in the United States.
# predicted:  The Mason School of Business are the current tenants of Alan B Miller Hall, 101 Ukrop Way, United States. The building was designed by Robert A M Stern and began construction on 30 March 2007.
#
#
# 282/7304
# tripla:  Piotr_Hallmann weight 70.308
# actual:  Piotr Hallmann’s weight is 70.308 kg.
# predicted:  Piotr Hallmann weighs 70,308 kg.
#
#
# 283/7304
# tripla:  Nord_(Year_of_No_Light_album) artist Year_of_No_Light Nord_(Year_of_No_Light_album) recordLabel Crucial_Blast Nord_(Year_of_No_Light_album) recordLabel E-Vinyl Nord_(Year_of_No_Light_album) releaseDate 2006-09-06 Nord_(Year_of_No_Light_album) runtime 58.41
# actual:  The Year of No Light, 58.41 minute E-Vinyl album, Nord was released on the Crucial Blast label on 2006-09-06.
# predicted:  The album "Nord" was released on 6 September 2006 and has a runtime of 58.41. It was released by Crucial Blast and E-Vinyl.
#
#
# 284/7304
# tripla:  Saint_Petersburg areaTotal 1439.0 Olga_Bondareva deathPlace Saint_Petersburg
# actual:  Olga Bondareva died in Saint Petersburg, a town which has an area of 1439 km2.
# predicted:  Olga Bondareva died in Saint Petersburg, which has a total area of 1439.0.
#
#
# 285/7304
# tripla:  Acharya_Institute_of_Technology affiliation Visvesvaraya_Technological_University Acharya_Institute_of_Technology city Bangalore Acharya_Institute_of_Technology sportsOffered Tennis
# actual:  The Acharya Institute of Technology in Bangalore, is affiliated with the Visvesvaraya Technological University and offers tennis as a sport option.
# predicted:  The Acharya Institute of Technology is located in Bangalore and is affiliated with the Visvesvaraya Technological University. The institute offers tennis as one of its sports.
#
#
# 286/7304
# tripla:  Universal_Music_Group keyPerson Lucian_Grainge Bootleg_Series_Volume_1:_The_Quine_Tapes recordLabel Polydor_Records Bootleg_Series_Volume_1:_The_Quine_Tapes recordLabel Universal_Music_Group Bootleg_Series_Volume_1:_The_Quine_Tapes recordedIn United_States
# actual:  The Bootleg Series Volume I: The Quine Tapes was released by the record label Polydor Records under the Universal Music Group record label in the United States. A key individual in the Universal Music Group is Lucian Grainge.
# predicted:  The record label of Bootleg Series Volume 1: The Quine Tapes is Polydor Records and was recorded in the United States. Lucian Grainge is a key person at the Universal Music Group.
#
#
# 287/7304
# tripla:  ENAIRE city Madrid Adolfo_Suárez_Madrid–Barajas_Airport location Alcobendas Adolfo_Suárez_Madrid–Barajas_Airport operatingOrganisation ENAIRE Adolfo_Suárez_Madrid–Barajas_Airport runwayLength 3500.0 Adolfo_Suárez_Madrid–Barajas_Airport runwayName "14L/32R"
# actual:  Adolfo Suarez Madrid-Barajas Airport in Alcobendas is operated by ENAIRE, which is based in Madrid. The airport's runway length is 3500 and the runway name is 14L/32R.
# predicted:  ENAIRE is located in Madrid and operates Adolfo Suárez Madrid–Barajas Airport in Alcobendas. The runway name is 14L/32R and it is 3500 metres long.
#
#
# 288/7304
# tripla:  Tom_Sizemore spouse Maeve_Quinlan
# actual:  Tom Sizemore is married to Maeve Quinlan.
# predicted:  Maeve Quinlan is the spouse of Tom Sizemore.
#
#
# 289/7304
# tripla:  11th_Mississippi_Infantry_Monument category Contributing_property 11th_Mississippi_Infantry_Monument established 2000 Adams_County,_Pennsylvania hasToItsSoutheast Carroll_County,_Maryland Adams_County,_Pennsylvania hasToItsWest Franklin_County,_Pennsylvania 11th_Mississippi_Infantry_Monument location Adams_County,_Pennsylvania 11th_Mississippi_Infantry_Monument municipality Gettysburg,_Pennsylvania 11th_Mississippi_Infantry_Monument state "Pennsylvania"
# actual:  Erected in 2000, the 11th Mississippi Infantry Monument is located in the municipality of Gettysburg in Adams County, Pennsylvania. Franklin County lies to the west of this contributing property, with Carroll County, Maryland to the southeast.
# predicted:  The 11th Mississippi Infantry Monument is located in Adams County, Pennsylvania. It was established in 2000 and is categorised as a contributing property. Adams County is south of Carroll County, Maryland and east of Franklin County.
#
#
# 290/7304
# ...
# actual:  Adams county, to the east of Franklin county, is the home of the 11th Mississippi Infantry Monument in Pennsylvania.
# predicted:  The 11th Mississippi Infantry Monument is located in Adams County, Pennsylvania, which has Franklin County to its west.
#
#
# 978/7304
# tripla:  Tennessee_Titans coach Mike_Mularkey Akeem_Ayers debutTeam Tennessee_Titans
# actual:  Akeem Ayers debuted with the Tennessee Titans team coached by Mike Mularkey.
# predicted:  Akeem Ayers made his debut for the Tennessee Titans, coached by Mike Mularkey.
#
#
# 979/7304
# tripla:  Piotr_Hallmann birthPlace Gdynia,_Poland Piotr_Hallmann height 175.26
# actual:  The 175.26cm tall Piotr Hallmann calls Gdynia, Poland his birthplace.
# predicted:  Piotr Hallmann was born in Gdynia, Poland and is 175.26m tall.
#
#
# 980/7304
# tripla:  English_Without_Tears musicComposer Nicholas_Brodszky English_Without_Tears producer Anatole_de_Grunwald English_Without_Tears releaseDate 1944-07-28
# actual:  The music of the film English Without Tears, released on 1944-07-28 is composed by Nicholas Brodszky and produced by Anatole de Grunwald.
# predicted:  English Without Tears was produced by Anatole de Grunwald and Nicholas Brodszky and was released on 28 July 1944.
#
#
# 981/7304
# tripla:  Aleksandr_Prudnikov birthDate 1989-02-24 Aleksandr_Prudnikov club FC_Terek_Grozny Aleksandr_Prudnikov currentclub FC_Amkar_Perm FC_Terek_Grozny ground Grozny Aleksandr_Prudnikov youthclub FC_Spartak_Moscow
# actual:  Aleksandr Prudnikov was born on February 24, 1989 and he currently plays for FC Amkar Perm, and previously played for FC Terek Grozny which is located in Grozny and youth FC Spartak Moscow.
# predicted:  Aleksandr Prudnikov was born on 24 February 1989 and he plays for FC Amkar Perm. He also played for FC Terek Grozny whose ground is in Grozny. He also played for FC Spartak Moscow youth team.
#
#
# 982/7304
# tripla:  Ciudad_Ayala country Mexico Mexico populationDensity 61.0 Ciudad_Ayala timeZone Pacific_Daylight_Time Ciudad_Ayala timeZone Pacific_Standard_Time_Zone
# actual:  Ciudad Ayala is located in the Pacific Daylight and in the Pacific standard Time Zone. It is a city in Mexico and has a population density of 61.0.
# predicted:  Ciudad Ayala is located in Mexico and has a population density of 61.0. The time zone of Ciudad Ayala is Pacific Standard Time and Pacific Daylight Time is the time zone of Mexico.
#
#
# 983/7304
# tripla:  Death_on_a_Factory_Farm director Tom_Simon Death_on_a_Factory_Farm director Sarah_Teale Death_on_a_Factory_Farm producer Tom_Simon Death_on_a_Factory_Farm producer Sarah_Teale Death_on_a_Factory_Farm runtime 83.0
# actual:  Death on a Factory Farm was produced and directed by Tom Simon and Sarah Teale. The film runs for 83 minutes.
# predicted:  Tom Simon is the director of Death on a Factory Farm which was produced by Sarah Teale and Tom Simon. The film has a runtime of 83.0 and was directed by Tom Simon.
#
#
# 984/7304
# tripla:  Mermaid_(Train_song) followedBy Imagine_(John_Lennon_song) Mermaid_(Train_song) genre Reggae Mermaid_(Train_song) musicalBand Train_(band) Mermaid_(Train_song) precededBy This'll_Be_My_Year Mermaid_(Train_song) producer Espionage_(production_team) Mermaid_(Train_song) runtime 3.16
# actual:  The song Mermaid was written by the band Train lasts 3.16 minutes and had been preceded by the song This'll Be My Year. The Train song Mermaid is in the reggae genre & was followed by the release of Imagine by John Lennon performed by Train/produced by the production team Espionage.
# predicted:  The musical band Train performed the song Mermaid which is a reggae song. It was preceded by This'll Be My Year and was produced by the Espionage production team. Imagine was followed by the song Mermaid which is a reggae song.
#
#
# 985/7304
# tripla:  Karlsruhe country Germany
# actual:  Karlsruhe is in Germany.
# predicted:  Karlsruhe is in Germany.
#
#
# 986/7304
# tripla:  Aaron_Turner associatedBand/associatedMusicalArtist Twilight_(band) Aaron_Turner genre Post-metal Aaron_Turner instrument Singing Aaron_Turner origin Boston
# actual:  Aaron Turner, originally from Boston, sings for a living as a post-metal music performer with the band Twilight.
# predicted:  Aaron Turner is a singer who performs post metal music and was a member of the band Twilight. He is originally from Boston.
#
#
# 987/7304
# tripla:  Liselotte_Grschebina deathPlace Israel Liselotte_Grschebina nationality Israel Israel populationDensity 387.63
# actual:  Liselotte Grschebina has Israeli nationality and died in Israel. The population density of Israel is 387.63.
# predicted:  Liselotte Grschebina is a national of Israel, where the population density is 387.63 and she died in Israel.
#
#
# 988/7304
# tripla:  Nurhan_Atasoy birthDate 1934-01-01 Nurhan_Atasoy birthPlace Turkey Nurhan_Atasoy citizenship Turkey Nurhan_Atasoy residence Istanbul
# actual:  Nurhan Atasoy (born in Turkey on January 1, 1934) is a Turkish citizen who resides in Istanbul.
# predicted:  Nurhan Atasoy was born on January 1, 1934 in Turkey. He lives in Istanbul and is a citizen of Turkey.
#
#
# 989/7304
# tripla:  McVeagh_of_the_South_Seas distributor Alliance_Films_Corporation McVeagh_of_the_South_Seas imdbId 0004319 McVeagh_of_the_South_Seas starring Harry_Carey_(actor_born_1878) McVeagh_of_the_South_Seas writer Harry_Carey_(actor_born_1878)
# actual:  Born in 1878, Harry Carey stars in McVeagh of the South Seas, which he also wrote. The film is distributed by Alliance Films Corporation, and is registered in IMBD under the ID 0004319.
# predicted:  McVeagh of the South Seas, starring Harry Carey (born in 1878), was distributed by Alliance Film Corporation and has the imdb ID 0004319.
#
#
# 990/7304
# tripla:  Ciudad_Ayala governmentType Council-manager_government Ciudad_Ayala leader Juan_Nolasco Ciudad_Ayala leaderTitle Governator Ciudad_Ayala populationDensity 1604.0 Ciudad_Ayala timeZone Pacific_Daylight_Time Ciudad_Ayala timeZone Pacific_Standard_Time_Zone
# actual:  Ciudad Ayala has a council-manager government led by governator Juan Nolasco. It has population density 1604.0. It is in the Pacific Standard Time Zone putting it on PDT.
# predicted:  The Governator of Ciudad Ayala is Juan Nolasco. The city is led by a council-managed government and has a population of 1604.0. The time zone of Ciudad Ayala is Pacific Standard Time and Pacific Daylight Time is the time zone of the city.
#
#
# 991/7304
# tripla:  Nord_(Year_of_No_Light_album) genre Sludge_metal Nord_(Year_of_No_Light_album) producer Year_of_No_Light
# actual:  The album Nord was produced by Year of No Light and won the album of the year in the sludge metal genre.
# predicted:  The album "Nord" is a sludge metal album produced by Year of No Light.
#
#
# 992/7304
# tripla:  Nie_Haisheng birthPlace Zaoyang Zaoyang isPartOf Hubei Nie_Haisheng mission Shenzhou_6
# actual:  Born in Zaoyang city, Hubei, Nie Haisheng participated in the Shenzhou 6 mission.
# predicted:  Nie Haisheng was born in Zaoyang, Hubei. He was a member of the Shenzhou 6 mission.
#
#
# 993/7304
# tripla:  Bionico country Mexico Bionico course Dessert Mexico currency Mexican_peso Mexico demonym Mexicans Dessert dishVariation Cookie Bionico region Guadalajara
# actual:  Bionico (served at the dessert course) is a food found in Guadalajara Mexico. The currency in Mexico is the peso inhabited by the Mexicans. Cookie is a type of dessert.
# predicted:  Bionico is a dessert found in Guadalajara, Mexico. The currency in Mexico is the peso and the people are called Mexicans. Cookies are also a dessert.
#
#
# 994/7304
# tripla:  Expect_a_Miracle artist Brian_Kelly_(composer_&_pianist) Expect_a_Miracle producer Brian_Kelly_(composer_&_pianist) Expect_a_Miracle runtime 54.56
# actual:  Expect a Miracle, created and produced by composer and pianist Brian Kelly, has a runtime of 54.56 minutes.
# predicted:  The musical, Expect a Miracle, which has a runtime of 54.56, was produced by the composer and pianist Brian Kelly.
#
#
# 995/7304
# tripla:  Alan_Shepard almaMater "NWC, M.A. 1957" Alan_Shepard birthDate "1923-11-18" Alan_Shepard birthPlace New_Hampshire Alan_Shepard deathPlace California Alan_Shepard mission Apollo_14 Alan_Shepard nationality United_States Alan_Shepard servedAsChiefOfTheAstronautOfficeIn 1963
# actual:  American Alan Shepard, who was born in New Hampshire on Nov 18, 1923 and died in California, went to school at NWC and graduated with an MA in 1957. Shepard was the Chief of the Astronaut Office in 1963, and was a member of the Apollo 14 crew.
# predicted:  Alan Shepard was born on November 18, 1923 in New Hampshire, USA. He graduated from NWC in 1957 with an M.A. and was a crew member of Apollo 14. He served as Chief of the Astronaut Office in 1963 and died in California.
#
#
# 996/7304
# tripla:  GMA_New_Media industry Entertainment GMA_New_Media location Philippines
# actual:  GMA New Media lies in the Philippines where applications are offered in the entertainment industry.
# predicted:  GMA New Media is a company in the entertainment industry located in the Philippines.
#
#
# 997/7304
# tripla:  ALCO_RS-3 buildDate "May 1950 - August 1956" ALCO_RS-3 cylinderCount 12 ALCO_RS-3 length 17068.8 (millimetres)
# actual:  The ALCO RS-3 produced between May 1950 and August 1956 with 12 cylinders has a length of 17068.8 millimetres.
# predicted:  The ALCO RS-3 was built between May 1950 and August 1956 and has 12 cylinders and is 17068.8 millimetres long.
#
#
# 998/7304
# tripla:  Super_Capers budget 2000000.0 Super_Capers director Ray_Griggs_(director) Super_Capers distributor Roadside_Attractions Super_Capers distributor Lionsgate Super_Capers gross 30955.0 Super_Capers runtime 98.0 Super_Capers starring Justin_Whalin
# actual:  Super Capers is a 98 minute film that was distributed by Lionsgate and Roadside Attractions. It was directed by Ray Griggs and stars Justin Whalin. The budget was $2,000,000 and they only grossed $30,955.
# predicted:  The film Super Capers, starring Justin Whale, was distributed by Roadside Attractions and Lionsgate. It was directed by Ray Griffin and has a gross of 30955.0. It has a runtime of 98 minutes and was produced at 2000000.0.
#
#
# 999/7304
# tripla:  It's_Great_to_Be_Young_(1956_film) editing Max_Benedict
# actual:  It's Great to Be Young was edited by Max Benedict.
# predicted:  Max Benedict edited the 1956 film It's Great to Be Young.
#
#
# 1000/7304
# tripla:  Lady_Anne_Monson deathDate 1776-02-18 Lady_Anne_Monson nationality Kingdom_of_England Lady_Anne_Monson residence India Lady_Anne_Monson spouse George_Monson
# actual:  Lady Anne Monson married George Monson was a British national but resided in India for most of her life. She died on February 18th, 1776.
# predicted:  Lady Anne Monson was a national of the Kingdom of England and lived in India. She was married to George Monson and died on 18 February 1776.
#
#
# 1001/7304
# tripla:  Brandon_Carter almaMater University_of_Cambridge Brandon_Carter birthPlace England University_of_Cambridge chancellor David_Sainsbury,_Baron_Sainsbury_of_Turville University_of_Cambridge viceChancellor Leszek_Borysiewicz
# actual:  David Sainsbury (Baron Sainsbury of Turville) and Leszek Borysiewicz hold the positions of Chancellor and Vice Chancellor, respectively, at Englishman Brandon Carter's alma mater, the University of Cambridge.
# predicted:  Brandon Carter was born in England and attended the University of Cambridge. The vice Chancellor of the University of Cambridge is Leszek Borysiewicz and the chancellor is David Sainbury, Baron Sainbury of Turville.
#
#
# 1002/7304
# tripla:  The_Fellowship_of_the_Ring author J._R._R._Tolkien The_Fellowship_of_the_Ring followedBy The_Two_Towers The_Fellowship_of_the_Ring literaryGenre Fantasy_(genre) The_Fellowship_of_the_Ring publisher George_Allen_&_Unwin
# actual:  The author of the Fellowship of the Ring, published by George Allen & Unwin, is J.R.R.Tolkien. It belongs to the fantasy literary genre and it is followed by The Two Towers.
# predicted:  The Two Towers followed The Fellowship of the Ring which was written by J.R.R. Tolkien and published by George Allen & Unwin. The book is a fantasy novel.
#
#
# 1003/7304
# tripla:  Acharya_Institute_of_Technology affiliation Visvesvaraya_Technological_University Acharya_Institute_of_Technology campus "In Soldevanahalli, Acharya Dr. Sarvapalli Radhakrishnan Road, Hessarghatta Main Road, Bangalore – 560090." Acharya_Institute_of_Technology director "Dr. G. P. Prabhukumar" All_India_Council_for_Technical_Education location Mumbai Acharya_Institute_of_Technology state Karnataka Acharya_Institute_of_Technology wasGivenTheTechnicalCampusStatusBy All_India_Council_for_Technical_Education
# actual:  The campus of the Acharya Institute of Technology is located at Soldevanahalli, Acharya Dr. Sarvapalli Radhakrishnan Road, Hessarghatta Main Road, Bangalore – 560090, in Karnataka state. The director of the Institute is Dr. G. P. Prabhukumar. The Institute is affiliated with the Visvesvaraya Technological University. It was given the status of Technical Campus by All India Council for Technical Education, which is located in Mumbai.
# predicted:  The Acharya Institute of Technology is located in Soldevanahalli, Acharya Dr. Sarvapalli Radhakrishnan Road, Hessarghatta Main Road, Bangalore – 560090, Karnataka. Its director is Dr. G. P. Prabhukumar and it was given the 'Technical Campus' status by the All India Council for Technical Education in Mumbai. The Institute is affiliated with the Visvesvaraya Technological University.
#
#
# 1004/7304
# tripla:  India areaTotal 3287590000000.0 India leader Pranab_Mukherjee Lady_Anne_Monson nationality Kingdom_of_England Lady_Anne_Monson residence India
# actual:  Lady Anne Monson was born in England but had her residence in India which has total area of 3287590000000.0. Pranab Mukherjee was a leader of India.
# predicted:  Lady Anne Monson is a national of the Kingdom of England and lives in India, where the total area is 3287590000000.0. The leader of India is Pranab Mukherjee.
#
#
# 1005/7304
# tripla:  English_Without_Tears director Harold_French English_Without_Tears editing Alan_Jaggs English_Without_Tears musicComposer Nicholas_Brodszky English_Without_Tears releaseDate 1944-07-28 English_Without_Tears runtime 89.0
# actual:  The film English Without Tears (release date 7-28-1944) is directed by Harold French. The music is composed by Nicholas Brodszky with the editing done by Alan Jaggs. The film duration is 89 minutes.
# predicted:  English Without Tears was released on 28 July 1944 and has a runtime of 89.0. It was directed by Harold French and edited by Alan Jaggs. It was composed by Nicholas Brodszky.
#
#
# 1006/7304
# tripla:  Petah_Tikva meaning "Opening of hope"
# actual:  Petah Tikva means "opening of hope."
# predicted:  Petah Tikva means "Opening of hope".
#
#
# 1007/7304
# tripla:  Aleksandr_Prudnikov club FC_Terek_Grozny Aleksandr_Prudnikov currentclub FC_Amkar_Perm FC_Terek_Grozny ground Grozny FC_Terek_Grozny manager Rashid_Rakhimov Aleksandr_Prudnikov youthclub FC_Spartak_Moscow
# actual:  Aleksandr Prudnikov youth football club was FC Spartak Moscow and he also played for FC Terek Grozny located in Grozny and managed by Rashid Rakhimov. Aleksandr Prudnikov currently plays for FC Amkar Perm.
# predicted:  Aleksandr Prudnikov, who played youth football for FC Spartak Moscow, currently plays for FC Amkar Perm. He also plays for FC Terek Grozny, whose ground is in Grozny and is managed by Rashid Rakhimov.
#
#
# 1008/7304
# tripla:  English_Without_Tears producer Anatole_de_Grunwald English_Without_Tears writer Anatole_de_Grunwald English_Without_Tears writer Terence_Rattigan
# actual:  Terence Rattigan wrote English Without Tears along with Anatole de Grunwald. Grunwald also produced the film.
# predicted:  English Without Tears was written by Terence Rattigan and Anatole de Grunwald.
#
#
# 1009/7304
# tripla:  Sony_Music_Entertainment owner Sony_Corporation
# actual:  Sony Music Entertainment is owned by Sony Corporation.
# predicted:  Sony Music Entertainment is owned by Sony Corporation.
