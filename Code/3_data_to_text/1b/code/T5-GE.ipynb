# %% [markdown]
# #**Step 1: Installazione, caricamento delle librerie e definizione delle variabili**

# %%
# !pip install transformers
# !pip install sentencepiece
# !pip install accelerate -U

#!pip install evaluate
#!pip install bert_score
#!pip install torchmetrics
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.40.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.14.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.2.2)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (0.1.99)
# Collecting accelerate
#   Downloading accelerate-0.30.0-py3-none-any.whl (302 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.4/302.4 kB 7.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (24.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.2.1+cu121)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.20.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.4.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.14.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (4.11.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.19.3 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2.2.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.10.0->accelerate)
#   Using cached nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (4.66.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, accelerate
# Successfully installed accelerate-0.30.0 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.1.105

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from torch.utils.data import Dataset
from transformers import T5ForConditionalGeneration, T5Tokenizer, T5Config, DataCollatorForSeq2Seq, Seq2SeqTrainingArguments, Seq2SeqTrainer
#from evaluate import load
#from torchmetrics.text import TranslationEditRate

# %%
percentuale_dataset = 1
dataset_type = ""
model_name = "t5-large"

# %% [markdown]
# #**Step 2: Collegamento a drive**

# %%
from google.colab import drive
drive.mount('/content/drive')

# change this to match your path
data_path_models = "./drive/MyDrive/Colab Notebooks/WebNLG-IT/Models"
data_path_data = "./drive/MyDrive/Colab Notebooks/data"
# Out:
# Mounted at /content/drive

# %% [markdown]
# #**Step 3: Importazione dei dataset**

# %%
class CustomDataset(Dataset):
    def __init__(self, X, y, tokenizer):
        self.X = X
        self.y = y
        self.tokenizer = tokenizer

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        input_text = self.X[idx]
        target_text = self.y[idx]

        input_encoding = self.tokenizer(input_text, padding='max_length', truncation=True, max_length=128, return_tensors='pt')
        target_encoding = self.tokenizer(target_text, padding='max_length', truncation=True, max_length=128, return_tensors='pt')

        return {
            'input_ids': input_encoding['input_ids'].squeeze(),
            'attention_mask': input_encoding['attention_mask'].squeeze(),
            'labels': target_encoding['input_ids'].squeeze()
        }

# carico il dataset
trainset = pd.read_csv(f'{data_path_data}/WebNLG-GE/train.csv')
devset = pd.read_csv(f'{data_path_data}/WebNLG-GE/dev.csv')

# %%
# ottengo un sottoinsieme del dataset di partenza
subset_trainset = trainset.sample(frac=percentuale_dataset, random_state=42)
subset_devset = devset.sample(frac=percentuale_dataset, random_state=42)

# train
X_train = subset_trainset['data_unit'].astype(str).values.tolist()
y_train = subset_trainset['sentence'].astype(str).values.tolist()

# dev
X_val = subset_devset['data_unit'].astype(str).values.tolist()
y_val = subset_devset['sentence'].astype(str).values.tolist()

# %%
len(subset_trainset)
# Out:
# 15992

# %%
len(subset_devset)
# Out:
# 1776

# %%
subset_trainset.head()
# Out:
#                                                data_unit  \
# 15981  Bill_Oddie birthPlace Rochdale Bananaman broad...
# 7814   Addis_Ababa_City_Hall country Ethiopia Addis_A...
# 150    Alan_Shepard almaMater "NWC, M.A. 1957" Alan_S...
# 1684   Allama_Iqbal_International_Airport cityServed ...
# 7497   Bhajji country India Bhajji ingredient Gram_fl...
#
#                                                 sentence
# 15981  Rochdale geboren Bill Oddie spielte in Bananam...
# 7814   Das Stadion von Addis Abeba, benannt nach dem ...
# 150    New Hampshire born Alan Shepard (Nov 18 1923) ...
# 1684   Die pakistanische Zivilluftfahrtbehörde befind...
# 7497   Die wichtigsten Zutaten eines Bhajji aus Indie...

# %%
len(X_train)
# Out:
# 15992

# %% [markdown]
# #**Step 4: Caricamento del modello**

# %%
from huggingface_hub import login
token = "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"
login(token=token)
# Out:
# Token will not been saved to git credential helper. Pass `add_to_git_credential=True` if you want to set the git credential as well.
# Token is valid (permission: read).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
# Load the T5 model, tokenizer, and configuration
model = T5ForConditionalGeneration.from_pretrained(model_name)
tokenizer = T5Tokenizer.from_pretrained(model_name)
config = T5Config.from_pretrained(model_name)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.95G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
# Create the custom datasets
train_dataset = CustomDataset(X_train, y_train, tokenizer)
val_dataset = CustomDataset(X_val, y_val, tokenizer)

# %%
# Set up the data collator, training arguments, and trainer
data_collator = DataCollatorForSeq2Seq(
    tokenizer=tokenizer,
    model=model,
    label_pad_token_id=tokenizer.pad_token_id
)

training_args = Seq2SeqTrainingArguments(
    output_dir="./results",
    #per_device_train_batch_size=2,
    #per_device_eval_batch_size=2,
    num_train_epochs=2,
    logging_dir="./logs",
    evaluation_strategy="steps",  # Calcolo della validation loss ad ogni epoca
    save_strategy="steps",  # Checkpoint del modello ad ogni epoca
    save_total_limit=3,  # Limita il numero di checkpoint salvati
    load_best_model_at_end=True,  # Carica il modello migliore al termine dell'addestramento
    metric_for_best_model="eval_loss",  # Sceglie la metrica per determinare il miglior modello
    greater_is_better=False,  # Indica se un valore più alto della metrica è migliore o no
    logging_steps=500,
    eval_steps=500,  # Numero di passaggi prima di valutare il modello
    # Aggiungi eventuali altri argomenti di training qui
)

# %%
trainer = Seq2SeqTrainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
    data_collator=data_collator,
    tokenizer=tokenizer,
)

# Fine-tune the model
trainer.train()
# Out:
#     <div>
#
#       <progress value='3998' max='3998' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [3998/3998 44:40, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.738800</td>
#       <td>0.249048</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.258400</td>
#       <td>0.219544</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.238200</td>
#       <td>0.204967</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.225600</td>
#       <td>0.197825</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.202000</td>
#       <td>0.193158</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.195900</td>
#       <td>0.189385</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.192600</td>
#       <td>0.187080</td>
#     </tr>
#   </tbody>
# </table><p>
# There were missing keys in the checkpoint model loaded: ['encoder.embed_tokens.weight', 'decoder.embed_tokens.weight', 'lm_head.weight'].
# TrainOutput(global_step=3998, training_loss=0.2810651446175969, metrics={'train_runtime': 2682.2576, 'train_samples_per_second': 11.924, 'train_steps_per_second': 1.491, 'total_flos': 1.7311718178816e+16, 'train_loss': 0.2810651446175969, 'epoch': 2.0})

# %%
# salvataggio del modello
model.save_pretrained(f'{data_path_models}/{model_name}_ge_2epoch')
tokenizer.save_pretrained(f'{data_path_models}/{model_name}_ge_2epoch')
# Out:
# ('./drive/MyDrive/Colab Notebooks/WebNLG-IT/Models/t5-large_ge_2epoch/tokenizer_config.json',
#  './drive/MyDrive/Colab Notebooks/WebNLG-IT/Models/t5-large_ge_2epoch/special_tokens_map.json',
#  './drive/MyDrive/Colab Notebooks/WebNLG-IT/Models/t5-large_ge_2epoch/spiece.model',
#  './drive/MyDrive/Colab Notebooks/WebNLG-IT/Models/t5-large_ge_2epoch/added_tokens.json')

# %% [markdown]
# #**Step 5: generazione frasi del modello creato**

# %%
model1 = T5ForConditionalGeneration.from_pretrained(f'{data_path_models}/{model_name}_ge_2epoch')
tokenizer1 = T5Tokenizer.from_pretrained(f'{data_path_models}/{model_name}_ge_2epoch')
print(f'{data_path_models}/{model_name}_ge_2epoch')
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# ./drive/MyDrive/Colab Notebooks/WebNLG-IT/Models/t5-large_ge_2epoch

# %%
def generate_text(input_rdf, max_length=128):
  input_text = f"{input_rdf}"
  input_ids = tokenizer1.encode(input_text, return_tensors="pt")

  # Imposta il parametro max_length per controllare la lunghezza dell'output generato
  output_ids = model1.generate(input_ids, max_length=max_length)

  output_text = tokenizer1.decode(output_ids[0], skip_special_tokens=True)
  return output_text

# %%
testset = pd.read_csv(f'{data_path_data}/WebNLG-GE/test.csv')

# ottengo un sottoinsieme del testset di partenza
subset_testset = testset.sample(frac=percentuale_dataset, random_state=42)

# test
X_test = subset_testset['data_unit'].values.tolist()
y_test = subset_testset['sentence'].values.tolist()

len(X_test)
# Out:
# 1000

# %%
subset_testset.head()
# Out:
#                                              data_unit  \
# 521         Peter_Stöger club FC_Admira_Wacker_Mödling
# 737                   Arem-arem ingredient Banana_leaf
# 740  Weymouth_Sands followedBy Maiden_Castle_(novel...
# 660  Christian_Panucci club Genoa_C.F.C. Christian_...
# 411                        Chicharrón region Andalusia
#
#                                               sentence
# 521  Peter Stögers Verein ist der FC Admira Wacker ...
# 737           Arem-arem nutzt die Zutat Bananenblatt.
# 740  'A Glastonbury Romance' folgte "Weymouth Sands...
# 660  A.s. Livorno Calcio werden von Christian Panuc...
# 411      Chicharron stammt aus der Region Andalusien.

# %%
triple = []
predicted = []
actuals = []

i = 0
for tripla in X_test:
  triple.append(tripla)
  prediction = generate_text(tripla)
  predicted.append(prediction)
  actuals.append(y_test[i])

  print(f'{i}/{len(X_test)-1}')
  print('tripla: ', tripla)
  print('actual: ', y_test[i])
  print('predicted: ', prediction)
  print('\n')

  df = pd.DataFrame(list(zip(triple, predicted, actuals)), columns =['triple', 'predicted', 'actuals'])
  df.to_csv(f'{data_path_models}/{model_name}_ge_2epoch_decoding.csv', index=False)

  i += 1
# Out:
# Output streaming troncato alle ultime 5000 righe.
#
#
# 167/999
# tripla:  Andrews_County_Airport runwayLength 1773.0
# actual:  Die Länge der Start- und Landebahn am Flughafen Andrews County beträgt 1773 Meter.
# predicted:  Die Fahrbahnlänge des Andrews County Airport beträgt 1773,0.
#
#
# 168/999
# tripla:  Alderney_Airport runwayLength 497.0
# actual:  Die Fahrbahnlänge des Flughafens Alderney beträgt 497,0.
# predicted:  Die Fahrbahnlänge des Flughafens Alderney beträgt 497,0.
#
#
# 169/999
# tripla:  A.C._Chievo_Verona ground "Verona, Italy" A.C._Chievo_Verona league Serie_A
# actual:  Verona, Italien ist die Heimat von A.C. Chievo Verona, die in der Liga, Serie A.
# predicted:  A.C. Chievo Verona spielt in der Serie A und hat seinen Sitz in Verona, Italien.
#
#
# 170/999
# tripla:  Auron_(comicsCharacter) creator Karl_Kesel Auron_(comicsCharacter) creator Walt_Simonson
# actual:  Die Comicfigur Auron wurde sowohl von Karl Kesel als auch von Walt Simonson gegründet.
# predicted:  Die Comicfigur Auron wurde von Karl Kesel und Walt Simonson gegründet.
#
#
# 171/999
# tripla:  Adolfo_Suárez_Madrid–Barajas_Airport runwayLength 3500.0
# actual:  Die Start- und Landebahn des Flughafens Adolfo Suárez Madrid-Barajas beträgt 3.500.
# predicted:  Die Fahrbahnlänge des Flughafens Adolfo Suárez Madrid-Barajas beträgt 3500.
#
#
# 172/999
# tripla:  Adolfo_Suárez_Madrid–Barajas_Airport location "Madrid, Paracuellos de Jarama, San Sebastián de los Reyes and Alcobendas" Adolfo_Suárez_Madrid–Barajas_Airport operatingOrganisation ENAIRE Adolfo_Suárez_Madrid–Barajas_Airport runwayLength 3500.0 Adolfo_Suárez_Madrid–Barajas_Airport runwayName "14R/32L"
# actual:  Der Flughafen Adolfo Suarez Madrid-Barajas befindet sich in Madrid, Paracuellos de Jarama, San Sebastian de los Reyes und Alcobendas und wird von ENAIRE betrieben. Es hat einen Fahrbahnnamen von 14R / 32L mit einer Länge von 3500.
# predicted:  Der Flughafen Adolfo Suárez Madrid-Barajas befindet sich in Madrid, Paracuellos de Jarama, San Sebastián de los Reyes und Alcobendas und wird von ENAIRE betrieben. Der Fahrbahnname ist 14R / 32L und ist 3500 Meter lang.
#
#
# 173/999
# tripla:  Cleveland governingBody Cleveland_City_Council Cleveland isPartOf Cuyahoga_County,_Ohio Cleveland isPartOf Ohio 200_Public_Square location Cleveland
# actual:  200 Public Square befindet sich in Cleveland, Cuyahoga County, Ohio, das von der Cleveland Stadtverwaltung regiert wird.
# predicted:  200 Public Square befindet sich in Cleveland, Cuyahoga County, Ohio, wo Cleveland City Council das Führungsgremium ist.
#
#
# 174/999
# tripla:  Adare_Manor architect Philip_Charles_Hardwick Adare_Manor completionDate 1862 Adare_Manor location Adare Adare_Manor location County_Limerick
# actual:  Adare Manor, 1862 vom Architekten Philip Charles Hardwick fertiggestellt, befindet sich in Adare, in der Grafschaft Limerick.
# predicted:  Adare Manor, entworfen von Philip Charles Hardwick, befindet sich in Adare, County Limerick und wurde 1862 fertiggestellt.
#
#
# 175/999
# tripla:  AFC_Ajax numberOfMembers 53502 AFC_Ajax season 2014
# actual:  AFC Ajax hat 53502 Mitglieder und sie zahlten in der Saison 2014.
# predicted:  AFC Ajax hat 53502 Mitglieder und spielte in der Saison 2014.
#
#
# 176/999
# tripla:  Beef_kway_teow country "Singapore and Indonesia" Beef_kway_teow ingredient Palm_sugar Beef_kway_teow region Indonesia
# actual:  Rindfleisch Kway Teow ist ein Gericht, das Palmenzucker enthält und gemeinhin in Singapur und Indonesien zu finden ist.
# predicted:  Palmenzucker ist eine Zutat in Rindfleisch Kway Teow, die aus Indonesien und Singapur kommt.
#
#
# 177/999
# tripla:  Baymax creator Duncan_Rouleau Baymax creator Steven_T._Seagle Baymax firstAppearanceInFilm Big_Hero_6_(film) Baymax series Big_Hero_6_(film)
# actual:  Baymax ist ein Charakter von Duncan Rouleau und Steve T. Seagle, der zuerst im Film "Big Hero 6" erschien.
# predicted:  Baymax, der in Big Hero 6 erstmals ins Kino kam, wurde von Duncan Rouleau und Steven T. Seagle gegründet.
#
#
# 178/999
# tripla:  Alan_B._Miller_Hall architecturalStyle Georgian_architecture Alan_B._Miller_Hall location Williamsburg,_Virginia Alan_B._Miller_Hall owner College_of_William_&_Mary
# actual:  Das College von William und Mary ist der Besitzer der georgianischen Alan B. Miller Hall in Virginia.
# predicted:  Alan B Miller Hall befindet sich in Williamsburg, Virginia und ist im Besitz des Kollegiums von William und Mary. Es ist im georgianischen Stil gebaut.
#
#
# 179/999
# tripla:  Almond family Rosaceae Ajoblanco ingredient Almond Almond order Rosids
# actual:  Mandeln, eine Zutat in Ajoblanco, stammen aus der Familie Rosaceae und aus dem Auftrag ROSIDS.
# predicted:  Mandel ist eine Zutat in Ajoblanco und gehört zur Familie Rosaceae und der Ordnung der Rosids.
#
#
# 180/999
# tripla:  Dublin country Republic_of_Ireland Dublin leaderTitle European_Parliament 3Arena location Dublin 3Arena owner Live_Nation_Entertainment
# actual:  Live Nation Entertainment ist der Besitzer von 3Arena in Dublin, Republik Irland, wo der Führer der Regierung ist das Europäische Parlament.
# predicted:  3Arena befindet sich in Dublin, Republik Irland, wo das Europäische Parlament der Führer ist. Der Besitzer der 3Arena ist Live Nation Entertainment.
#
#
# 181/999
# tripla:  Almond order Rosids
# actual:  Mandeln sind von der Bestellung ROSIDS.
# predicted:  Mandeln sind Teil der Ordnung der Rosids.
#
#
# 182/999
# tripla:  Maple_Ridge_Township,_Alpena_County,_Michigan country United_States
# actual:  Ahorn Ridge Townshio, Alpena County Michigan ist in den USA.
# predicted:  Maple Ridge Township, Alpena County, Michigan ist in den USA.
#
#
# 183/999
# tripla:  Acharya_Institute_of_Technology affiliation Visvesvaraya_Technological_University Acharya_Institute_of_Technology city Bangalore Acharya_Institute_of_Technology country "India" Acharya_Institute_of_Technology established 2000 Acharya_Institute_of_Technology numberOfPostgraduateStudents 700
# actual:  Das Acharya Institute of Technology in Bangalore, Indien wurde im Jahr 2000 gegründet. Sie hat 700 Studenten und ist an die Visvesvaraya Technological University angeschlossen.
# predicted:  Das Acharya Institute of Technology in Bangalore, Indien wurde im Jahr 2000 gegründet und hat 700 postgraduierte Studenten. Es ist mit der Visvesvaraya Technological University verbunden.
#
#
# 184/999
# tripla:  Lemon order Sapindales
# actual:  Zitrone kommt aus der Anlagenordnung Sapindales.
# predicted:  Zitrone ist Teil der Bestellung Sapindales.
#
#
# 185/999
# tripla:  Bacon_Explosion country United_States Bacon_Explosion ingredient Bacon Bacon_Explosion region Kansas_City_metropolitan_area
# actual:  Bacon ist eine Zutat in einer Bacon-Explosion, die aus der Metropolregion Kansas City in den USA stammt.
# predicted:  Speck Explosion kommt aus der Metropolregion Kansas City in den USA.
#
#
# 186/999
# tripla:  Acharya_Institute_of_Technology country "India" Acharya_Institute_of_Technology established 2000
# actual:  Das Acharya Institute of Technology in Indien wurde im Jahr 2000 gegründet.
# predicted:  Das Acharya Institute of Technology wurde im Jahr 2000 in Indien gegründet.
#
#
# 187/999
# tripla:  School of Business and Social Sciences at the Aarhus University affiliation European_University_Association School of Business and Social Sciences at the Aarhus University established 1928
# actual:  Die School of Business and Social Sciences an der Universität Aarhus wurde 1928 gegründet und ist mit dem Europäischen Hochschulverband verbunden.
# predicted:  Die School of Business and Social Sciences an der Universität Aarhus wurde 1928 gegründet und ist mit dem Europäischen Hochschulverband verbunden.
#
#
# 188/999
# tripla:  Bacon_sandwich country United_Kingdom Bacon_sandwich ingredient Ketchup
# actual:  Ketchup kann eine Zutat in einem Speck-Sandwich sein, das im Vereinigten Königreich beliebt ist.
# predicted:  Ketchup ist eine Zutat in einem Speck-Sandwich, das aus dem Vereinigten Königreich kommt.
#
#
# 189/999
# tripla:  Barny_Cakes carbohydrate 18.0 g Barny_Cakes dishVariation Apple Barny_Cakes fat 4.8 g Barny_Cakes protein 1.8 g
# actual:  Barny Kuchen kann man mit Apfel machen. Sie enthalten 1,8 g Eiweiß, 4,8 g Fett und 18 Gramm Kohlenhydrat.
# predicted:  Barny Kuchen, die eine Variante von Apple sind, enthalten 4,8g Fett und 18,0g Kohlenhydrate.
#
#
# 190/999
# tripla:  AIP_Advances editor "Vincent H. Crespi, Bernard S. Gerstman, A.T. Charlie Johnson,  Masaaki Tanaka, Enge G. Wang"
# actual:  Die Herausgeber von AIP Advances sind Vicent H. Crespi, Bernard S. Gerstman, A.T. Charlie Johnson, Masaaki Tanaka, Enge G. Wang.
# predicted:  AIP Advances wurde von Vincent H. Crespi, Bernard S. Gerstman, A.T. Charlie Johnson, Masaaki Tanaka und Enge G. Wang geschrieben.
#
#
# 191/999
# tripla:  Alan_B._Miller_Hall address "101 Ukrop Way" Alan_B._Miller_Hall inaugurationDate "2009-10-02"
# actual:  Alan B Miller Hall (die am 2009-10-02 eingeweiht wurde) hat die Adresse "101 Ukrop Way".
# predicted:  Die Alan B Miller Hall, die 101 Ukrop Way hat, wurde am 2. Oktober 2009 eingeweiht.
#
#
# 192/999
# tripla:  11th_Mississippi_Infantry_Monument state "Pennsylvania"
# actual:  Das 11. Mississippi-Infanterie-Denkmal ist in Pennsylvania.
# predicted:  Das 11. Mississippi-Infanterie-Denkmal befindet sich in Pennsylvania.
#
#
# 193/999
# tripla:  Batagor dishVariation Siomay Siomay dishVariation Shumai
# actual:  Batagor, Shumai und Siomay sind Variationen des gleichen Gerichts.
# predicted:  Batagor und Shumai sind Variationen von Siomay und Shumai.
#
#
# 194/999
# tripla:  Asilomar_Conference_Grounds architect Julia_Morgan Julia_Morgan birthPlace San_Francisco Julia_Morgan significantBuilding Los_Angeles_Herald-Examiner Julia_Morgan significantBuilding Asilomar_State_Beach
# actual:  Julia Morgan, geboren in San Francisco und Designer vieler bedeutender Gebäude, darunter das Los Angeles Herald Examiner Gebäude und der Asilomar State Beach, war auch der Architekt des Geländes der Asilomar Konferenz.
# predicted:  Julia Morgan wurde in San Francisco geboren und entwarf die Asilomar Conference Grounds, die Los Angeles Herald Examiner und Asilomar State Beach.
#
#
# 195/999
# tripla:  Serie_B champions Carpi_F.C._1909 A.C._Cesena ground Italy A.C._Cesena league Serie_B
# actual:  Die AC Cesena, deren Boden sich in Italien befindet, ist in der Serie B Liga. Carpi FC 1909 ist bisheriger Meister der Serie B.
# predicted:  A.C. Cesena Boden ist in Italien und sie spielen in der Serie B, die von Carpi FC 1909 gewonnen wurde.
#
#
# 196/999
# tripla:  Blockbuster_(comicsCharacter) alternativeName "Roland Desmond"
# actual:  Die Comicfigur Blockbuster ist auch als Roland Desmond bekannt.
# predicted:  Die Comicfigur Blockbuster hat den alternativen Namen Roland Desmond.
#
#
# 197/999
# tripla:  Marriott_International foundationPlace Washington,_D.C. Marriott_International keyPerson Bill_Marriott Marriott_International location Bethesda,_Maryland AC_Hotel_Bella_Sky_Copenhagen tenant Marriott_International
# actual:  Bill Marriot ist die Schlüsselperson bei Marriott International, die in Washington D.C. gegründet wurde und sich jetzt in Bethesda Maryland befindet und der Mieter des AC Hotel Bella Sky Kopenhagen ist.
# predicted:  Bill Marriott ist eine Schlüsselperson bei Marriott International, die in Bethesda, Maryland, gegründet wurde. Der Mieter des AC Hotel Bella Sky Copenhagen ist Marriott International.
#
#
# 198/999
# tripla:  11th_Mississippi_Infantry_Monument category Contributing_property 11th_Mississippi_Infantry_Monument municipality Gettysburg,_Pennsylvania 11th_Mississippi_Infantry_Monument state "Pennsylvania"
# actual:  Das 11. Mississippi-Infanterie-Denkmal, das sich in Gettysbury im Bundesstaat Pennsylvania befindet, wird als Sachbeschädigung eingestuft.
# predicted:  Das 11. Mississippi-Infanterie-Denkmal befindet sich in der Gemeinde Gettysburg, Pennsylvania und ist als Sachbeschädigung kategorisiert.
#
#
# 199/999
# tripla:  Serie_B champions Carpi_F.C._1909 A.C._Cesena ground Italy A.C._Cesena league Serie_B A.C._Cesena numberOfMembers 23900
# actual:  Der Boden von AC Cesena befindet sich in Italien und hat 23900 Mitglieder. Sie spielen in der Serie B-Liga, von denen Carpi FC 1909 der Meister ist.
# predicted:  A.C. Cesena hat 23900 Mitglieder und spielt in der Serie B, die von Carpi FC 1909 gewonnen wurde.
#
#
# 200/999
# tripla:  Aarhus_Airport operatingOrganisation Aktieselskab Aarhus_Airport runwayLength 2776.0 Aarhus_Airport runwayName "10R/28L"
# actual:  Der Flughafen Aarhus wird von Aktieselskab betrieben; sein Fahrbahnname ist 10R / 28L und seine Fahrbahnlänge beträgt 2776.
# predicted:  Aktieselskab ist die Betriebsorganisation für den Flughafen Aarhus, die eine Fahrbahnlänge von 2776,0 hat und 10R / 28L heißt.
#
#
# 201/999
# tripla:  Bionico country Mexico Bionico ingredient Raisin
# actual:  Rosinen sind in Bionico zu finden, das in Mexiko zu finden ist.
# predicted:  Bionico ist ein Lebensmittel, das Rosinen enthält und stammt aus Mexiko.
#
#
# 202/999
# tripla:  Springer_Science+Business_Media founder Julius_Springer
# actual:  Der Gründer von Springer Science und Business Media ist Julius Springer.
# predicted:  Julius Springer ist der Gründer von Springer Science + Business Media.
#
#
# 203/999
# tripla:  Philippines officialLanguage Philippine_English
# actual:  Das philippinische Englisch ist die Amtssprache der Philippinen.
# predicted:  Die offizielle Sprache der Philippinen ist philippinisches Englisch.
#
#
# 204/999
# tripla:  United_Kingdom capital London Bacon_sandwich country United_Kingdom Bacon_sandwich dishVariation BLT BLT dishVariation Club_sandwich
# actual:  London ist die Hauptstadt des Vereinigten Königreichs, das das Land ist, in das das Speck-Sandwich kommt. Eine Variante eines Speck-Sandwich ist die BLT, die selbst eine Variante eines Club Sandwich ist.
# predicted:  London ist die Hauptstadt des Vereinigten Königreichs, wo das Speck-Sandwich eine Variante des BLT ist.
#
#
# 205/999
# tripla:  103_Colmore_Row location Colmore_Row
# actual:  103 Colmore Row befindet sich bei Colmore Row.
# predicted:  103 Colmore Row befindet sich in Colmore Row.
#
#
# 206/999
# tripla:  Bananaman broadcastedBy BBC Bananaman creator Steve_Bright Bananaman firstAired "1983-10-03" Bananaman lastAired "1986-04-15" Bananaman starring Jill_Shilling
# actual:  Die BBC hat die TV-Serie von Bananaman zwischen dem 3. Oktober 1983 und dem 15. April 1986 ausgestrahlt. Es wurde von Steve Bright erstellt und spielte Jill Shilling.
# predicted:  Bananaman wurde am 3. Oktober 1983 erstmals ausgestrahlt und am 15. April 1986 von der BBC ausgestrahlt. Es wurde von Steve Bright erstellt und spielte Jill Shilling.
#
#
# 207/999
# tripla:  Turkey capital Ankara Turkey currency Turkish_lira Atatürk_Monument_(İzmir) designer Pietro_Canonica Atatürk_Monument_(İzmir) inaugurationDate "1932-07-27" Turkey leaderTitle President_of_Turkey Atatürk_Monument_(İzmir) location Turkey
# actual:  Das Atatürk-Denkmal, das von Pietro Canonica entworfen wurde, wurde am 27. Juli 1932 eingeweiht. Der Führer der Türkei ist der Präsident, seine Währung ist die türkische Lira und die Hauptstadt ist Ankara.
# predicted:  Das Atatürk-Denkmal (Izmir) wurde von Pietro Canonica entworfen und am 27. Juli 1932 eingeweiht. Die Hauptstadt der Türkei ist Ankara und die Währung ist die türkische Lira. Der Führer der Türkei ist der Präsident der Türkei.
#
#
# 208/999
# tripla:  Acharya_Institute_of_Technology campus "In Soldevanahalli, Acharya Dr. Sarvapalli Radhakrishnan Road, Hessarghatta Main Road, Bangalore – 560090." Acharya_Institute_of_Technology director "Dr. G. P. Prabhukumar"
# actual:  Der Direktor des Acharya Institute of Technology ist Dr. G P Prabhukumar. Der Campus befindet sich in Soldevanahalli, Acharya Dr. Sardampfalli Radhakrishnan Road, Hessarghatta Main Road, Bangalore - 560090.
# predicted:  Der Campus des Acharya Institute of Technology befindet sich in Soldevanahalli, Acharya Dr. Sardampfalli Radhakrishnan Road, Hessarghatta Main Road, Bangalore - 560090. Der Direktor des Instituts ist Dr. G. P. Prabhukumar.
#
#
# 209/999
# tripla:  Greece leader Prokopis_Pavlopoulos A.E_Dimitra_Efxeinoupolis location Greece
# actual:  Der Verein A.E Dimitra Efxeinoupolis befindet sich in Griechenland, wo Prokopis Pavlopoulos führend ist.
# predicted:  A.E Dimitra Efxeinoupolis befindet sich in Griechenland, wo der Führer Prokopis Pavlopoulos ist.
#
#
# 210/999
# tripla:  AFC_Ajax_(amateurs) ground Amsterdam Amsterdam leader Eberhard_van_der_Laan
# actual:  AFC Ajax hat seinen Sitz in Amsterdam, wo der Führer Eberhard van der Laan ist.
# predicted:  Eberhard van der Laan ist der Anführer von Amsterdam, wo sich der Boden des AFC Ajax (Amateure) befindet.
#
#
# 211/999
# tripla:  Abilene,_Texas areaOfWater 14.2 (square kilometres)
# actual:  Abilene, Texas hat eine Wasserfläche von 14,2 Quadratkilometern.
# predicted:  Abilene, Texas hat eine Wasserfläche von 14,2 Quadratkilometern.
#
#
# 212/999
# tripla:  Akron,_Ohio leaderTitle Mayor
# actual:  Der Anführer von Akron, Ohio ist der Bürgermeister.
# predicted:  Der Bürgermeister ist der Titel des Führers von Akron, Ohio.
#
#
# 213/999
# tripla:  Accademia_di_Architettura_di_Mendrisio academicStaffSize 100 Accademia_di_Architettura_di_Mendrisio city Mendrisio Accademia_di_Architettura_di_Mendrisio country Switzerland Accademia_di_Architettura_di_Mendrisio established 1996 Switzerland leaderTitle Federal_Chancellor_of_Switzerland Accademia_di_Architettura_di_Mendrisio numberOfStudents 600
# actual:  Die Stadt Mendrisio in der Schweiz, die von der Bundeskanzlerin geleitet wird, ist der Standort der 1996 gegründeten Accademia di Architettura di Mendrisio, die 600 Studenten und 100 akademische Mitarbeiter hat.
# predicted:  Die Accademia di Architettura di Mendrisio in Mendrisio, Schweiz wurde 1996 gegründet und hat 600 Studenten. Es hat 100 akademische Mitarbeiter und 600 Studenten. Der Schweizer Regierungschef ist der Bundeskanzler.
#
#
# 214/999
# tripla:  Romania leaderTitle Prime_Minister_of_Romania
# actual:  Der Führer Rumäniens ist als Ministerpräsident bekannt.
# predicted:  Der Premierminister von Rumänien ist der Führer des Landes.
#
#
# 215/999
# tripla:  Malaysia capital Putrajaya Asam_pedas country Malaysia Malaysia ethnicGroup Malaysian_Chinese Malaysia ethnicGroup Malaysian_Malay Asam_pedas region "Sumatra and Malay Peninsula"
# actual:  ASAM pedas ist ein Lebensmittel in der Region von Sumatra und Malay Halbinsel in Malaysia, dessen Hauptstadt Putrajaya ist, und deren ethnische Gruppen die Malay und die malaysischen Chinesen sind.
# predicted:  ASAM pedas ist ein Lebensmittel in Malaysia, wo die Hauptstadt Putrajaya ist und die malaysischen Chinesen und Malay eine ethnische Gruppe sind. Es stammt aus der Region Sumatra und der malaiischen Halbinsel.
#
#
# 216/999
# tripla:  14th_New_Jersey_Volunteer_Infantry_Monument country "United States" 14th_New_Jersey_Volunteer_Infantry_Monument district Monocacy_National_Battlefield 14th_New_Jersey_Volunteer_Infantry_Monument established "1907-07-11" Monocacy_National_Battlefield location Frederick_County,_Maryland Monocacy_National_Battlefield nearestCity Frederick,_Maryland 14th_New_Jersey_Volunteer_Infantry_Monument owningOrganisation National_Park_Service
# actual:  Das 14. New Jersey Freiwillige Infanterie-Denkmal (befindet sich im Monocacy National Battlefield, Frederick County, Maryland, USA) wurde am 11. Juli 1907 gegründet. Die nächste Stadt ist Frederick, Maryland. Das Denkmal wurde von der Nationalparkverwaltung zur Verfügung gestellt.
# predicted:  Das 14. New Jersey Volunteer Infantry Monument befindet sich im Monocacy National Battlefield in Frederick County, Maryland, USA. Es wurde am 11. Juli 1907 gegründet und ist im Besitz der Nationalparkverwaltung. Die nächste Stadt ist Frederick.
#
#
# 217/999
# tripla:  Bananaman broadcastedBy BBC Bananaman creator John_Geering Bananaman firstAired "1983-10-03" Bananaman lastAired "1986-04-15" Bananaman starring Graeme_Garden
# actual:  Bananaman wurde am 3. Oktober 1983 in der BBC ausgestrahlt und am 15. April 1986 ausgestrahlt. Graeme Garden war einer der Stars der Serie, die von John Geering geschaffen wurde.
# predicted:  Bananaman wurde am 3. Oktober 1983 erstmals ausgestrahlt und am 15. April 1986 von der BBC ausgestrahlt. Es wurde von John Geering gegründet und spielte Graeme Garden.
#
#
# 218/999
# tripla:  Binignit country Philippines Binignit ingredient Taro
# actual:  Taro ist eine Zutat von Binignit, die von den Philippinen kommt.
# predicted:  Taro ist eine Zutat in Binignit, die auf den Philippinen gefunden wird.
#
#
# 219/999
# tripla:  Baked_Alaska country France Baked_Alaska ingredient Christmas_pudding Baked_Alaska region Hong_Kong
# actual:  Weihnachtspudding ist eine Zutat in Baked Alaska, die sowohl aus Hongkong als auch aus Frankreich stammt.
# predicted:  Weihnachtspudding ist eine Zutat in Baked Alaska, die aus Hongkong und Frankreich kommt.
#
#
# 220/999
# tripla:  Spain currency Euro
# actual:  Die Währung von Spanien ist Euro.
# predicted:  Die Währung Spaniens ist der Euro.
#
#
# 221/999
# tripla:  John_Buscema award Inkpot_Award
# actual:  John Buscema hat den Inkpot Award gewonnen.
# predicted:  John Buscema gewann den Inkpot Award.
#
#
# 222/999
# tripla:  Amatriciana_sauce ingredient Tomato
# actual:  Amatriciana Sauce hat Tomate als eine ihrer Zutaten.
# predicted:  Tomate ist eine Zutat in Amatriciana Sauce.
#
#
# 223/999
# tripla:  Alan_Shepard deathPlace California California senators Dianne_Feinstein
# actual:  Dianne Feinstein gehört zu den Senatoren von Kalifornien, wo Alan Shepard starb.
# predicted:  Alan Shepard starb in Kalifornien, wo Dianne Feinstein Senatorin ist.
#
#
# 224/999
# tripla:  Asterix_(comicsCharacter) alternativeName "Astérix"
# actual:  Der alternative Name von Asterix (Comics-Charakter) ist "Astérix".
# predicted:  Asterix (komische Figur) hat den alternativen Namen Astérix.
#
#
# 225/999
# tripla:  A_Wizard_of_Mars language English_language English_language spokenIn Great_Britain
# actual:  Ein Zauberer von Mars ist auf Englisch geschrieben, das in Großbritannien gesprochen wird.
# predicted:  Ein Zauberer von Mars wurde auf Englisch geschrieben, das in Großbritannien gesprochen wird.
#
#
# 226/999
# tripla:  Christian_Panucci club Genoa_C.F.C. A.S._Livorno_Calcio manager Christian_Panucci
# actual:  A.s. Livorno Calcio wird von Christian Panucci verwaltet, der an den Club Genua CFC angeschlossen ist.
# predicted:  Christian Panucci spielte für Genoa C.F.C. und verwaltet A.S. Livorno Calcio.
#
#
# 227/999
# tripla:  Almond order Rosids
# actual:  Mandeln sind von der Bestellung ROSIDS.
# predicted:  Mandeln sind Teil der Ordnung der Rosids.
#
#
# 228/999
# tripla:  1_Decembrie_1918_University country Romania 1_Decembrie_1918_University latinName "Universitas Apulensis" Romania patronSaint Andrew_the_Apostle
# actual:  Universitas Apulensis ist der lateinische Name der 1 Decembrie 1918 Universität in Rumänien. Der Schutzpatron des Landes ist Andrew der Apostel.
# predicted:  Die 1 Decembrie 1918 Universität in Rumänien hat den lateinischen Namen Universitas Apulensis und der Schutzheilige des Landes ist Andrew der Apostel.
#
#
# 229/999
# tripla:  A.F.C._Fylde ground Warton,_Fylde
# actual:  Der Boden von AFC Fylde befindet sich in Warton, Fylde.
# predicted:  AFC Fylde Boden ist Warton, Fylde.
#
#
# 230/999
# tripla:  Asam_pedas creatorOfDish Padang_cuisine
# actual:  Padang Küche hat dazu geführt, dass das Gericht Asam pedas.
# predicted:  Padang ist die Heimat von Asam pedas.
#
#
# 231/999
# tripla:  Italy capital Rome Italy demonym Italians A.S._Gubbio_1910 ground Italy Italy leader Pietro_Grasso Italy officialLanguage Italian_language
# actual:  Der Boden von A.S. Gubbio 1910 befindet sich in Italien, dem Land, das von Italienern bewohnt wird. Die Hauptstadt von Italien ist Rom, die Amtssprache ist Italienisch und der Führer ist Pietro Grasso.
# predicted:  Der Boden von A.S. Gubbio 1910 befindet sich in Italien, wo die Hauptstadt Rom ist und die Italiener leben. Pietro Grasso ist der Führer von Italien, wo die Amtssprache Italienisch ist.
#
#
# 232/999
# tripla:  Akita,_Akita country Japan Japan ethnicGroup Brazilians_in_Japan Akita_Museum_of_Art location Akita_Prefecture Akita_Museum_of_Art location Akita,_Akita
# actual:  Japan, Heimat vieler Brasilianer, beherbergt auch das Akita Museum of Art, gegründet und befindet sich in der Präfektur Akita.
# predicted:  Das Akita Museum für Kunst befindet sich in Akita, Akita, Japan. Die Brasilianer sind eine ethnische Gruppe in Japan.
#
#
# 233/999
# tripla:  Bionico dishVariation Honey
# actual:  Honig kann als Variante im Gericht Bionico verwendet werden.
# predicted:  Bionico ist eine Variante von Honig.
#
#
# 234/999
# tripla:  AWH_Engineering_College academicStaffSize 250 AWH_Engineering_College country India AWH_Engineering_College established 2001
# actual:  AWH Engineering College wurde 2001 gegründet und befindet sich in Indien. Sie hat derzeit 250 Mitarbeiter.
# predicted:  Das AWH Engineering College in Indien wurde 2001 gegründet und hat 250 akademische Mitarbeiter.
#
#
# 235/999
# tripla:  Stuart_Parker_(footballer) club Chesterfield_F.C. Stuart_Parker_(footballer) club Drogheda_United_F.C. A.F.C._Blackpool manager Stuart_Parker_(footballer)
# actual:  Stuart Parker war Fußballer für Chesterfield FC und ist Fußballer mit der Drogheda United F.C, er hatte auch AFC Blackpool geschafft.
# predicted:  Stuart Parker ist der Manager von AFC Blackpool und spielt für Chesterfield F.C. Er ist auch bei Drogheda United F.C.
#
#
# 236/999
# tripla:  Egg_Harbor_Township,_New_Jersey country United_States Atlantic_City_International_Airport location Egg_Harbor_Township,_New_Jersey Atlantic_City_International_Airport runwayLength 1873.0
# actual:  Atlantic City International Airport befindet sich in Egg Harbor Township, New Jersey, USA. Seine Fahrbahnlänge beträgt 1873,0.
# predicted:  Atlantic City International Airport befindet sich in Egg Harbor Township, New Jersey, USA. Die Fahrbahnlänge beträgt 1873,0.
#
#
# 237/999
# tripla:  Cornell_University affiliation Association_of_American_Universities Administrative_Science_Quarterly publisher Cornell_University
# actual:  Neben der Verbindung mit dem Verband der amerikanischen Universitäten veröffentlicht die Cornell University Verwaltungswissenschaft Quarterly.
# predicted:  Die Cornell University ist mit dem Verband der amerikanischen Universitäten verbunden und ist Herausgeber der Verwaltungswissenschaft Quarterly.
#
#
# 238/999
# tripla:  Bolt_(comicsCharacter) alternativeName "Larry Bolatinsky" Bolt_(comicsCharacter) creator Paris_Cullins Bolt_(comicsCharacter) creator Ernie_Colón
# actual:  Larry Bolatinsky ist der alternative Name für die Comicfigur Bolt, der von Ernie Colon und Paris Cullins erschaffen wurde.
# predicted:  Die Comicfigur Bolt, auch bekannt als Larry Bolatinsky, wurde von Paris Cullins und Ernie Colon gegründet.
#
#
# 239/999
# tripla:  United_States_Air_Force transportAircraft Lockheed_C-130_Hercules
# actual:  Das Transportflugzeug für die United States Air Force ist die Lockheed C-130 Hercules.
# predicted:  Die Lockheed C-130 Hercules ist ein Transportflugzeug der United States Air Force.
#
#
# 240/999
# tripla:  20_Fenchurch_Street completionDate "April 2014" 20_Fenchurch_Street floorArea 62145.3 (square metres) 20_Fenchurch_Street floorCount 34
# actual:  20 Fenchurch Street, im April 2014 fertiggestellt, hat 34 Stockwerke und eine Bodenfläche von 62145,3 Quadratmetern.
# predicted:  20 Fenchurch Street wurde im April 2014 fertiggestellt und hat 34 Etagen und eine Grundfläche von 62145,3 Quadratmetern.
#
#
# 241/999
# tripla:  Batchoy country Philippines Philippines ethnicGroup Igorot_people Philippines ethnicGroup Chinese_Filipino Philippines language Philippine_Spanish
# actual:  Die Igorot-Leute und die chinesischen Filipinos sind beide ethnische Gruppen auf den Philippinen, wo die gesprochene Sprache Spanisch ist. Das Land ist der Ursprung des Gerichts, das als Batchoy bekannt ist.
# predicted:  Batchoy kommt von den Philippinen, wo philippinische Spanisch gesprochen wird und es eine ethnische Gruppe gibt, die Igorot Menschen und chinesische Filipinos.
#
#
# 242/999
# tripla:  A_Loyal_Character_Dancer mediaType "Print"
# actual:  Ein Loyal Character Dancer ist im Druck.
# predicted:  Ein Loyal Character Dancer ist in Print erhältlich.
#
#
# 243/999
# tripla:  Belgium language German_language
# actual:  Die Sprache, die gesprochen wird, ist Deutsch.
# predicted:  Die deutsche Sprache wird in Belgien gesprochen.
#
#
# 244/999
# tripla:  California_State_Assembly isPartOf California_State_Legislature
# actual:  Die kalifornische Staatsversammlung ist Teil der kalifornischen Staatskanzlei.
# predicted:  Die kalifornische Staatsversammlung ist Teil der kalifornischen Staatsgesetzgebung.
#
#
# 245/999
# tripla:  Sri_Lanka capital Sri_Jayawardenepura_Kotte Adisham_Hall country Sri_Lanka Sri_Lanka language Tamil_language Adisham_Hall location Haputale
# actual:  Tamil ist die Sprache, die in Sri Lanka gesprochen wird, dessen Hauptstadt Sri Jayawardenepura Kotte ist, auch in Sri Lanka ist die Adisham-Halle, die sich in Haputale befindet.
# predicted:  Adisham Hall befindet sich in Haputale, Sri Lanka, wo die Hauptstadt Sri Jayawardenepura Kotte ist und die tamilische Sprache gesprochen wird.
#
#
# 246/999
# tripla:  Ampara_Hospital bedCount 476 Ampara_Hospital country Sri_Lanka Ampara_Hospital state Eastern_Province,_Sri_Lanka
# actual:  Ampara Hospital hat 476 Betten und befindet sich in der östlichen Provinz, Sri Lanka.
# predicted:  Ampara Hospital befindet sich in der östlichen Provinz, Sri Lanka und hat 476 Betten.
#
#
# 247/999
# tripla:  Jens_Härtel club SV_Babelsberg_03
# actual:  Jens Hartel spielt für den SV Babelsberg 03.
# predicted:  Jens Hartel spielte für den SV Babelsberg 03.
#
#
# 248/999
# tripla:  Auron_(comicsCharacter) creator Karl_Kesel Auron_(comicsCharacter) creator Walt_Simonson Karl_Kesel nationality Americans
# actual:  Die Comicfigur Auron wurde von Walt Simonson und dem Amerikaner Karl Kesel ins Leben gerufen.
# predicted:  Die Comicfigur Auron wurde von Walt Simonson und dem Amerikaner Karl Kesel gegründet.
#
#
# 249/999
# tripla:  Bacon_Explosion country United_States United_States ethnicGroup Asian_Americans
# actual:  Asiatische Amerikaner sind eine ethnische Gruppe in den Vereinigten Staaten, wo Bacon Explosion kommt.
# predicted:  Bacon Explosion kommt aus den USA, wo asiatische Amerikaner eine ethnische Gruppe sind.
#
#
# 250/999
# tripla:  Baked_Alaska country France Baked_Alaska ingredient Sponge_cake Baked_Alaska region "Paris, New York or Hong Kong"
# actual:  Schwamm-Kuchen ist eine Zutat in Baked Alaska, die aus Frankreich, Paris, New York oder Hongkong kommt.
# predicted:  Gebackenes Alaska, das aus Frankreich kommt, enthält Biskuitkuchen und ist in Paris, New York und Hongkong beliebt.
#
#
# 251/999
# tripla:  250_Delaware_Avenue floorArea 30843.8 (square metres) 250_Delaware_Avenue floorCount 12
# actual:  250 Delaware Avenue hat eine Grundfläche von 30853,8 Quadratmetern und hat 12 Etagen.
# predicted:  250 Delaware Avenue hat 12 Etagen und eine Bodenfläche von 30843,8 Quadratmetern.
#
#
# 252/999
# tripla:  3Arena architect Populous_(company)
# actual:  Der Architekt der 3Arena war das Unternehmen bevölkerungsreich.
# predicted:  Die 3Arena wurde von der Firma Populous entworfen.
#
#
# 253/999
# tripla:  250_Delaware_Avenue floorArea 30843.8 (square metres) 250_Delaware_Avenue location Buffalo,_New_York
# actual:  250 Delaware Avenue befindet sich in Buffalo, New York, und hat eine Grundfläche von 30843,8 Quadratmetern.
# predicted:  250 Delaware Avenue befindet sich in Buffalo, New York und hat eine Grundfläche von 30843,8 Quadratmetern.
#
#
# 254/999
# tripla:  Alan_Shepard nationality United_States
# actual:  Alan Shepard stammt aus den USA.
# predicted:  Alan Shepard ist ein Amerikaner.
#
#
# 255/999
# tripla:  Bakewell_pudding dishVariation Bakewell_tart
# actual:  Bakewell tart ist eine Variante von Bakewell Pudding.
# predicted:  Bakewell Pudding ist eine Variante von Bakewell Tart.
#
#
# 256/999
# tripla:  Luciano_Spalletti club Udinese_Calcio Luciano_Spalletti club Empoli_F.C. Luciano_Spalletti club Virtus_Entella A.S._Roma manager Luciano_Spalletti
# actual:  Als Roma-Manager ist Luciano Spalletti, der für Udinese Calcio spielte. Er spielt für beide, Empoli F.C. Und Virtus Entella.
# predicted:  Luciano Spalletti ist der Manager von AS Roma und spielt für Udinese Calcio und Empoli F.C. Er ist auch im Virtus Entella Club.
#
#
# 257/999
# tripla:  Abilene_Regional_Airport cityServed Abilene,_Texas Abilene,_Texas country United_States Abilene,_Texas isPartOf Taylor_County,_Texas Abilene,_Texas isPartOf Jones_County,_Texas Abilene_Regional_Airport runwayLength 1121.0
# actual:  Abilene Regional Airport bedient die Stadt Abilene in Taylor County und auch Jones County, Texas, USA. Der Flughafen hat eine Fahrbahnlänge von 1121,0.
# predicted:  Abilene Regional Airport dient der Stadt Abilene, die Teil von Taylor County und Jones County in Texas, USA. Die Fahrbahnlänge beträgt 1121,0.
#
#
# 258/999
# tripla:  1_Decembrie_1918_University country Romania 1_Decembrie_1918_University latinName "Universitas Apulensis" 1_Decembrie_1918_University state Alba
# actual:  Der lateinische Name der 1 Decembrie 1918 Universität in Alba, Rumänien, ist Universitas Apulensis.
# predicted:  Die 1 Decembrie 1918 Universität befindet sich in Alba, Rumänien und hat den lateinischen Namen Universitas Apulensis.
#
#
# 259/999
# tripla:  Romania leaderTitle Prime_Minister_of_Romania
# actual:  Der Führer Rumäniens ist als Ministerpräsident bekannt.
# predicted:  Der Premierminister von Rumänien ist der Führer des Landes.
#
#
# 260/999
# tripla:  Batchoy country Philippines Philippines ethnicGroup Zamboangans Philippines ethnicGroup Igorot_people Philippines language Arabic Philippines language Philippine_Spanish
# actual:  Batchoy stammt von den Philippinen. Die Philippinen sind auch die Heimat der Igorot und Zamboangans Menschen und hat die arabischen und philippinischen spanischen Sprachen.
# predicted:  Batchoy kommt von den Philippinen, wo die Sprache philippinische Spanisch und Arabisch gesprochen wird. Die ethnischen Gruppen sind die Zamboangans und die Igorot-Menschen.
#
#
# 261/999
# tripla:  Singapore language English_language
# actual:  Die englische Sprache wird in Singapur gesprochen.
# predicted:  Englisch ist die Sprache, die in Singapur gesprochen wird.
#
#
# 262/999
# tripla:  A.D._Isidro_Metapán ground "Metapán, El Salvador" A.D._Isidro_Metapán numberOfMembers 10000
# actual:  Mit 10000 Mitgliedern, AD Isidro Metapán Gelände befindet sich in Metapán, El Salvador.
# predicted:  A.D. Isidro Metapan hat 10000 Mitglieder und hat seinen Boden in Metapan, El Salvador.
#
#
# 263/999
# tripla:  Ayam_penyet country Java Java ethnicGroup Banyumasan_people Ayam_penyet region Singapore
# actual:  Ayam Penyet, ein Gericht aus Singapur, findet sich auch in Java. Die Banyumasan Menschen sind eine ethnische Gruppe in Java.
# predicted:  Ayam Penyet ist ein Gericht aus Singapur und Java, wo die Banyumasan Menschen eine ethnische Gruppe sind.
#
#
# 264/999
# tripla:  Dane_Whitman_Black_Knight_(comicsCharacter) alternativeName "Dane Whitman" Dane_Whitman_Black_Knight_(comicsCharacter) creator Roy_Thomas
# actual:  Dane Whitman ist der alternative Name für den komischen Charakter, Dane Whitman Black Knight, der von Roy Thomas erschaffen wurde.
# predicted:  Dane Whitman, auch bekannt als Dane Whitman, ist eine komische Figur, die von Roy Thomas geschaffen wurde.
#
#
# 265/999
# tripla:  Jens_Härtel club FC_Sachsen_Leipzig 1._FC_Magdeburg manager Jens_Härtel
# actual:  Der Manager des FC Magdeburg ist Jens Härtel, der den Verein FC Sachsen Leipzig vertreten hat.
# predicted:  Jens Härtel ist Manager des 1. FC Magdeburg und spielt für den FC Sachsen Leipzig.
#
#
# 266/999
# tripla:  A.F.C._Blackpool ground "The Mechanics," A.F.C._Blackpool numberOfMembers 1500
# actual:  A.F.C. Blackpools Spielbereich ist The Mechanics. Sie hat 1500 Mitglieder.
# predicted:  AFC Blackpool hat 1500 Mitglieder und ihr Boden ist The Mechanics.
#
#
# 267/999
# tripla:  Acharya_Institute_of_Technology affiliation Visvesvaraya_Technological_University Visvesvaraya_Technological_University city Belgaum Acharya_Institute_of_Technology country "India" Acharya_Institute_of_Technology numberOfPostgraduateStudents 700
# actual:  Das Acharya Institute of Technology befindet sich in Indien und hat 700 Doktoranden. Es ist mit der Visvesvaraya Technological University in Belgaum verbunden.
# predicted:  Das Acharya Institute of Technology in Indien hat 700 postgraduierte Studenten und ist mit der Visvesvaraya Technological University in Belgaum verbunden.
#
#
# 268/999
# tripla:  William_Anders birthDate "1933-10-17" William_Anders birthPlace British_Hong_Kong William_Anders dateOfRetirement "1969-09-01"
# actual:  William Anders ging am 1. September 1969 in den Ruhestand, nachdem er am 17. Oktober 1933 im britischen Hongkong geboren wurde.
# predicted:  William Anders wurde am 17. Oktober 1933 im britischen Hongkong geboren. Er ging am 1. September 1969 in den Ruhestand.
#
#
# 269/999
# tripla:  Ayam_penyet country Java Java ethnicGroup Baduy
# actual:  Ayam Penyet ist ein Lebensmittel, das in Java gefunden wird, wo eine ethnische Gruppe Baduy ist.
# predicted:  Ayam Penyet ist ein Gericht aus Java, wo Baduy eine ethnische Gruppe ist.
#
#
# 270/999
# tripla:  Adirondack_Regional_Airport cityServed Lake_Placid,_New_York Adirondack_Regional_Airport cityServed Saranac_Lake,_New_York Saranac_Lake,_New_York country United_States Saranac_Lake,_New_York isPartOf Harrietstown,_New_York Lake_Placid,_New_York isPartOf Essex_County,_New_York
# actual:  Adirondack Regional Airport dient der Stadt Lake Placid, Essex County, New York, und auch Saranac Lake (Teil von Harrietstown) New York, USA.
# predicted:  Adirondack Regional Airport dient der Stadt Lake Placid, New York, USA. Lake Placid ist Teil von Harrietstown, New York.
#
#
# 271/999
# tripla:  United_States capital Washington,_D.C.
# actual:  Washington, D.C ist die Hauptstadt der Vereinigten Staaten.
# predicted:  Washington DC ist die Hauptstadt der Vereinigten Staaten.
#
#
# 272/999
# tripla:  Buzz_Aldrin birthDate "1930-01-20"
# actual:  Buzz Aldrin Geburtsdatum ist der 20. Januar 1930.
# predicted:  Buzz Aldrin wurde am 20. Januar 1930 geboren.
#
#
# 273/999
# tripla:  A.S._Gubbio_1910 ground Stadio_Pietro_Barbetti
# actual:  Der Boden des AS Gubbio 1910 heißt Stadio Pietro Barbetti.
# predicted:  A.s. Gubbio 1910 Boden ist Stadio Pietro Betti.
#
#
# 274/999
# tripla:  Amsterdam_Airport_Schiphol runwayLength 3300.0
# actual:  Die Fahrbahnlänge des Amsterdamer Flughafens Schiphol beträgt 3300,0.
# predicted:  Die Fahrbahnlänge des Amsterdamer Flughafens Schiphol beträgt 3300,0.
#
#
# 275/999
# tripla:  John_van_den_Brom club İstanbulspor_A.Ş. AZ_Alkmaar manager John_van_den_Brom
# actual:  John van den Brom, der die AZ Alkmaair verwaltet, spielt für Istanulspor A.S.
# predicted:  John van den Brom ist der Manager von AZ Alkmaar und spielt für Istanbulspor A..
#
#
# 276/999
# tripla:  AFC_Ajax_(amateurs) numberOfMembers 5000
# actual:  AFC Ajax (Amateure) hat 5000 Mitglieder.
# predicted:  AFC Ajax (Amateure) hat 5000 Mitglieder.
#
#
# 277/999
# tripla:  Jack_Kirby nationality Americans
# actual:  Jack Kirby ist ein Amerikaner.
# predicted:  Jack Kirby ist ein Amerikaner.
#
#
# 278/999
# tripla:  Asam_pedas region Malay_Peninsula
# actual:  ASAM pedas hadert von der malaiischen Halbinsel.
# predicted:  ASAM pedas ist ein Gericht aus der malaiischen Halbinsel.
#
#
# 279/999
# tripla:  A_Wizard_of_Mars mediaType Hardcover
# actual:  Ein Zauberer von Mars wird in Hardcover veröffentlicht.
# predicted:  Ein Zauberer von Mars ist in Hardcover erhältlich.
#
#
# 280/999
# tripla:  Amatriciana_sauce country Italy Italy language Italian_language
# actual:  Italien ist das Land Amatriciana Sauce kommt und ist, wo die italienische Sprache gesprochen wird.
# predicted:  Amatriciana Sauce stammt aus Italien, wo die italienische Sprache gesprochen wird.
#
#
# 281/999
# tripla:  Texas capital Austin,_Texas Texas country United_States Texas language English_language Texas largestCity Houston Andrews_County_Airport location Texas
# actual:  Andrews County Airport befindet sich in Texas in den USA @ Austin ist die Hauptstadt von Texas, dessen größte Stadt Houston ist. In diesem Staat wird Englisch gesprochen.
# predicted:  Andrews County Airport befindet sich in Texas, USA, wo die englische Sprache gesprochen wird und die Hauptstadt Austin ist. Houston ist die größte Stadt in Texas.
#
#
# 282/999
# tripla:  Blockbuster_(comicsCharacter) creator Carmine_Infantino
# actual:  Der Schöpfer von Blockbuster (Comics-Charakter) ist Carmine Infantino.
# predicted:  Die Comicfigur Blockbuster wurde von Carmine Infantino ins Leben gerufen.
#
#
# 283/999
# tripla:  Appleton_International_Airport cityServed Appleton,_Wisconsin Greenville,_Wisconsin isPartOf Grand_Chute,_Wisconsin Greenville,_Wisconsin isPartOf Ellington,_Wisconsin Appleton_International_Airport location Greenville,_Wisconsin
# actual:  The Appleton International Airport is located in and services Greenville, Wisconsin. Grand Chute und Ellington gehören zu Wisconsin.
# predicted:  Appleton International Airport befindet sich in Greenville, Wisconsin, Teil von Grand Chute und Ellington.
#
#
# 284/999
# tripla:  Albany,_Oregon areaTotal 45.97 (square kilometres)
# actual:  Die Gesamtfläche von Albany Oregon ist 45,97 Sq K.
# predicted:  Albany, Oregon hat eine Gesamtfläche von 45,97 Quadratkilometern.
#
#
# 285/999
# tripla:  Asam_pedas country Malaysia Malaysia ethnicGroup Malaysian_Malay Sumatra ethnicGroup Acehnese_people Asam_pedas region Sumatra
# actual:  ASAM peda ist ein Gericht aus Sumatra, wo die Acehnesen eine ethnische Gruppe sind. Es findet sich auch in Malaysia, wo die Malaien eine ethnische Gruppe sind.
# predicted:  ASAM pedas ist ein Gericht aus Sumatra, Malaysia. Acehnese sind eine ethnische Gruppe in Sumatra und Malaysia.
#
#
# 286/999
# tripla:  Arem-arem country Indonesia
# actual:  Arem-arem ist ein Lebensmittel, das in Indonesien gefunden wird.
# predicted:  Arem-arem ist ein Gericht aus Indonesien.
#
#
# 287/999
# tripla:  United_States capital Washington,_D.C. 1634:_The_Ram_Rebellion country United_States United_States ethnicGroup Native_Americans_in_the_United_States
# actual:  Die Indianer sind eine ethnische Gruppe in den USA, wo die Hauptstadt Washington DC und 1634 The Ram Rebellion geschrieben wurde.
# predicted:  1634 Die Ram Rebellion wurde in den Vereinigten Staaten geschrieben, wo die Hauptstadt Washington DC ist und die Indianer eine ethnische Gruppe sind.
#
#
# 288/999
# tripla:  Asilomar_Conference_Grounds architect Julia_Morgan Julia_Morgan birthPlace California Julia_Morgan significantBuilding Chinatown,_San_Francisco Julia_Morgan significantBuilding Asilomar_State_Beach Julia_Morgan significantProject Hearst_Castle
# actual:  Die Architektin Julia Morgan, die in Kalifornien geboren wurde, entwarf viele bedeutende Gebäude, darunter das Gelände der Asilomar Konferenz, das Wahrzeichen Hearst Castle, Asilomar State Beach und die Gebäude von Chinatown in San Francisco.
# predicted:  Julia Morgan wurde in Kalifornien geboren und entwarf bedeutende Gebäude in Chinatown, San Francisco und Asilomar State Beach. Sie war auch der Architekt des Hearst Castle.
#
#
# 289/999
# tripla:  Marriott_International foundationPlace Washington,_D.C. Denmark language Faroese_language AC_Hotel_Bella_Sky_Copenhagen location Denmark AC_Hotel_Bella_Sky_Copenhagen tenant Marriott_International
# actual:  Der Mieter des AC Hotel Bella Sky Copenhagen, Dänemark ist das Marriott International Hotel, ein Unternehmen, das in Washington D.C. gegründet wurde. Die Sprache färöisch wird in Dänemark gesprochen.
# predicted:  Marriott International wurde in Washington DC gegründet und ist der Mieter des AC Hotel Bella Sky in Kopenhagen, Dänemark. Die färöische Sprache wird in Dänemark gesprochen.
#
#
# 290/999
# tripla:  St._Vincent–St._Mary_High_School city Akron,_Ohio Akron,_Ohio country United_States Akron_Summit_Assault ground St._Vincent–St._Mary_High_School
# actual:  Akron Summit Assault 's ground is St. Vincent-St. Mary High School, Akron, Ohio, USA.
# predicted:  Akron Summit Assault's ground is St. Vincent-St. Mary High School in Akron, Ohio, USA.
#
#
# 291/999
# tripla:  Adisham_Hall architecturalStyle "Tudor and Jacabian" Adisham_Hall location Haputale
# actual:  The architecture style of adisham hall of Haputale, is Tudor and jacabian.
# predicted:  Adisham Hall befindet sich in Haputale und hat den architektonischen Stil von Tudor und Jacabian.
#
#
# 292/999
# tripla:  A_Fortress_of_Grey_Ice country United_States United_States ethnicGroup Asian_Americans United_States leaderTitle President_of_the_United_States
# actual:  Eine Festung von Grey Ice stammt aus den USA, die vom Präsidenten geleitet wird und die ethnische Gruppe der asiatischen Amerikaner umfasst.
# predicted:  Eine Festung von Grey Ice stammt aus den USA, wo der Führer als Präsident bekannt ist und asiatische Amerikaner eine ethnische Gruppe sind.
#
#
# 293/999
# tripla:  200_Public_Square completionDate 1985 200_Public_Square floorCount 45 200_Public_Square location Cleveland
# actual:  200 öffentlicher Platz, der 45 Etagen hat, wurde 1985 in Cleveland fertiggestellt.
# predicted:  200 öffentlicher Platz, Cleveland, wurde 1985 fertiggestellt und hat 45 Etagen.
#
#
# 294/999
# tripla:  Appleton_International_Airport cityServed Appleton,_Wisconsin Greenville,_Wisconsin country United_States Greenville,_Wisconsin isPartOf Ellington,_Wisconsin Greenville,_Wisconsin isPartOf Dale,_Wisconsin Appleton_International_Airport location Greenville,_Wisconsin
# actual:  Appleton, Wisconsin ist eine Stadt in den USA, die vom internationalen Flughafen Appleton bedient wird. Der Flughafen befindet sich in Greenville, Wisconsin, das Teil von Dale und Ellington ist.
# predicted:  Appleton International Airport befindet sich in Greenville, Wisconsin, USA. Greenville ist Teil von Ellington und Dale.
#
#
# 295/999
# tripla:  Bananaman broadcastedBy BBC Bananaman creator Steve_Bright Bananaman firstAired "1983-10-03" Bananaman lastAired "1986-04-15" Bananaman starring Graeme_Garden
# actual:  Bananaman wurde zuerst auf der BBC 10 / 03 / 1983 ausgestrahlt und seine letzte Sendung war der 15. April 1986. Der Schöpfer von Bananaman ist Steve Bright und die Showstars Graeme Garden.
# predicted:  Bananaman wurde am 3. Oktober 1983 erstmals ausgestrahlt und am 15. April 1986 von der BBC ausgestrahlt. Es wurde von Steve Bright erstellt und spielte Graeme Garden.
#
#
# 296/999
# tripla:  Alan_B._Miller_Hall architect Robert_A._M._Stern Virginia country United_States Alan_B._Miller_Hall currentTenants Mason_School_of_Business Alan_B._Miller_Hall location Virginia Alan_B._Miller_Hall owner College_of_William_&_Mary
# actual:  Alan B. Miller Hall, entworfen von Robert A M Stern, befindet sich in Virginia, USA. Die Halle befindet sich im Besitz des Kollegiums von William und Mary, und sein aktueller Mieter ist die Mason School of Business.
# predicted:  Die Mason School of Business sind die aktuellen Mieter von Alan B Miller Hall, Virginia, USA, das im Besitz des Kollegiums von William und Mary ist. Der Architekt von Alan B Miller Hall war Robert A M Stern.
#
#
# 297/999
# tripla:  A.C._Cesena ground Cesena A.C._Cesena league Serie_B A.C._Cesena numberOfMembers 23900
# actual:  A.C. Cesena, mit 23900 Mitgliedern, ist in der Serie B Liga und hat einen Boden in Cesena.
# predicted:  A.C. Cesena Boden ist in Cesena und sie haben 23900 Mitglieder. Sie spielen in der Serie B Liga.
#
#
# 298/999
# tripla:  Adolfo_Suárez_Madrid–Barajas_Airport location "Madrid, Paracuellos de Jarama, San Sebastián de los Reyes and Alcobendas" Adolfo_Suárez_Madrid–Barajas_Airport runwayLength 4349.0
# actual:  Adolfo Suárez Madrid-Barajas Airport (in Madrid, Paracuellos de Jarama, San Sebastián de los Reyes und Alcobendas) hat eine Landebahn, die 4349 Meter lang ist.
# predicted:  Der Flughafen Adolfo Suárez Madrid-Barajas befindet sich in Madrid, Paracuellos de Jarama, San Sebastián de los Reyes und Alcobendas und hat eine Fahrbahnlänge von 4349,0.
#
#
# 299/999
# tripla:  Allama_Iqbal_International_Airport cityServed Lahore Allama_Iqbal_International_Airport location Pakistan Allama_Iqbal_International_Airport operatingOrganisation Pakistan_Civil_Aviation_Authority Allama_Iqbal_International_Airport runwayLength 3360.12 Allama_Iqbal_International_Airport runwayName "18L/36R"
# ...
#
#
# 956/999
# tripla:  Antioquia_Department country Colombia Bandeja_paisa ingredient Avocado Bandeja_paisa region Antioquia_Department
# actual:  Avocado ist eine der Zutaten in der Schüssel bandeja paisa findet sich in der Antioquia Department of Columbia.
# predicted:  Avocado ist eine Zutat in bandeja paisa, die aus der Antioquia-Abteilung in Kolumbien stammt.
#
#
# 957/999
# tripla:  Alan_Bean birthPlace Wheeler,_Texas Alan_Bean nationality United_States Alan_Bean occupation Test_pilot
# actual:  Alan Bean, ein US-Nationalspieler, dessen Geburtsort ist Wheeler, Texas, diente als Testpilot.
# predicted:  Alan Bean ist ein US-amerikanischer Testpilot, der in Wheeler, Texas, geboren wurde.
#
#
# 958/999
# tripla:  Amsterdam_Airport_Schiphol runwayName "18C/36C 'Zwanenburgbaan'"
# actual:  18C / 36C oder Zwanenburgbaan sind die Namen für die Piste am Amsterdamer Flughafen Schiphol.
# predicted:  Der Fahrbahnname am Amsterdamer Flughafen Schiphol ist 18C / 36C 'Zwanenburgbaan.
#
#
# 959/999
# tripla:  A_Glastonbury_Romance author John_Cowper_Powys John_Cowper_Powys birthPlace Shirley,_Derbyshire Weymouth_Sands followedBy Maiden_Castle_(novel) A_Glastonbury_Romance followedBy Weymouth_Sands
# actual:  Der Autor von A Glastonbury Romance ist John Cowper Powys, der in Shirley, Derbyshire geboren wurde. Einem Glastonbury-Romance folgte Weymouth Sands, dem dann die Burg Maiden folgte.
# predicted:  John Cowper Powys wurde in Shirley, Derbyshire geboren und schrieb A Glastonbury Romance, gefolgt von Weymouth Sands und Maiden Castle.
#
#
# 960/999
# tripla:  Ayam_penyet country Indonesia Ayam_penyet ingredient Fried_chicken
# actual:  Gebratenes Huhn ist eine Zutat im Gericht Ayam Penyet, das aus Indonesien stammt.
# predicted:  Gebratenes Huhn ist eine Zutat in Ayam Penyet, die aus Indonesien kommt.
#
#
# 961/999
# tripla:  Amatriciana_sauce country Italy
# actual:  Amatriciana Sauce ist in Italien zu finden.
# predicted:  Amatriciana Sauce stammt aus Italien.
#
#
# 962/999
# tripla:  A_Fortress_of_Grey_Ice country United_States United_States ethnicGroup African_Americans A_Fortress_of_Grey_Ice language English_language
# actual:  Eine Festung von Grey Ice ist in der englischen Sprache geschrieben. Sie stammt aus den USA, wo eine der ethnischen Gruppen afrikanische Amerikaner ist.
# predicted:  Eine Festung von Grey Ice stammt aus den USA, wo afrikanische Amerikaner eine ethnische Gruppe sind. Es ist auf Englisch geschrieben.
#
#
# 963/999
# tripla:  Bibbo_Bibbowski creator Jerry_Ordway Bibbo_Bibbowski creator Marv_Wolfman Jerry_Ordway nationality Americans
# actual:  Bibbo Bibbowski wurde von Marv Wolfman und Jerry Ordway geschaffen, der ein Amerikaner ist.
# predicted:  Marv Wolfman und Jerry Ordway sind Amerikaner, die Bibbo Bibbowski schufen.
#
#
# 964/999
# tripla:  Al_Asad_Airbase location Iraq Al_Asad_Airbase operatingOrganisation United_States_Air_Force Al_Asad_Airbase runwayLength 3990.0 Al_Asad_Airbase runwayName "09L/27R"
# actual:  Die United States Air Force ist die Betriebsorganisation für den Luftwaffenstützpunkt Al Asad im Irak. Der Fahrbahnname der Luftwaffenbasis heißt 09L / 27R und ist 3.990 lang.
# predicted:  Die United States Air Force ist die Betriebsorganisation für die Al Asad Airbase im Irak, die eine Fahrbahnlänge von 3990,0 hat. Der Name der Piste ist 09L / 27R.
#
#
# 965/999
# tripla:  Akron_Summit_Assault manager Denzil_Antonio Akron_Summit_Assault numberOfMembers 3000
# actual:  Denzil Antonio ist der Manager von Akron Summit Assault, der 3000 Mitglieder hat.
# predicted:  Denzil Antonio ist der Manager von Akron Summit Assault, der 3000 Mitglieder hat.
#
#
# 966/999
# tripla:  Bacon_sandwich alternativeName "Bacon butty, bacon sarnie, rasher sandwich, bacon sanger, piece 'n bacon, bacon cob, bacon barm, bacon muffin" Bacon_sandwich country United_Kingdom Bacon_sandwich ingredient Bacon
# actual:  Ein Speck mit Speck und Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck, Speck
# predicted:  Speck-Sandwich, auch bekannt als Speck butty, Speck sarnie, rasher Sandwich, Speck Sanger, Stück 'n Speck, Speck cob, Speck barm, Speck Muffin, ist ein Gericht aus dem Vereinigten Königreich.
#
#
# 967/999
# tripla:  Amatriciana_sauce country Italy Amatriciana_sauce ingredient Guanciale
# actual:  Guanciale ist eine Zutat in der traditionellen italienischen Amatriciana Sauce.
# predicted:  Guanciale ist eine Zutat in Amatriciana Sauce, die aus Italien stammt.
#
#
# 968/999
# tripla:  AWH_Engineering_College academicStaffSize 250 AWH_Engineering_College country India India largestCity Mumbai India river Ganges
# actual:  Das AWH Engineering College (Indien) hat 250 Mitarbeiter. Die größte Stadt Indiens ist Mumbai und einer der Flüsse des Landes ist der Ganges.
# predicted:  Das AWH Engineering College in Indien hat 250 akademische Mitarbeiter. Die größte Stadt des Landes ist Mumbai und der Ganges ist ein Fluss in Indien.
#
#
# 969/999
# tripla:  Luciano_Spalletti club Virtus_Entella
# actual:  Luciano Spalletti spielt für Virtus Entella.
# predicted:  Luciano Spalletti spielt für Virtus Entella.
#
#
# 970/999
# tripla:  1634:_The_Bavarian_Crisis author Eric_Flint Eric_Flint birthPlace Burbank,_California 1634:_The_Bavarian_Crisis precededBy The_Grantville_Gazettes
# actual:  Eric Flint, geboren in Burbank, Kalifornien, ist der Autor von 1634: Die bayerische Krise, die den Grantville Gazetten folgt.
# predicted:  Eric Flint wurde in Burbank, Kalifornien geboren und schrieb 1634: Die bayerische Krise, die den Grantville Gazetten vorausgegangen war.
#
#
# 971/999
# tripla:  Ajoblanco alternativeName "Ajo blanco" Ajoblanco country Spain Ajoblanco ingredient Bread
# actual:  Ajoblanco, auch bekannt als "Ajo blanco", kommt aus Spanien. Brot ist eine der Zutaten.
# predicted:  Ajoblanco, auch bekannt als Ajo blanco, stammt aus Spanien und enthält Brot.
#
#
# 972/999
# tripla:  Adisham_Hall architecturalStyle Tudor_Revival_architecture Adisham_Hall buildingStartDate "1927" Adisham_Hall completionDate 1931 Adisham_Hall location Sri_Lanka
# actual:  Das architektonisch gestaltete "Tudor Revival" Adisham Hall befindet sich in Sri Lanka und wurde 1927 erbaut und 1931 fertiggestellt.
# predicted:  Adisham Hall befindet sich in Sri Lanka und wurde 1927 begonnen und 1931 fertiggestellt. Der Tudor Revival-Stil der Architektur ist der Baubeginn.
#
#
# 973/999
# tripla:  Bacon_sandwich country United_Kingdom Bacon_sandwich dishVariation BLT Bacon_sandwich ingredient Condiment
# actual:  Das britische Gericht, das Speck-Sandwich verwendet Klimaanlagen als Zutat und hat die Variante BLT.
# predicted:  Das Vereinigte Königreich ist der Ursprung des Speck-Sandwich, das eine Variante des BLT ist.
#
#
# 974/999
# tripla:  A_Wizard_of_Mars publisher Harcourt_(publisher)
# actual:  Harcourt ist Herausgeber von A Wizard of Mars.
# predicted:  Ein Zauberer von Mars wurde von Harcourt veröffentlicht.
#
#
# 975/999
# tripla:  Bananaman broadcastedBy "STV" Bananaman firstAired "1983-10-03" Bananaman starring Bill_Oddie
# actual:  Bill Oddie spielte in Bananaman, die erstmals am 3. Oktober 1983 ausgestrahlt wurde und vom STV ausgestrahlt wurde.
# predicted:  Bananaman wurde erstmals am 3. Oktober 1983 ausgestrahlt und spielte Bill Oddie. Es wurde vom STV ausgestrahlt.
#
#
# 976/999
# tripla:  National_League_North champions Barrow_A.F.C. A.F.C._Fylde league National_League_North
# actual:  Fylde spielte in der Landesliga Nord, von denen Barrow AFC der Meister ist.
# predicted:  Barrow AFC sind Meister der National League North, in der AFC Fylde spielen.
#
#
# 977/999
# tripla:  William_Anders birthDate "1933-10-17" William_Anders birthPlace British_Hong_Kong William_Anders dateOfRetirement "1969-09-01" William_Anders nationality United_States
# actual:  William Anders ist ein US-Staatsangehöriger, der am 17. Oktober 1933 im britischen Hongkong geboren wurde und am 1. Januar 1969 in den Ruhestand ging.
# predicted:  William Anders wurde am 17. Oktober 1933 im britischen Hongkong geboren. Er ist ein Amerikaner, der am 1. September 1969 in den Ruhestand ging.
#
#
# 978/999
# tripla:  Akita_Museum_of_Art floorArea 3746.66 (square metres) Akita_Museum_of_Art floorCount 3 Akita_Museum_of_Art inaugurationDate "2013-09-28"
# actual:  Das Akita Museum of Art, das am 28. September 2013 eingeweiht wurde, hat 3 Etagen und eine Bodenfläche von 3746,66 Quadratmetern.
# predicted:  Das Akita Museum für Kunst hat 3 Etagen und eine Bodenfläche von 3746,66 Quadratmetern. Es wurde am 28. September 2013 eingeweiht.
#
#
# 979/999
# tripla:  Denmark language German_language
# actual:  Eine der in Dänemark verwendeten Sprachen ist die deutsche Sprache.
# predicted:  Dänemark spricht Deutsch.
#
#
# 980/999
# tripla:  Allama_Iqbal_International_Airport location Pakistan Allama_Iqbal_International_Airport runwayLength 3360.12 Allama_Iqbal_International_Airport runwayName "18L/36R"
# actual:  Der internationale Flughafen Allama Iqbal, der sich in Pakistan befindet, hat eine Fahrbahnlänge von 3360.12. Der Fahrbahnname ist 18L / 36R.
# predicted:  Der internationale Flughafen Allama Iqbal befindet sich in Pakistan und hat eine Fahrbahnlänge von 3360,12 Metern. Der Fahrbahnname ist 18L / 36R.
#
#
# 981/999
# tripla:  3Arena location North_Wall,_Dublin 3Arena owner Live_Nation_Entertainment
# actual:  3Arena befindet sich in North Wall, Dublin und befindet sich im Besitz von Live Nation Entertainment.
# predicted:  3Arena befindet sich am Nordwall, Dublin und ist im Besitz von Live Nation Entertainment.
#
#
# 982/999
# tripla:  Baked_Alaska country United_States United_States ethnicGroup African_Americans United_States leaderTitle President_of_the_United_States
# actual:  Der Präsident ist der Führer der USA Eine Ethik-Gruppe gibt es afrikanische Amerikaner. Das Dessert, Baked Alaska, stammt aus den USA.
# predicted:  Gebackene Alaska stammt aus den USA, wo der Führer als Präsident bekannt ist und afrikanische Amerikaner eine ethnische Gruppe sind.
#
#
# 983/999
# tripla:  Virginia country United_States Alan_B._Miller_Hall currentTenants Mason_School_of_Business Alan_B._Miller_Hall location Virginia Alan_B._Miller_Hall owner College_of_William_&_Mary
# actual:  Alan B. Miller Hall is situated in Virginia, United States and is owned by the College of William and Mary. Die Mason School of Business sind die aktuellen Mieter.
# predicted:  Die Mason School of Business sind die aktuellen Mieter von Alan B Miller Hall, Virginia, USA, die im Besitz des Kollegiums von William und Mary ist.
#
#
# 984/999
# tripla:  Adisham_Hall address "St. Benedict's Monastery, Adisham, Haputhale, Sri Lanka" Adisham_Hall architecturalStyle Tudor_Revival_architecture Adisham_Hall buildingStartDate "1927" Adisham_Hall completionDate 1931 Adisham_Hall location Sri_Lanka
# actual:  Adisham Hall wurde zwischen 1927 und 1931 im Tudor Revival Stil errichtet. Es befindet sich im Kloster St. Benedikt, Adisham, Haputhale, Sri Lanka.
# predicted:  Adisham Hall befindet sich in Sri Lanka, St. Benedikt's Kloster, Adisham, Haputhale. Es wurde 1927 begonnen und 1931 fertiggestellt.
#
#
# 985/999
# tripla:  United_States leaderTitle President_of_the_United_States
# actual:  Der Titel des Regierungschefs der USA ist Präsident der USA.
# predicted:  Der Führer der Vereinigten Staaten hat den Titel des Präsidenten.
#
#
# 986/999
# tripla:  Bandeja_paisa country Colombian_cuisine Bandeja_paisa ingredient Fried_egg
# actual:  Gebratenes Ei ist eine Zutat von bandeja paisa, die ein Gericht aus der kolumbianischen Küche ist.
# predicted:  Bandeja paisa ist ein Gericht aus Kolumbien und enthält gebratenes Ei.
#
#
# 987/999
# tripla:  Auburn,_Washington populationDensity 914.8 (inhabitants per square kilometre)
# actual:  Die Bevölkerungsdichte von Auburn (Washington) beträgt 914,8 Einwohner pro Quadratkilometer.
# predicted:  Die Bevölkerungsdichte von Auburn, Washington beträgt 911,8 Einwohner pro Quadratkilometer.
#
#
# 988/999
# tripla:  Asam_pedas country Malaysia Malaysia ethnicGroup Malaysian_Malay Sumatra ethnicGroup Minangkabau_people Asam_pedas region Sumatra
# actual:  ASAM pedas ist ein Lebensmittel in Malaysia und Sumatra. Malaysian Malay ist eine ethnische Gruppe in Malaysia und Sumatra hat eine ethnische Gruppe namens Minangkabau Menschen.
# predicted:  ASAM pedas ist ein Lebensmittel in Sumatra, Malaysia, wo die malaysischen Malaien eine ethnische Gruppe sind.
#
#
# 989/999
# tripla:  AZAL_Arena location Azerbaijan
# actual:  Die Azal-Arena ist in Aserbaidschan.
# predicted:  Azal Arena befindet sich in Aserbaidschan.
#
#
# 990/999
# tripla:  Alan_B._Miller_Hall architecturalStyle Georgian_architecture Alan_B._Miller_Hall location Williamsburg,_Virginia Alan_B._Miller_Hall owner College_of_William_&_Mary
# actual:  Das College von William und Mary ist der Besitzer der georgianischen Alan B. Miller Hall in Virginia.
# predicted:  Alan B Miller Hall befindet sich in Williamsburg, Virginia und ist im Besitz des Kollegiums von William und Mary. Es ist im georgianischen Stil gebaut.
#
#
# 991/999
# tripla:  Bandeja_paisa country Colombian_cuisine Bandeja_paisa ingredient Hogao Bandeja_paisa region Antioquia_Department
# actual:  Bandeja paisa ist ein Gericht aus der Region Antioquia, Kolumbien und eine seiner Zutaten ist Hogao.
# predicted:  Hogao ist eine Zutat in bandeja paisa, die aus der Antioquia-Abteilung in Kolumbien stammt.
#
#
# 992/999
# tripla:  Asterix_(comicsCharacter) alternativeName "Astérix" Asterix_(comicsCharacter) creator René_Goscinny Asterix_(comicsCharacter) creator Albert_Uderzo
# actual:  Asterix die komische Figur, deren alternativer Name Asterix von Albert Uderzo und Rene Goscinny geschaffen wurde.
# predicted:  Die Comicfigur Asterix, auch bekannt als Astérix, wurde von Rene Goscinny und Albert Uderzo gegründet.
#
#
# 993/999
# tripla:  Gus_Poyet club Real_Zaragoza AEK_Athens_F.C. manager Gus_Poyet
# actual:  AEK Athen F.C. Manager ist Gus Poyet, der mit dem Real Zaragoza, einem Fußballverein, in Verbindung gebracht wird.
# predicted:  Gus Poyet spielte für Real Zaragoza und verwaltet AEK Athen F.C.
#
#
# 994/999
# tripla:  1634:_The_Bavarian_Crisis author "Virginia DeMarce and Eric Flint" 1634:_The_Bavarian_Crisis precededBy Grantville_Gazette_II Grantville_Gazette_II precededBy The_Grantville_Gazette
# actual:  Verfasst von Virginia DeMarce und Eric Flint, 1634: Der bayerischen Krise ging Grantville Gazette II voraus, die wiederum der "Grantville Gazette" vorausging.
# predicted:  1634: Die bayerische Krise wurde von Virginia DeMarce und Eric Flint geschrieben und ging auf Grantville Gazette II voraus.
#
#
# 995/999
# tripla:  300_North_LaSalle floorCount 60
# actual:  300 North LaSalle hat 60 Etagen.
# predicted:  300 North LaSalle hat 60 Etagen.
#
#
# 996/999
# tripla:  United_States leader Joe_Biden
# actual:  Joe Biden war ein Vertreter der USA.
# predicted:  Joe Biden ist der Führer der Vereinigten Staaten.
#
#
# 997/999
# tripla:  United_States leaderTitle President_of_the_United_States
# actual:  Der Titel des Regierungschefs der USA ist Präsident der USA.
# predicted:  Der Führer der Vereinigten Staaten hat den Titel des Präsidenten.
#
#
# 998/999
# tripla:  Chicago country United_States Chicago isPartOf DuPage_County,_Illinois 300_North_LaSalle location Chicago
# actual:  300 North LaSalle ist in Chicago im DuPage County von Illinois innerhalb der USA.
# predicted:  300 North LaSalle befindet sich in Chicago, DuPage County, Illinois, USA.
#
#
# 999/999
# tripla:  Illinois country United_States 300_North_LaSalle location Illinois
# actual:  300 North LaSalle ist in Illinois, ein Staat in den Vereinigten Staaten.
# predicted:  300 North LaSalle befindet sich in Illinois, USA.
