# %% [markdown]
# #**Step 1: Installazione, caricamento delle librerie e definizione delle variabili**

# %%
# !pip install transformers
# !pip install sentencepiece
# !pip install accelerate -U

#!pip install evaluate
#!pip install bert_score
#!pip install torchmetrics
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.40.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.14.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.2.2)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (0.1.99)
# Collecting accelerate
#   Downloading accelerate-0.30.0-py3-none-any.whl (302 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.4/302.4 kB 4.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (24.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.2.1+cu121)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.20.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.4.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.14.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (4.11.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.19.3 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2.2.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.10.0->accelerate)
#   Using cached nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (4.66.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, accelerate
# Successfully installed accelerate-0.30.0 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.1.105

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from torch.utils.data import Dataset
from transformers import T5ForConditionalGeneration, T5Tokenizer, T5Config, DataCollatorForSeq2Seq, Seq2SeqTrainingArguments, Seq2SeqTrainer
#from evaluate import load
#from torchmetrics.text import TranslationEditRate

# %%
percentuale_dataset = 1
dataset_type = ""
model_name = "t5-large"

# %% [markdown]
# #**Step 2: Collegamento a drive**

# %%
from google.colab import drive
drive.mount('/content/drive')

# change this to match your path
data_path_models = "./drive/MyDrive/Colab Notebooks/WebNLG-IT/Models"
data_path_data = "./drive/MyDrive/Colab Notebooks/data"
# Out:
# Mounted at /content/drive

# %% [markdown]
# #**Step 3: Importazione dei dataset**

# %%
class CustomDataset(Dataset):
    def __init__(self, X, y, tokenizer):
        self.X = X
        self.y = y
        self.tokenizer = tokenizer

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        input_text = self.X[idx]
        target_text = self.y[idx]

        input_encoding = self.tokenizer(input_text, padding='max_length', truncation=True, max_length=128, return_tensors='pt')
        target_encoding = self.tokenizer(target_text, padding='max_length', truncation=True, max_length=128, return_tensors='pt')

        return {
            'input_ids': input_encoding['input_ids'].squeeze(),
            'attention_mask': input_encoding['attention_mask'].squeeze(),
            'labels': target_encoding['input_ids'].squeeze()
        }

# carico il dataset
trainset = pd.read_csv(f'{data_path_data}/WebNLG-IT/train.csv')
devset = pd.read_csv(f'{data_path_data}/WebNLG-IT/dev.csv')

# %%
# ottengo un sottoinsieme del dataset di partenza
subset_trainset = trainset.sample(frac=percentuale_dataset, random_state=42)
subset_devset = devset.sample(frac=percentuale_dataset, random_state=42)

# train
X_train = subset_trainset['data_unit'].values.tolist()
y_train = subset_trainset['sentence'].values.tolist()

# dev
X_val = subset_devset['data_unit'].values.tolist()
y_val = subset_devset['sentence'].values.tolist()

# %%
subset_trainset.head()
# Out:
#                                                data_unit  \
# 39562                    Mexico language Mexican_Spanish
# 36480                 Belgium leader Philippe_of_Belgium
# 17867  Super_Capers budget 2000000.0 Super_Capers gro...
# 14307  Alvah_Sabin activeYearsStartDate 1853-03-04 Al...
# 25736                     South_Africa leader Jacob_Zuma
#
#                                                 sentence
# 39562  In Messico una delle lingue parlate è lo spagn...
# 36480         Il leader del Belgio è Filippo del Belgio.
# 17867  Adam West ha avuto un ruolo principale nel fil...
# 14307  Il servizio attivo di Alvah Sabin è iniziato i...
# 25736               Jacob Zuma è un leader in Sudafrica.

# %%
len(X_train)
# Out:
# 40081

# %% [markdown]
# #**Step 4: Caricamento del modello**

# %%
# Load the T5 model, tokenizer, and configuration
model = T5ForConditionalGeneration.from_pretrained(model_name)
tokenizer = T5Tokenizer.from_pretrained(model_name)
config = T5Config.from_pretrained(model_name)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.95G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
# Create the custom datasets
train_dataset = CustomDataset(X_train, y_train, tokenizer)
val_dataset = CustomDataset(X_val, y_val, tokenizer)

# %%
# Set up the data collator, training arguments, and trainer
data_collator = DataCollatorForSeq2Seq(
    tokenizer=tokenizer,
    model=model,
    label_pad_token_id=tokenizer.pad_token_id
)

training_args = Seq2SeqTrainingArguments(
    output_dir="./results",
    #per_device_train_batch_size=2,
    #per_device_eval_batch_size=2,
    num_train_epochs=2,
    logging_dir="./logs",
    evaluation_strategy="steps",  # Calcolo della validation loss ad ogni epoca
    save_strategy="steps",  # Checkpoint del modello ad ogni epoca
    save_total_limit=3,  # Limita il numero di checkpoint salvati
    load_best_model_at_end=True,  # Carica il modello migliore al termine dell'addestramento
    metric_for_best_model="eval_loss",  # Sceglie la metrica per determinare il miglior modello
    greater_is_better=False,  # Indica se un valore più alto della metrica è migliore o no
    logging_steps=500,
    eval_steps=500,  # Numero di passaggi prima di valutare il modello
    # Aggiungi eventuali altri argomenti di training qui
)

# %%
trainer = Seq2SeqTrainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
    data_collator=data_collator,
    tokenizer=tokenizer,
)

# Fine-tune the model
trainer.train()
# Out:
#     <div>
#
#       <progress value='10022' max='10022' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [10022/10022 2:11:37, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.865000</td>
#       <td>0.323472</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.356800</td>
#       <td>0.261562</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.302400</td>
#       <td>0.232108</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.273700</td>
#       <td>0.215651</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.255000</td>
#       <td>0.201670</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.240600</td>
#       <td>0.193568</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.230300</td>
#       <td>0.186847</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.227100</td>
#       <td>0.179606</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.216700</td>
#       <td>0.175368</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.209200</td>
#       <td>0.171288</td>
#     </tr>
#     <tr>
#       <td>5500</td>
#       <td>0.188800</td>
#       <td>0.169727</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>0.190100</td>
#       <td>0.167508</td>
#     </tr>
#     <tr>
#       <td>6500</td>
#       <td>0.190600</td>
#       <td>0.164290</td>
#     </tr>
#     <tr>
#       <td>7000</td>
#       <td>0.189700</td>
#       <td>0.162028</td>
#     </tr>
#     <tr>
#       <td>7500</td>
#       <td>0.183700</td>
#       <td>0.160583</td>
#     </tr>
#     <tr>
#       <td>8000</td>
#       <td>0.179800</td>
#       <td>0.159153</td>
#     </tr>
#     <tr>
#       <td>8500</td>
#       <td>0.180600</td>
#       <td>0.158254</td>
#     </tr>
#     <tr>
#       <td>9000</td>
#       <td>0.180700</td>
#       <td>0.156910</td>
#     </tr>
#     <tr>
#       <td>9500</td>
#       <td>0.178900</td>
#       <td>0.156216</td>
#     </tr>
#     <tr>
#       <td>10000</td>
#       <td>0.180100</td>
#       <td>0.155877</td>
#     </tr>
#   </tbody>
# </table><p>
# There were missing keys in the checkpoint model loaded: ['encoder.embed_tokens.weight', 'decoder.embed_tokens.weight', 'lm_head.weight'].
# TrainOutput(global_step=10022, training_loss=0.25083388684633795, metrics={'train_runtime': 7899.8906, 'train_samples_per_second': 10.147, 'train_steps_per_second': 1.269, 'total_flos': 4.3388630335488e+16, 'train_loss': 0.25083388684633795, 'epoch': 2.0})

# %%
# salvataggio del modello
model.save_pretrained(f'{data_path_models}/{model_name}_2epoch')
tokenizer.save_pretrained(f'{data_path_models}/{model_name}_2epoch')
# Out:
# ('./drive/MyDrive/Colab Notebooks/WebNLG-IT/Models/t5-large_2epoch/tokenizer_config.json',
#  './drive/MyDrive/Colab Notebooks/WebNLG-IT/Models/t5-large_2epoch/special_tokens_map.json',
#  './drive/MyDrive/Colab Notebooks/WebNLG-IT/Models/t5-large_2epoch/spiece.model',
#  './drive/MyDrive/Colab Notebooks/WebNLG-IT/Models/t5-large_2epoch/added_tokens.json')

# %% [markdown]
# #**Step 5: generazione frasi del modello creato**

# %%
model1 = T5ForConditionalGeneration.from_pretrained(f'{data_path_models}/{model_name}_2epoch')
tokenizer1 = T5Tokenizer.from_pretrained(f'{data_path_models}/{model_name}_2epoch')
print(f'{data_path_models}/{model_name}_2epoch')
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# ./drive/MyDrive/Colab Notebooks/WebNLG-IT/Models/t5-large_2epoch

# %%
def generate_text(input_rdf, max_length=128):
  input_text = f"{input_rdf}"
  input_ids = tokenizer1.encode(input_text, return_tensors="pt")

  # Imposta il parametro max_length per controllare la lunghezza dell'output generato
  output_ids = model1.generate(input_ids, max_length=max_length)

  output_text = tokenizer1.decode(output_ids[0], skip_special_tokens=True)
  return output_text

# %%
testset = pd.read_csv(f'{data_path_data}/WebNLG-IT/test.csv')

# ottengo un sottoinsieme del testset di partenza
subset_testset = testset.sample(frac=percentuale_dataset, random_state=42)

# test
X_test = subset_testset['data_unit'].values.tolist()
y_test = subset_testset['sentence'].values.tolist()

len(X_test)
# Out:
# 1000

# %%
subset_testset.head()
# Out:
#                                              data_unit  \
# 521         Peter_Stöger club FC_Admira_Wacker_Mödling
# 737                   Arem-arem ingredient Banana_leaf
# 740  Weymouth_Sands followedBy Maiden_Castle_(novel...
# 660  Christian_Panucci club Genoa_C.F.C. Christian_...
# 411                        Chicharrón region Andalusia
#
#                                               sentence
# 521  La squadra di Peter Stöger è l'FC Admira Wacke...
# 737  La foglia di banano è un ingrediente di Arem a...
# 740  A Glastonbury Romance" fu seguito da "Weymouth...
# 660  L'A.S. Livorno Calcio è diretto da Christian P...
# 411  Il chicharrón si trova nella regione dell'Anda...

# %%
triple = []
predicted = []
actuals = []

i = 0
for tripla in X_test:
  triple.append(tripla)
  prediction = generate_text(tripla)
  predicted.append(prediction)
  actuals.append(y_test[i])

  print(f'{i}/{len(X_test)-1}')
  print('tripla: ', tripla)
  print('actual: ', y_test[i])
  print('predicted: ', prediction)
  print('\n')

  df = pd.DataFrame(list(zip(triple, predicted, actuals)), columns =['triple', 'predicted', 'actuals'])
  df.to_csv(f'{data_path_models}/{model_name}_2epoch_decoding.csv', index=False)

  i += 1
# Out:
# Output streaming troncato alle ultime 5000 righe.
#
#
# 167/999
# tripla:  Andrews_County_Airport runwayLength 1773.0
# actual:  La lunghezza della pista dell'aeroporto di Andrews County è di 1773 metri.
# predicted:  La lunghezza della pista dell'aeroporto della contea di Andrews è di 1773,0 metri.
#
#
# 168/999
# tripla:  Alderney_Airport runwayLength 497.0
# actual:  L'aeroporto di Alderney ha una pista di 497,0 metri.
# predicted:  La lunghezza della pista dell'aeroporto di Alderney è di 497,0 metri.
#
#
# 169/999
# tripla:  A.C._Chievo_Verona ground "Verona, Italy" A.C._Chievo_Verona league Serie_A
# actual:  Verona, Italia è la sede dell'A.C. Chievo Verona, che milita nel campionato di Serie A.
# predicted:  L'A.C. Chievo Verona gioca in Serie A e il suo campo si trova a Verona, in Italia.
#
#
# 170/999
# tripla:  Auron_(comicsCharacter) creator Karl_Kesel Auron_(comicsCharacter) creator Walt_Simonson
# actual:  Il personaggio dei fumetti Auron è stato creato sia da Karl Kesel che da Walt Simonson.
# predicted:  Auron è un personaggio dei fumetti creato da Karl Kesel e Walt Simonson.
#
#
# 171/999
# tripla:  Adolfo_Suárez_Madrid–Barajas_Airport runwayLength 3500.0
# actual:  La lunghezza della pista dell'Aeroporto Adolfo Suárez Madrid-Barajas è di 3.500 metri.
# predicted:  La lunghezza della pista dell'aeroporto Adolfo Suárez Madrid-Barajas è di 3500,0 metri.
#
#
# 172/999
# tripla:  Adolfo_Suárez_Madrid–Barajas_Airport location "Madrid, Paracuellos de Jarama, San Sebastián de los Reyes and Alcobendas" Adolfo_Suárez_Madrid–Barajas_Airport operatingOrganisation ENAIRE Adolfo_Suárez_Madrid–Barajas_Airport runwayLength 3500.0 Adolfo_Suárez_Madrid–Barajas_Airport runwayName "14R/32L"
# actual:  L'Aeroporto Adolfo Suarez Madrid-Barajas si trova a Madrid, Paracuellos de Jarama, San Sebastian de los Reyes e Alcobendas ed è gestito da ENAIRE. Ha una pista di nome 14R/32L con una lunghezza di 3500.
# predicted:  L'aeroporto Adolfo Suarez Madrid-Barajas si trova a Madrid, Paracuellos de Jarama, San Sebastián de los Reyes e Alcobendas.  gestito da ENAIRE e ha una pista denominata 14R/32L lunga 3500 metri.
#
#
# 173/999
# tripla:  Cleveland governingBody Cleveland_City_Council Cleveland isPartOf Cuyahoga_County,_Ohio Cleveland isPartOf Ohio 200_Public_Square location Cleveland
# actual:  200 Public Square si trova a Cleveland, nella contea di Cuyahoga, Ohio, ed è governata dal Comune di Cleveland.
# predicted:  200 Public Square si trova a Cleveland, nella contea di Cuyahoga, Ohio. L'organo di governo di Cleveland è il Consiglio comunale di Cleveland.
#
#
# 174/999
# tripla:  Adare_Manor architect Philip_Charles_Hardwick Adare_Manor completionDate 1862 Adare_Manor location Adare Adare_Manor location County_Limerick
# actual:  Adare Manor, completato nel 1862 dall'architetto Philip Charles Hardwick, si trova ad Adare, nella contea di Limerick.
# predicted:  Philip Charles Hardwick è l'architetto dell'Adare Manor, completato nel 1862 e situato ad Adare, nella contea di Limerick.
#
#
# 175/999
# tripla:  AFC_Ajax numberOfMembers 53502 AFC_Ajax season 2014
# actual:  L'AFC Ajax ha 53502 soci e ha pagato nella stagione 2014.
# predicted:  L'AFC Ajax ha 53502 membri e ha giocato nella stagione 2014.
#
#
# 176/999
# tripla:  Beef_kway_teow country "Singapore and Indonesia" Beef_kway_teow ingredient Palm_sugar Beef_kway_teow region Indonesia
# actual:  Lo zucchero di palma è un ingrediente del beef kway teow, un piatto originario dell'Indonesia e comunemente diffuso anche a Singapore.
# predicted:  Il Beef kway teow è un piatto di Singapore e in Indonesia. Uno degli ingredienti è il sugo di palma.
#
#
# 177/999
# tripla:  Baymax creator Duncan_Rouleau Baymax creator Steven_T._Seagle Baymax firstAppearanceInFilm Big_Hero_6_(film) Baymax series Big_Hero_6_(film)
# actual:  Baymax è un personaggio creato da Duncan Rouleau e Steven T. Seagle, apparso per la prima volta nel film "Big Hero 6".
# predicted:  Baymax è un personaggio del film Big Hero 6, creato da Duncan Rouleau e Steven T. Seagle.
#
#
# 178/999
# tripla:  Alan_B._Miller_Hall architecturalStyle Georgian_architecture Alan_B._Miller_Hall location Williamsburg,_Virginia Alan_B._Miller_Hall owner College_of_William_&_Mary
# actual:  Il College of William and Mary è proprietario della Alan B. Miller Hall in stile georgiano a Williamsburg, Virginia.
# predicted:  La Alan B. Miller Hall, di proprietà del College of William and Mary, si trova a Williamsburg, in Virginia, ed è in stile architettonico georgiano.
#
#
# 179/999
# tripla:  Almond family Rosaceae Ajoblanco ingredient Almond Almond order Rosids
# actual:  La mandorla, che è uno degli ingredienti di Ajoblanco, fa parte della famiglia delle Rosacee e dell'ordine dei Rosidi.
# predicted:  La mandorla appartiene alla famiglia delle Rosaceae e all'ordine delle Rosidi.  un ingrediente dell'Ajoblanco.
#
#
# 180/999
# tripla:  Dublin country Republic_of_Ireland Dublin leaderTitle European_Parliament 3Arena location Dublin 3Arena owner Live_Nation_Entertainment
# actual:  Live Nation Entertainment è proprietaria della 3Arena di Dublino, nella Repubblica d'Irlanda. Dublino è guidata dal Parlamento europeo.
# predicted:  La 3Arena di Dublino, in Repubblica d'Irlanda, è di proprietà di Live Nation Entertainment. Il Parlamento europeo è il leader di Dublino.
#
#
# 181/999
# tripla:  Almond order Rosids
# actual:  Il mandorlo fa parte dell'ordine dei Rosidi.
# predicted:  La mandorla appartiene all'ordine delle Rosidi.
#
#
# 182/999
# tripla:  Maple_Ridge_Township,_Alpena_County,_Michigan country United_States
# actual:  Maple Ridge Township, Alpena County Michigan si trova negli Stati Uniti.
# predicted:  Maple Ridge Township, nella contea di Alpena, Michigan, si trova negli Stati Uniti.
#
#
# 183/999
# tripla:  Acharya_Institute_of_Technology affiliation Visvesvaraya_Technological_University Acharya_Institute_of_Technology city Bangalore Acharya_Institute_of_Technology country "India" Acharya_Institute_of_Technology established 2000 Acharya_Institute_of_Technology numberOfPostgraduateStudents 700
# actual:  L'Acharya Institute of Technology di Bangalore, India, è stato fondato nel 2000. Ha 700 studenti ed è affiliato alla Visvesvaraya Technological University.
# predicted:  L'Acharya Institute of Technology di Bangalore, India, è stato fondato nel 2000 e conta 700 studenti post-laurea. L'istituto è affiliato alla Visvesvaraya Technological University.
#
#
# 184/999
# tripla:  Lemon order Sapindales
# actual:  Il limone è incluso nell'ordine delle Sapindales.
# predicted:  L'ordine dello Sapindales è il limone.
#
#
# 185/999
# tripla:  Bacon_Explosion country United_States Bacon_Explosion ingredient Bacon Bacon_Explosion region Kansas_City_metropolitan_area
# actual:  Il bacon è un ingrediente di una Bacon Explosion proveniente dall'area metropolitana di Kansas City, negli Stati Uniti.
# predicted:  La Bacon Explosion è un piatto dell'area metropolitana di Kansas City, negli Stati Uniti. Il bacon è un ingrediente della Bacon Explosion.
#
#
# 186/999
# tripla:  Acharya_Institute_of_Technology country "India" Acharya_Institute_of_Technology established 2000
# actual:  L'Acharya Institute of Technology è stato fondato in India nel 2000.
# predicted:  L'Acharya Institute of Technology è stato fondato nel 2000 e si trova in India.
#
#
# 187/999
# tripla:  School of Business and Social Sciences at the Aarhus University affiliation European_University_Association School of Business and Social Sciences at the Aarhus University established 1928
# actual:  La Scuola di Economia e Scienze Sociali dell'Università di Aarhus, fondata nel 1928, è affiliata alla European University Association.
# predicted:  La Scuola di Economia e Scienze Sociali dell'Università di Aarhus è stata fondata nel 1928 ed è affiliata all'Associazione delle Università Europee.
#
#
# 188/999
# tripla:  Bacon_sandwich country United_Kingdom Bacon_sandwich ingredient Ketchup
# actual:  Il panino con il bacon, a cui spesso si aggiunge il ketchup, proviene dal Regno Unito.
# predicted:  Il ketchup è un ingrediente del panino al bacon, originario del Regno Unito.
#
#
# 189/999
# tripla:  Barny_Cakes carbohydrate 18.0 g Barny_Cakes dishVariation Apple Barny_Cakes fat 4.8 g Barny_Cakes protein 1.8 g
# actual:  Le barrette possono essere preparate con le mele. Contengono 1,8 g di proteine, 4,8 g di grassi e 18 grammi di carboidrati.
# predicted:  Il piatto dei Barny Cakes, che includono anche l'apple, contiene 1,8 g di proteine, 4,8 g di grassi e 18,0 g di carboidrati.
#
#
# 190/999
# tripla:  AIP_Advances editor "Vincent H. Crespi, Bernard S. Gerstman, A.T. Charlie Johnson,  Masaaki Tanaka, Enge G. Wang"
# actual:  I redattori di AIP Advances sono i seguenti: Vincent H. Crespi, Bernard S. Gerstman, A.T. Charlie Johnson, Masaaki Tanaka, Enge G. Wang.
# predicted:  AIP Advances è stato redatto da Vincent H. Crespi, Bernard S. Gerstman, A.T. Charlie Johnson, Masaaki Tanaka e Enge G. Wang.
#
#
# 191/999
# tripla:  Alan_B._Miller_Hall address "101 Ukrop Way" Alan_B._Miller_Hall inaugurationDate "2009-10-02"
# actual:  La Alan B Miller Hall (inaugurata il 2009-10-02) ha come indirizzo "101 Ukrop Way".
# predicted:  L'Alan B. Miller Hall si trova al 101 di Ukrop Way ed è stata inaugurata il 2 ottobre 2009.
#
#
# 192/999
# tripla:  11th_Mississippi_Infantry_Monument state "Pennsylvania"
# actual:  Il monumento all'11° Fanteria del Mississippi si trova in Pennsylvania.
# predicted:  Il monumento all'11° Fanteria del Mississippi si trova nello Stato della Pennsylvania.
#
#
# 193/999
# tripla:  Batagor dishVariation Siomay Siomay dishVariation Shumai
# actual:  Batagor, Shumai e Siomay sono varianti dello stesso piatto.
# predicted:  Batagor e Shumai sono varianti di un piatto simile.
#
#
# 194/999
# tripla:  Asilomar_Conference_Grounds architect Julia_Morgan Julia_Morgan birthPlace San_Francisco Julia_Morgan significantBuilding Los_Angeles_Herald-Examiner Julia_Morgan significantBuilding Asilomar_State_Beach
# actual:  L'architetto Julia Morgan, nata a San Francisco, ha progettato molti edifici importanti, tra cui l'Asilomar Conference Grounds, il Los Angeles Herald Examiner Building e l'Asilomar State Beach.
# predicted:  Julia Morgan, nata a San Francisco, ha progettato l'edificio significativo del Los Angeles Herald Examiner e dell'Asilomar Conference Grounds.
#
#
# 195/999
# tripla:  Serie_B champions Carpi_F.C._1909 A.C._Cesena ground Italy A.C._Cesena league Serie_B
# actual:  L'AC Cesena gioca nel campionato di Serie B che in passato è stato vinto dal Carpi F.C. 1909. Il loro campo si trova in Italia.
# predicted:  L'A.C. Cesena gioca in Serie B, dove il Carpi F.C. 1909 è stato campione. Il suo campo si trova in Italia.
#
#
# 196/999
# tripla:  Blockbuster_(comicsCharacter) alternativeName "Roland Desmond"
# actual:  Il personaggio dei fumetti Blockbuster è noto anche come Roland Desmond.
# predicted:  Il personaggio dei fumetti Blockbuster ha il nome alternativo di Roland Desmond.
#
#
# 197/999
# tripla:  Marriott_International foundationPlace Washington,_D.C. Marriott_International keyPerson Bill_Marriott Marriott_International location Bethesda,_Maryland AC_Hotel_Bella_Sky_Copenhagen tenant Marriott_International
# actual:  Bill Marriot è la persona chiave di Marriott International, fondata a Washington D.C. e ora situata a Bethesda Maryland, nonché affittuaria dell'AC Hotel Bella Sky di Copenhagen.
# predicted:  Bill Marriott è una persona chiave di Marriott International, fondata a Washington D.C. e con sede a Bethesda, Maryland. L'affittuario dell'AC Hotel Bella Sky Copenhagen è Marriott International.
#
#
# 198/999
# tripla:  11th_Mississippi_Infantry_Monument category Contributing_property 11th_Mississippi_Infantry_Monument municipality Gettysburg,_Pennsylvania 11th_Mississippi_Infantry_Monument state "Pennsylvania"
# actual:  Il Monumento dell'11° Fanteria del Mississippi, nel comune di Gettysburg, Pennsylvania, rientra nella categoria dei beni che contribuiscono.
# predicted:  Il monumento all'11° Fanteria del Mississippi si trova a Gettysburg, in Pennsylvania, ed è classificato come proprietà contribuente.
#
#
# 199/999
# tripla:  Serie_B champions Carpi_F.C._1909 A.C._Cesena ground Italy A.C._Cesena league Serie_B A.C._Cesena numberOfMembers 23900
# actual:  L'A.C. Cesena ha 23900 soci e la sua sede si trova in Italia. Gioca nel campionato di Serie B, di cui il Carpi FC 1909 è il precedente campione.
# predicted:  L'A.C. Cesena, con 23900 membri, gioca in Serie B, dove il Carpi F.C. 1909 è stato campione.
#
#
# 200/999
# tripla:  Aarhus_Airport operatingOrganisation Aktieselskab Aarhus_Airport runwayLength 2776.0 Aarhus_Airport runwayName "10R/28L"
# actual:  Gestito dall'organizzazione Aktieselskab, l'aeroporto di Aarhus ha una pista lunga 2776,0 metri e una pista denominata 10R/28L.
# predicted:  Aktieselskab è l'organizzazione operativa dell'aeroporto di Aarhus, che ha una pista lunga 2776,0 e una denominazione 10R/28L.
#
#
# 201/999
# tripla:  Bionico country Mexico Bionico ingredient Raisin
# actual:  Il Bionico è un alimento che contiene uvetta e si trova in Messico.
# predicted:  Il Bionico è un alimento diffuso in Messico e contiene uvetta.
#
#
# 202/999
# tripla:  Springer_Science+Business_Media founder Julius_Springer
# actual:  Julius Springer è il fondatore di Springer Science and Business Media.
# predicted:  Julius Springer è il fondatore di Springer Science+Business Media.
#
#
# 203/999
# tripla:  Philippines officialLanguage Philippine_English
# actual:  L'inglese filippino è la lingua ufficiale delle Filippine.
# predicted:  L'inglese filippino è la lingua ufficiale delle Filippine.
#
#
# 204/999
# tripla:  United_Kingdom capital London Bacon_sandwich country United_Kingdom Bacon_sandwich dishVariation BLT BLT dishVariation Club_sandwich
# actual:  Londra è la capitale del Regno Unito, paese da cui proviene il bacon sandwich. Una variante del panino al bacon è il BLT, che a sua volta è una variante del Club Sandwich.
# predicted:  Il panino al bacon è un piatto del Regno Unito, la cui capitale è Londra. Il BLT è una variante del panino al bacon e il club sandwich è una variante del BLT.
#
#
# 205/999
# tripla:  103_Colmore_Row location Colmore_Row
# actual:  103 Colmore Row si trova a Colmore Row.
# predicted:  Il 103 Colmore Row si trova a Colmore Row.
#
#
# 206/999
# tripla:  Bananaman broadcastedBy BBC Bananaman creator Steve_Bright Bananaman firstAired "1983-10-03" Bananaman lastAired "1986-04-15" Bananaman starring Jill_Shilling
# actual:  La BBC ha trasmesso la serie televisiva di Bananaman tra il 3 ottobre 1983 e il 15 aprile 1986. È stata creata da Steve Bright e interpretata da Jill Shilling.
# predicted:  Bananaman è stato trasmesso per la prima volta il 3 ottobre 1983 dalla BBC e ha avuto come protagonista Jill Shilling.  stato creato da Steve Bright e trasmesso per l'ultima volta il 15 aprile 1986.
#
#
# 207/999
# tripla:  Turkey capital Ankara Turkey currency Turkish_lira Atatürk_Monument_(İzmir) designer Pietro_Canonica Atatürk_Monument_(İzmir) inaugurationDate "1932-07-27" Turkey leaderTitle President_of_Turkey Atatürk_Monument_(İzmir) location Turkey
# actual:  Il leader della Turchia è il Presidente, la moneta è la lira turca e la capitale è Ankara. Qui si trova il monumento ad Atatürk, progettato da Pietro Canonica e inaugurato a Smirne il 27 luglio 1932.
# predicted:  Il monumento ad Atatürk a Smirne, in Turchia, è stato progettato da Pietro Canonica e inaugurato il 27 luglio 1932. La capitale della Turchia è Ankara e la valuta è la lira turca. Il leader della Turchia è chiamato Presidente della Turchia.
#
#
# 208/999
# tripla:  Acharya_Institute_of_Technology campus "In Soldevanahalli, Acharya Dr. Sarvapalli Radhakrishnan Road, Hessarghatta Main Road, Bangalore – 560090." Acharya_Institute_of_Technology director "Dr. G. P. Prabhukumar"
# actual:  Il campus dell'Acharya Institute of Technology si trova a Soldevanahalli, Acharya Dr. Sarvapalli Radhakrishnan Road, Hessarghatta Main Road, Bangalore - 560090 e il direttore è il Dr. G. P. Prabhukumar.
# predicted:  Il campus dell'Acharya Institute of Technology si trova a Soldevanahalli, Acharya Dr. Sarvapalli Radhakrishnan Road, Hessarghatta Main Road, Bangalore - 560090 ed è diretto dal Dr. G. P. Prabhukumar.
#
#
# 209/999
# tripla:  Greece leader Prokopis_Pavlopoulos A.E_Dimitra_Efxeinoupolis location Greece
# actual:  La squadra A.E Dimitra Efxeinoupolis si trova in Grecia ed è guidato da Prokopis Pavlopoulos.
# predicted:  L'A.E Dimitra Efxeinoupolis si trova in Grecia, dove il leader è Prokopis Pavlopoulos.
#
#
# 210/999
# tripla:  AFC_Ajax_(amateurs) ground Amsterdam Amsterdam leader Eberhard_van_der_Laan
# actual:  L'AFC Ajax ha sede ad Amsterdam e il leader è Eberhard van der Laan.
# predicted:  Eberhard van der Laan è il leader di Amsterdam, dove si trova il campo dell'AFC Ajax (dilettanti).
#
#
# 211/999
# tripla:  Abilene,_Texas areaOfWater 14.2 (square kilometres)
# actual:  Ad Abilene, in Texas, ci sono 14,2 chilometri quadrati di acqua.
# predicted:  Abilene, Texas, ha una superficie d'acqua di 14,2 chilometri quadrati.
#
#
# 212/999
# tripla:  Akron,_Ohio leaderTitle Mayor
# actual:  Sindaco è il titolo del leader di Akron, Ohio.
# predicted:  Il sindaco è il leader di Akron, Ohio.
#
#
# 213/999
# tripla:  Accademia_di_Architettura_di_Mendrisio academicStaffSize 100 Accademia_di_Architettura_di_Mendrisio city Mendrisio Accademia_di_Architettura_di_Mendrisio country Switzerland Accademia_di_Architettura_di_Mendrisio established 1996 Switzerland leaderTitle Federal_Chancellor_of_Switzerland Accademia_di_Architettura_di_Mendrisio numberOfStudents 600
# actual:  L'Accademia di Architettura di Mendrisio si trova a Mendrisio, in Svizzera, ed è stata fondata nel 1996. Ha 100 membri del personale accademico e 600 studenti. Il leader della Svizzera è il Cancelliere federale.
# predicted:  L'Accademia di Architettura di Mendrisio, in Svizzera, è stata fondata nel 1996 e conta 600 studenti. Il suo personale accademico è composto da 100 persone e il suo leader è il Cancelliere federale della Svizzera.
#
#
# 214/999
# tripla:  Romania leaderTitle Prime_Minister_of_Romania
# actual:  Il leader della Romania è noto come Primo Ministro.
# predicted:  Il primo ministro della Romania è il leader della Romania.
#
#
# 215/999
# tripla:  Malaysia capital Putrajaya Asam_pedas country Malaysia Malaysia ethnicGroup Malaysian_Chinese Malaysia ethnicGroup Malaysian_Malay Asam_pedas region "Sumatra and Malay Peninsula"
# actual:  L'asam pedas è un alimento diffuso nella regione di Sumatra e nella penisola malese della Malesia, la cui capitale è Putrajaya, i cui gruppi etnici comprendono i malesi e i cinesi della Malesia.
# predicted:  L'asam pedas è un piatto diffuso in Malesia, dove la capitale è Putrajaya e i malesi e i cinesi malesi sono gruppi etnici. L'asam pedas è originario di Sumatra e della penisola malese.
#
#
# 216/999
# tripla:  14th_New_Jersey_Volunteer_Infantry_Monument country "United States" 14th_New_Jersey_Volunteer_Infantry_Monument district Monocacy_National_Battlefield 14th_New_Jersey_Volunteer_Infantry_Monument established "1907-07-11" Monocacy_National_Battlefield location Frederick_County,_Maryland Monocacy_National_Battlefield nearestCity Frederick,_Maryland 14th_New_Jersey_Volunteer_Infantry_Monument owningOrganisation National_Park_Service
# actual:  Il monumento al 14° New Jersey Volunteer Infantry si trova nel Monocacy National Battlefield, nella contea di Frederick, Maryland, Stati Uniti. Il monumento è stato istituito l'11 luglio 1907 ed è di proprietà del National Park Service.
# predicted:  Il 14th New Jersey Volunteer Infantry Monument è stato istituito l'11 luglio 1907 e si trova nel Monocacy National Battlefield, nella contea di Frederick, Maryland, Stati Uniti. Il monumento è di proprietà del National Park Service e si trova nel Monocacy National Battlefield. La città più vicina è Frederick, Maryland.
#
#
# 217/999
# tripla:  Bananaman broadcastedBy BBC Bananaman creator John_Geering Bananaman firstAired "1983-10-03" Bananaman lastAired "1986-04-15" Bananaman starring Graeme_Garden
# actual:  Bananaman è andato in onda per la prima volta sulla BBC il 3 ottobre 1983 e ha trasmesso il suo ultimo episodio il 15 aprile 1986. Bananaman è andato in onda per l'ultima volta il 15 aprile 1986. Graeme Garden è uno dei protagonisti della serie creata da John Geering.
# predicted:  John Geering ha creato Bananaman, trasmesso per la prima volta il 3 ottobre 1983 e trasmesso per l'ultima volta il 15 aprile 1986. Graeme Garden ha recitato nel film, trasmesso dalla BBC.
#
#
# 218/999
# tripla:  Binignit country Philippines Binignit ingredient Taro
# actual:  Il Binignit è un piatto delle Filippine, i cui ingredienti includono il taro.
# predicted:  Il taro è un ingrediente del Binignit, che proviene dalla regione delle Filippine.
#
#
# 219/999
# tripla:  Baked_Alaska country France Baked_Alaska ingredient Christmas_pudding Baked_Alaska region Hong_Kong
# actual:  L'omelette norvegese, che contiene il budino di Natale, proviene dalla Francia. L'omelette norvegese viene servita nella regione di Hong Kong.
# predicted:  L'omelette norvegese è originaria della Francia e di Hong Kong. Uno degli ingredienti dell'omelette norvegese è il Christmas pudding.
#
#
# 220/999
# tripla:  Spain currency Euro
# actual:  La Spagna utilizza l'euro come valuta.
# predicted:  La valuta della Spagna è l'euro.
#
#
# 221/999
# tripla:  John_Buscema award Inkpot_Award
# actual:  John Buscema ha vinto il premio Inkpot.
# predicted:  John Buscema ha vinto il premio Inkpot.
#
#
# 222/999
# tripla:  Amatriciana_sauce ingredient Tomato
# actual:  Il sugo all'amatriciana ha tra i suoi ingredienti il pomodoro.
# predicted:  Il pomodoro è un ingrediente della salsa amatriciana.
#
#
# 223/999
# tripla:  Alan_Shepard deathPlace California California senators Dianne_Feinstein
# actual:  Dianne Feinstein è uno dei senatori della California, dove Alan Shepard è morto.
# predicted:  Alan Shepard è morto in California, dove Dianne Feinstein è senatrice.
#
#
# 224/999
# tripla:  Asterix_(comicsCharacter) alternativeName "Astérix"
# actual:  Il nome alternativo di Asterix (personaggio dei fumetti) è "Astérix".
# predicted:  Il personaggio dei fumetti Asterix ha il nome alternativo di Astérix.
#
#
# 225/999
# tripla:  A_Wizard_of_Mars language English_language English_language spokenIn Great_Britain
# actual:  A Wizard of Mars è pubblicato in inglese, la lingua parlata in Gran Bretagna.
# predicted:  Un mago di Marte è scritto in inglese, la lingua parlata in Gran Bretagna.
#
#
# 226/999
# tripla:  Christian_Panucci club Genoa_C.F.C. A.S._Livorno_Calcio manager Christian_Panucci
# actual:  L'A.S. Livorno Calcio è gestito da Christian Panucci che ha giocato a calcio nel Genoa C.F.C.
# predicted:  Christian Panucci è stato dirigente dell'A.S. Livorno Calcio e gioca nel Genoa C.F.C.
#
#
# 227/999
# tripla:  Almond order Rosids
# actual:  Il mandorlo fa parte dell'ordine dei Rosidi.
# predicted:  La mandorla appartiene all'ordine delle Rosidi.
#
#
# 228/999
# tripla:  1_Decembrie_1918_University country Romania 1_Decembrie_1918_University latinName "Universitas Apulensis" Romania patronSaint Andrew_the_Apostle
# actual:  1 dicembre 1918 L'Università si trova in Romania. Il suo nome latino è "Universitas Apulensis". Il santo patrono della Romania è l'apostolo Andrea.
# predicted:  L'Università 1 Decembrie 1918 si trova in Romania, dove il patrono è l'apostolo Andrea. Il suo nome latino è Universitas Apulensis.
#
#
# 229/999
# tripla:  A.F.C._Fylde ground Warton,_Fylde
# actual:  Il campo dell'AFC Fylde si trova a Warton, Fylde.
# predicted:  Il campo dell'AFC Fylde si trova a Warton, Fylde.
#
#
# 230/999
# tripla:  Asam_pedas creatorOfDish Padang_cuisine
# actual:  La cucina di Padang ha portato alla creazione del piatto Asam pedas.
# predicted:  L'asam pedas è un piatto della cucina Padang.
#
#
# 231/999
# tripla:  Italy capital Rome Italy demonym Italians A.S._Gubbio_1910 ground Italy Italy leader Pietro_Grasso Italy officialLanguage Italian_language
# actual:  Il terreno dell'A.S. Gubbio 1910 si trova in Italia, il Paese che è abitato da italiani. La capitale dell'Italia è Roma, la lingua ufficiale è l'italiano e il leader è Pietro Grasso.
# predicted:  Il terreno dell'A.S. Gubbio 1910 si trova in Italia, dove la capitale è Roma e la lingua ufficiale è l'italiano. Pietro Grasso è il leader dell'Italia, dove gli italiani sono il nome dei suoi abitanti.
#
#
# 232/999
# tripla:  Akita,_Akita country Japan Japan ethnicGroup Brazilians_in_Japan Akita_Museum_of_Art location Akita_Prefecture Akita_Museum_of_Art location Akita,_Akita
# actual:  Il Giappone, patria di molti brasiliani, ospita anche l'Akita Museum of Art, fondato e situato nella prefettura di Akita.
# predicted:  Il Museo d'Arte di Akita si trova nella prefettura di Akita, in Giappone. I brasiliani sono un gruppo etnico del Giappone.
#
#
# 233/999
# tripla:  Bionico dishVariation Honey
# actual:  Il miele può essere utilizzato come variante nel piatto Bionico.
# predicted:  Il miele è una variante del Bionico.
#
#
# 234/999
# tripla:  AWH_Engineering_College academicStaffSize 250 AWH_Engineering_College country India AWH_Engineering_College established 2001
# actual:  L'AWH Engineering College è stato fondato in India nel 2001 e conta 250 membri del personale accademico.
# predicted:  L'AWH Engineering College, indiano, è stato fondato nel 2001 e conta 250 membri del personale accademico.
#
#
# 235/999
# tripla:  Stuart_Parker_(footballer) club Chesterfield_F.C. Stuart_Parker_(footballer) club Drogheda_United_F.C. A.F.C._Blackpool manager Stuart_Parker_(footballer)
# actual:  L'AFC Blackpool ha assunto Stuart Parker come allenatore. È legato al Chesterfield football club ed è stato al Drogheda United FC.
# predicted:  Stuart Parker è stato dirigente dell'AFC Blackpool e ha giocato a calcio per il Chesterfield FC e il Drogheda United FC.
#
#
# 236/999
# tripla:  Egg_Harbor_Township,_New_Jersey country United_States Atlantic_City_International_Airport location Egg_Harbor_Township,_New_Jersey Atlantic_City_International_Airport runwayLength 1873.0
# actual:  L'aeroporto internazionale di Atlantic City si trova nella cittadina di Egg Harbor, New Jersey, USA. La lunghezza della pista è di 1873 metri.
# predicted:  L'aeroporto internazionale di Atlantic City si trova nella cittadina di Egg Harbor, New Jersey, Stati Uniti. La pista è lunga 1873 metri.
#
#
# 237/999
# tripla:  Cornell_University affiliation Association_of_American_Universities Administrative_Science_Quarterly publisher Cornell_University
# actual:  Administrative Science Quarterly è stato pubblicato dalla Cornell University, affiliata all'Association of American Universities.
# predicted:  La Cornell University, affiliata all'Association of American Universities, è l'editore di Administrative Science Quarterly.
#
#
# 238/999
# tripla:  Bolt_(comicsCharacter) alternativeName "Larry Bolatinsky" Bolt_(comicsCharacter) creator Paris_Cullins Bolt_(comicsCharacter) creator Ernie_Colón
# actual:  Larry Bolatinsky è il nome alternativo del personaggio dei fumetti Bolt, creato da Ernie Colon e Paris Cullins.
# predicted:  Il personaggio dei fumetti Bolt, alias Larry Bolatinsky, è stato creato da Paris Cullins e Ernie Colon.
#
#
# 239/999
# tripla:  United_States_Air_Force transportAircraft Lockheed_C-130_Hercules
# actual:  Il Lockheed C-130 Hercules è un aereo da trasporto della United States Air Force.
# predicted:  L'aeronautica militare degli Stati Uniti ha un aereo da trasporto chiamato Lockheed C-130 Hercules.
#
#
# 240/999
# tripla:  20_Fenchurch_Street completionDate "April 2014" 20_Fenchurch_Street floorArea 62145.3 (square metres) 20_Fenchurch_Street floorCount 34
# actual:  20 Fenchurch Street, completato nell'aprile 2014, ha 34 piani e una superficie di 62145,3 metri quadrati.
# predicted:  20 Fenchurch Street ha 34 piani e una superficie di 62145,3 metri quadrati.  stato completato nel 2014 e ha una superficie di 62145,3 metri quadrati.
#
#
# 241/999
# tripla:  Batchoy country Philippines Philippines ethnicGroup Igorot_people Philippines ethnicGroup Chinese_Filipino Philippines language Philippine_Spanish
# actual:  Nelle Filippine si parla lo spagnolo filippino, si mangia il Batchoy e sono presenti i gruppi etnici degli Igorot e dei cinesi filippini.
# predicted:  Il batchoy viene consumato nelle Filippine, dove si parla lo spagnolo filippino e i gruppi etnici includono il popolo Igorot e i cinesi filippini.
#
#
# 242/999
# tripla:  A_Loyal_Character_Dancer mediaType "Print"
# actual:  A Loyal Character Dancer è in stampa.
# predicted:  A Loyal Character Dancer è disponibile in stampa.
#
#
# 243/999
# tripla:  Belgium language German_language
# actual:  La lingua del Belgio è il tedesco.
# predicted:  Il tedesco è una delle lingue parlate in Belgio.
#
#
# 244/999
# tripla:  California_State_Assembly isPartOf California_State_Legislature
# actual:  L'Assemblea dello Stato della California fa parte della legislatura dello Stato della California.
# predicted:  L'Assemblea dello Stato della California fa parte della legislatura dello Stato della California.
#
#
# 245/999
# tripla:  Sri_Lanka capital Sri_Jayawardenepura_Kotte Adisham_Hall country Sri_Lanka Sri_Lanka language Tamil_language Adisham_Hall location Haputale
# actual:  L'Adisham Hall si trova a Haputalethe, nello Sri Lanka, dove la capitale è Sri Jayawardenepura Kotte e si parla la lingua tamil.
# predicted:  L'Adisham Hall si trova a Haputale, nello Sri Lanka, dove la capitale è Sri Jayawardenepura Kotte e la lingua parlata è il tamil.
#
#
# 246/999
# tripla:  Ampara_Hospital bedCount 476 Ampara_Hospital country Sri_Lanka Ampara_Hospital state Eastern_Province,_Sri_Lanka
# actual:  Situato nella provincia orientale dello Sri Lanka, l'ospedale di Ampara dispone di 476 posti letto.
# predicted:  L'ospedale di Ampara, situato nella provincia orientale dello Sri Lanka, ha 476 posti letto.
#
#
# 247/999
# tripla:  Jens_Härtel club SV_Babelsberg_03
# actual:  Jens Härtel fa parte del club SV Babelsberg 03.
# predicted:  Jens Härtel gioca per SV Babelsberg 03!
#
#
# 248/999
# tripla:  Auron_(comicsCharacter) creator Karl_Kesel Auron_(comicsCharacter) creator Walt_Simonson Karl_Kesel nationality Americans
# actual:  Il personaggio dei fumetti Auron è stato creato da Walt Simonson e dall'americano Karl Kesel.
# predicted:  Auron è un personaggio dei fumetti creato da Walt Simonson e Karl Kesel, americano.
#
#
# 249/999
# tripla:  Bacon_Explosion country United_States United_States ethnicGroup Asian_Americans
# actual:  Gli asiatici americani sono un gruppo etnico degli Stati Uniti, da cui proviene Bacon Explosion.
# predicted:  L'esplosione del bacon proviene dagli Stati Uniti, dove gli asiatici americani sono un gruppo etnico.
#
#
# 250/999
# tripla:  Baked_Alaska country France Baked_Alaska ingredient Sponge_cake Baked_Alaska region "Paris, New York or Hong Kong"
# actual:  Il pan di Spagna è un ingrediente dell'omelette norvegese, che può provenire da Parigi (Francia), New York o Hong Kong.
# predicted:  L'omelette norvegese è originaria della Francia ed è originaria di Parigi, New York o Hong Kong. Uno degli ingredienti dell'omelette norvegese è il pan di Spagna.
#
#
# 251/999
# tripla:  250_Delaware_Avenue floorArea 30843.8 (square metres) 250_Delaware_Avenue floorCount 12
# actual:  Il 250 Delaware Avenue ha una superficie di 30843,8 metri quadrati e si sviluppa su 12 piani.
# predicted:  Il 250 Delaware Avenue ha 12 piani e una superficie di 30843,8 metri quadrati.
#
#
# 252/999
# tripla:  3Arena architect Populous_(company)
# actual:  L'architetto di 3Arena è la società Populous.
# predicted:  L'architetto della 3Arena è la società Populous.
#
#
# 253/999
# tripla:  250_Delaware_Avenue floorArea 30843.8 (square metres) 250_Delaware_Avenue location Buffalo,_New_York
# actual:  250 Delaware Avenue, Buffalo, New York, ha una superficie di 30843,8 metri quadrati.
# predicted:  250 Delaware Avenue si trova a Buffalo, New York, e ha una superficie di 30843,8 metri quadrati.
#
#
# 254/999
# tripla:  Alan_Shepard nationality United_States
# actual:  La nazionalità di Alan Shepard è quella degli Stati Uniti.
# predicted:  Alan Shepard è un cittadino statunitense.
#
#
# 255/999
# tripla:  Bakewell_pudding dishVariation Bakewell_tart
# actual:  Una variante del bakewell pudding è la torta bakewell.
# predicted:  La torta bakewell è una variante del Bakewell pudding.
#
#
# 256/999
# tripla:  Luciano_Spalletti club Udinese_Calcio Luciano_Spalletti club Empoli_F.C. Luciano_Spalletti club Virtus_Entella A.S._Roma manager Luciano_Spalletti
# actual:  L'allenatore dell'A.S. Roma è Luciano Spalletti, che ha giocato nell'Udinese Calcio. Gioca sia per l'Empoli F.C. che per la Virtus Entella.
# predicted:  Luciano Spalletti è stato dirigente dell'A.S. Roma e ha giocato nell'Udinese Calcio e nell'Empoli F.C. e nella Virtus Entella.
#
#
# 257/999
# tripla:  Abilene_Regional_Airport cityServed Abilene,_Texas Abilene,_Texas country United_States Abilene,_Texas isPartOf Taylor_County,_Texas Abilene,_Texas isPartOf Jones_County,_Texas Abilene_Regional_Airport runwayLength 1121.0
# actual:  Con una pista lunga 1.121, l'aeroporto regionale di Abilene serve Abilene (parte della Contea di Taylor e della Contea di Jones), Texas, Stati Uniti.
# predicted:  L'aeroporto regionale di Abilene serve Abilene, Texas, Stati Uniti. Abilene fa parte della contea di Taylor e della contea di Jones. La pista dell'aeroporto è lunga 1121,0 metri.
#
#
# 258/999
# tripla:  1_Decembrie_1918_University country Romania 1_Decembrie_1918_University latinName "Universitas Apulensis" 1_Decembrie_1918_University state Alba
# actual:  1 dicembre 1918 L'Università si trova ad Alba, in Romania, e il suo nome latino è "Universitas Apulensis".
# predicted:  L'Università 1 Decembrie 1918 si trova ad Alba, in Romania. Il suo nome latino è Universitas Apulensis.
#
#
# 259/999
# tripla:  Romania leaderTitle Prime_Minister_of_Romania
# actual:  Il leader della Romania è noto come Primo Ministro.
# predicted:  Il primo ministro della Romania è il leader della Romania.
#
#
# 260/999
# tripla:  Batchoy country Philippines Philippines ethnicGroup Zamboangans Philippines ethnicGroup Igorot_people Philippines language Arabic Philippines language Philippine_Spanish
# actual:  Le lingue parlate nelle Filippine sono lo spagnolo filippino e l'arabo. Si mangia il batchoy e i gruppi etnici sono gli Zamboangani e gli Igorot.
# predicted:  Il batchoy viene consumato nelle Filippine, dove si parla arabo e spagnolo filippino. I Zamboangan e gli Igorot sono gruppi etnici delle Filippine.
#
#
# 261/999
# tripla:  Singapore language English_language
# actual:  A Singapore si parla la lingua inglese.
# predicted:  L'inglese è la lingua parlata a Singapore.
#
#
# 262/999
# tripla:  A.D._Isidro_Metapán ground "Metapán, El Salvador" A.D._Isidro_Metapán numberOfMembers 10000
# actual:  Con 10000 membri, la sede dell'AD Isidro Metapán si trova a Metapán, El Salvador.
# predicted:  L'A.D. Isidro Metapán ha 10000 membri e il suo campo si trova a Metapán, El Salvador.
#
#
# 263/999
# tripla:  Ayam_penyet country Java Java ethnicGroup Banyumasan_people Ayam_penyet region Singapore
# actual:  L'ayam penyet è un piatto della regione di Singapore. Si trova anche a Giava, dove il popolo Banyumasan è un gruppo etnico.
# predicted:  L'ayam penyet è un piatto originario di Singapore e di Giava, dove il popolo Banyumasan è un gruppo etnico.
#
#
# 264/999
# tripla:  Dane_Whitman_Black_Knight_(comicsCharacter) alternativeName "Dane Whitman" Dane_Whitman_Black_Knight_(comicsCharacter) creator Roy_Thomas
# actual:  Dane Whitman è il nome alternativo del personaggio dei fumetti Dane Whitman Black Knight, creato da Roy Thomas.
# predicted:  Dane Whitman, o Dane Whitman, è un personaggio dei fumetti creato da Roy Thomas. Il nome alternativo del personaggio è "Cavaliere nel Negro".
#
#
# 265/999
# tripla:  Jens_Härtel club FC_Sachsen_Leipzig 1._FC_Magdeburg manager Jens_Härtel
# actual:  L'allenatore dell'FC Magdeburg è Jens Härtel, che ha rappresentato la squadra FC Sachsen Leipzig.
# predicted:  Jens Härtel è stato dirigente dell'FC Magdeburg e ha giocato nell'FC Sachsen Leipzig.
#
#
# 266/999
# tripla:  A.F.C._Blackpool ground "The Mechanics," A.F.C._Blackpool numberOfMembers 1500
# actual:  L'area di gioco dell'A.F.C. Blackpool è The Mechanics. Conta 1500 membri.
# predicted:  L'AFC Blackpool ha 1500 membri e il suo campo si chiama The Mechanics.
#
#
# 267/999
# tripla:  Acharya_Institute_of_Technology affiliation Visvesvaraya_Technological_University Visvesvaraya_Technological_University city Belgaum Acharya_Institute_of_Technology country "India" Acharya_Institute_of_Technology numberOfPostgraduateStudents 700
# actual:  L'Acharya Institute of Technology si trova in India e conta 700 studenti post-laurea. È affiliato alla Visvesvaraya Technological University di Belgaum.
# predicted:  L'Acharya Institute of Technology di Belgaum, India, conta 700 studenti post-laurea. L'istituto è affiliato alla Visvesvaraya Technological University di Belgaum.
#
#
# 268/999
# tripla:  William_Anders birthDate "1933-10-17" William_Anders birthPlace British_Hong_Kong William_Anders dateOfRetirement "1969-09-01"
# actual:  William Anders è andato in pensione il 1° settembre 1969, essendo nato il 17 ottobre 1933 nella Hong Kong britannica.
# predicted:  William Anders è nato nella Hong Kong britannica il 17 ottobre 1933 e si è ritirato il 1° settembre 1969.
#
#
# 269/999
# tripla:  Ayam_penyet country Java Java ethnicGroup Baduy
# actual:  L'ayam penyet è un piatto che si trova a Giava, dove i Baduy sono un gruppo etnico.
# predicted:  L'ayam penyet è un piatto originario di Giava, dove il gruppo etnico è quello dei Baduy.
#
#
# 270/999
# tripla:  Adirondack_Regional_Airport cityServed Lake_Placid,_New_York Adirondack_Regional_Airport cityServed Saranac_Lake,_New_York Saranac_Lake,_New_York country United_States Saranac_Lake,_New_York isPartOf Harrietstown,_New_York Lake_Placid,_New_York isPartOf Essex_County,_New_York
# actual:  L'Adirondack Regional Airport serve la città di Lake Placid, nella contea di Essex, New York, e anche Saranac Lake (parte di Harrietstown) New York, Stati Uniti.
# predicted:  L'Adirondack Regional Airport serve la città di Saranac Lake, che fa parte di Harrietstown, nella Contea di Essex, New York, Stati Uniti.
#
#
# 271/999
# tripla:  United_States capital Washington,_D.C.
# actual:  Washington DC è la capitale degli Stati Uniti.
# predicted:  Washington D.C. è la capitale degli Stati Uniti.
#
#
# 272/999
# tripla:  Buzz_Aldrin birthDate "1930-01-20"
# actual:  La data di nascita di Buzz Aldrin è 1930 01 20.
# predicted:  Buzz Aldrin è nato il 20 gennaio 1930.
#
#
# 273/999
# tripla:  A.S._Gubbio_1910 ground Stadio_Pietro_Barbetti
# actual:  Il terreno di gioco dell'A.S. Gubbio 1910 si chiama Stadio Pietro Barbetti.
# predicted:  Il terreno dell'A.S. Gubbio 1910 è lo Stadio Pietro Barbetti.
#
#
# 274/999
# tripla:  Amsterdam_Airport_Schiphol runwayLength 3300.0
# actual:  La lunghezza della pista dell'aeroporto di Amsterdam Schiphol è di 3300,0 metri.
# predicted:  La lunghezza della pista dell'aeroporto di Amsterdam Schiphol è di 3300,0 metri.
#
#
# 275/999
# tripla:  John_van_den_Brom club İstanbulspor_A.Ş. AZ_Alkmaar manager John_van_den_Brom
# actual:  John van den Brom è stato dirigente dell'AZ Alkmaar ed è un giocatore dell'İstanbulspor A.Ş.
# predicted:  John van den Brom è stato dirigente dell'AZ Alkmaar e gioca per l'stanbulspor A..
#
#
# 276/999
# tripla:  AFC_Ajax_(amateurs) numberOfMembers 5000
# actual:  AFC Ajax ha 5000 membri.
# predicted:  L'AFC Ajax (dilettanti) conta 5000 membri.
#
#
# 277/999
# tripla:  Jack_Kirby nationality Americans
# actual:  Jack Kirby è americano.
# predicted:  Jack Kirby è un cittadino americano.
#
#
# 278/999
# tripla:  Asam_pedas region Malay_Peninsula
# actual:  L'asam pedas è un alimento diffuso nella penisola malese.
# predicted:  L'asam pedas è un alimento diffuso nella penisola malese.
#
#
# 279/999
# tripla:  A_Wizard_of_Mars mediaType Hardcover
# actual:  Un mago di Marte è pubblicato in copertina rigida.
# predicted:  Un mago di Marte è disponibile in copertina rigida.
#
#
# 280/999
# tripla:  Amatriciana_sauce country Italy Italy language Italian_language
# actual:  L'Italia è il paese da cui proviene la salsa amatriciana e dove si parla la lingua italiana.
# predicted:  La salsa amatriciana proviene dall'Italia, dove si parla italiano.
#
#
# 281/999
# tripla:  Texas capital Austin,_Texas Texas country United_States Texas language English_language Texas largestCity Houston Andrews_County_Airport location Texas
# actual:  L'aeroporto della contea di Andrews si trova in Texas, negli Stati Uniti. L'inglese è parlato in questo Stato, dove la capitale è Austin e la città più grande è Houston.
# predicted:  L'aeroporto della contea di Andrews si trova in Texas, negli Stati Uniti. La capitale del Texas è Austin e la città più grande è Houston. La lingua parlata nel Texas è l'inglese.
#
#
# 282/999
# tripla:  Blockbuster_(comicsCharacter) creator Carmine_Infantino
# actual:  Il personaggio dei fumetti, Blockbuster, è stato creato da Carmine Infantino.
# predicted:  Il personaggio dei fumetti Blockbuster è stato creato da Carmine Infantino.
#
#
# 283/999
# tripla:  Appleton_International_Airport cityServed Appleton,_Wisconsin Greenville,_Wisconsin isPartOf Grand_Chute,_Wisconsin Greenville,_Wisconsin isPartOf Ellington,_Wisconsin Appleton_International_Airport location Greenville,_Wisconsin
# actual:  Greenville si trova a Grand Chute e fa parte di Ellington, Wisconsin. È la sede dell'aeroporto internazionale di Appleton, che serve la città di Appleton.
# predicted:  L'aeroporto internazionale di Appleton si trova a Greenville, Wisconsin, che fa parte di Grand Chute e Ellington. L'aeroporto serve Appleton, Wisconsin.
#
#
# 284/999
# tripla:  Albany,_Oregon areaTotal 45.97 (square kilometres)
# actual:  Albany, Oregon, ha una superficie totale di 45,97 chilometri quadrati.
# predicted:  Albany, Oregon, ha una superficie totale di 45,97 chilometri quadrati.
#
#
# 285/999
# tripla:  Asam_pedas country Malaysia Malaysia ethnicGroup Malaysian_Malay Sumatra ethnicGroup Acehnese_people Asam_pedas region Sumatra
# actual:  L'asam pedas è un piatto originario di Sumatra, dove gli Acehnesi sono un gruppo etnico. Il piatto si trova anche in Malesia, dove vivono i malesi.
# predicted:  L'asam pedas è un piatto tradizionale di Sumatra, in Malesia. Gli Acehnesi sono un gruppo etnico di Sumatra.
#
#
# 286/999
# tripla:  Arem-arem country Indonesia
# actual:  L'Arem-arem è un alimento diffuso in Indonesia.
# predicted:  L'Arem-arem proviene dall'Indonesia.
#
#
# 287/999
# tripla:  United_States capital Washington,_D.C. 1634:_The_Ram_Rebellion country United_States United_States ethnicGroup Native_Americans_in_the_United_States
# actual:  I nativi americani sono un gruppo etnico degli Stati Uniti dove la capitale è Washington DC e dove nel 1634 è stato scritto La ribellione del montone.
# predicted:  1634 La ribellione di Ram proviene dagli Stati Uniti, dove la capitale è Washington D.C. e i nativi americani sono un gruppo etnico.
#
#
# 288/999
# tripla:  Asilomar_Conference_Grounds architect Julia_Morgan Julia_Morgan birthPlace California Julia_Morgan significantBuilding Chinatown,_San_Francisco Julia_Morgan significantBuilding Asilomar_State_Beach Julia_Morgan significantProject Hearst_Castle
# actual:  L'architetto Julia Morgan, nata in California, ha progettato molti edifici significativi, tra cui il parco della Asilomar Conference, il castello di Hearst, la Asilomar State Beach e gli edifici di Chinatown a San Francisco.
# predicted:  Julia Morgan, nata in California, ha progettato molti edifici significativi, tra cui l'Asilomar Conference Grounds e l'Asilomar State Beach. Ha progettato anche l'Hearst Castle e Chinatown, a San Francisco.
#
#
# 289/999
# tripla:  Marriott_International foundationPlace Washington,_D.C. Denmark language Faroese_language AC_Hotel_Bella_Sky_Copenhagen location Denmark AC_Hotel_Bella_Sky_Copenhagen tenant Marriott_International
# actual:  Marriott International, fondata a Washington D.C., è un inquilino dell'AC Hotel Bella Sky Copenhagen, situato in Danimarca. La lingua faroese è parlata in tutta la Danimarca.
# predicted:  L'AC Hotel Bella Sky Copenhagen si trova in Danimarca, dove si parla la lingua faroese. Marriott International è stata fondata a Washington DC.
#
#
# 290/999
# tripla:  St._Vincent–St._Mary_High_School city Akron,_Ohio Akron,_Ohio country United_States Akron_Summit_Assault ground St._Vincent–St._Mary_High_School
# actual:  La sede dell'Akron Summit Assault è la St. Vincent-St. Mary High School, Akron, Ohio, USA.
# predicted:  La St Vincent-St Mary High School si trova nella città di Akron, Ohio, Stati Uniti, ed è il campo dell'Akron Summit Assault.
#
#
# 291/999
# tripla:  Adisham_Hall architecturalStyle "Tudor and Jacabian" Adisham_Hall location Haputale
# actual:  Adisham Hall, il cui stile architettonico è Tudor e Jacabian, si trova ad Haputale.
# predicted:  La Adisham Hall si trova a Haputale ed è stata progettata in stile Tudor e Jacabian.
#
#
# 292/999
# tripla:  A_Fortress_of_Grey_Ice country United_States United_States ethnicGroup Asian_Americans United_States leaderTitle President_of_the_United_States
# actual:  Una Fortezza di Ghiaccio Grigio proviene dagli Stati Uniti ed è guidata dal Presidente e comprende il gruppo etnico degli asiatici americani.
# predicted:  Una fortezza di ghiaccio grigio proviene dagli Stati Uniti, dove il leader è il Presidente e gli asiatici americani sono un gruppo etnico.
#
#
# 293/999
# tripla:  200_Public_Square completionDate 1985 200_Public_Square floorCount 45 200_Public_Square location Cleveland
# actual:  Il 200 Public Square ha 45 piani, è stato completato nel 1985 e si trova a Cleveland.
# predicted:  200 Public Square, con 45 piani, è stato completato nel 1985 a Cleveland.
#
#
# 294/999
# tripla:  Appleton_International_Airport cityServed Appleton,_Wisconsin Greenville,_Wisconsin country United_States Greenville,_Wisconsin isPartOf Ellington,_Wisconsin Greenville,_Wisconsin isPartOf Dale,_Wisconsin Appleton_International_Airport location Greenville,_Wisconsin
# actual:  L'aeroporto internazionale di Appleton si trova a Greenville, Wisconsin, negli Stati Uniti. L'aeroporto serve Appleton. Greenville fa parte di Ellington e Dale, Wisconsin.
# predicted:  L'aeroporto internazionale di Appleton si trova a Greenville, Wisconsin, che fa parte di Ellington e Dale, Wisconsin, Stati Uniti. L'aeroporto serve la città di Appleton.
#
#
# 295/999
# tripla:  Bananaman broadcastedBy BBC Bananaman creator Steve_Bright Bananaman firstAired "1983-10-03" Bananaman lastAired "1986-04-15" Bananaman starring Graeme_Garden
# actual:  Bananaman è andato in onda per la prima volta sulla BBC il 10/03/1983 e la sua ultima trasmissione è stata il 15 aprile 1986. Il creatore di Bananaman è Steve Bright e lo show ha come protagonista Graeme Garden.
# predicted:  Bananaman è stato trasmesso per la prima volta il 3 ottobre 1983 dalla BBC e il suo ultimo ruolo è stato il 15 aprile 1986. Graeme Garden è il protagonista del film, creato da Steve Bright.
#
#
# 296/999
# tripla:  Alan_B._Miller_Hall architect Robert_A._M._Stern Virginia country United_States Alan_B._Miller_Hall currentTenants Mason_School_of_Business Alan_B._Miller_Hall location Virginia Alan_B._Miller_Hall owner College_of_William_&_Mary
# actual:  La Alan B. Miller Hall, progettata da Robert A M Stern, si trova in Virginia, negli Stati Uniti. L'edificio è di proprietà del College of William and Mary e il suo attuale inquilino è la Mason School of Business.
# predicted:  La Mason School of Business è l'attuale inquilino della Alan B Miller Hall, situata in Virginia, Stati Uniti, progettata da Robert A M Stern. La Mason School of Business è proprietaria della Alan B Miller Hall.
#
#
# 297/999
# tripla:  A.C._Cesena ground Cesena A.C._Cesena league Serie_B A.C._Cesena numberOfMembers 23900
# actual:  L'A.C. Cesena, in Serie B, ha 23900 soci e si trova a Cesena.
# predicted:  L'A.C. Cesena, con 23900 membri, gioca in Serie B e ha sede a Cesena.
#
#
# 298/999
# tripla:  Adolfo_Suárez_Madrid–Barajas_Airport location "Madrid, Paracuellos de Jarama, San Sebastián de los Reyes and Alcobendas" Adolfo_Suárez_Madrid–Barajas_Airport runwayLength 4349.0
# actual:  L'aeroporto Adolfo Suárez Madrid-Barajas (situato a Madrid, Paracuellos de Jarama, San Sebastián de los Reyes e Alcobendas) ha una pista lunga 4349 metri.
# predicted:  L'aeroporto Adolfo Suárez Madrid-Barajas si trova a Madrid, Paracuellos de Jarama, San Sebastián de los Reyes e Alcobendas e ha una pista lunga 4349,0 metri.
#
#
# 299/999
# ...
# actual:  Il personaggio dei fumetti, Balder, è stato creato dall'americano Jack Kirby.
# predicted:  Il personaggio dei fumetti Balder è stato creato dall'americano Jack Kirby.
#
#
# 955/999
# tripla:  Azerbaijan legislature National_Assembly_(Azerbaijan)
# actual:  L'Assemblea nazionale detta la legislatura dell'Azerbaigian.
# predicted:  L'Assemblea nazionale è l'organo legislativo dell'Azerbaigian.
#
#
# 956/999
# tripla:  Antioquia_Department country Colombia Bandeja_paisa ingredient Avocado Bandeja_paisa region Antioquia_Department
# actual:  L'avocado è uno degli ingredienti del piatto Bandeja paisa, che si trova nel dipartimento di Antioquia. Il dipartimento di Antioquia si trova in Colombia.
# predicted:  La bandeja paisa è un piatto del dipartimento di Antioquia, in Colombia. L'avocado è un ingrediente della bandeja paisa.
#
#
# 957/999
# tripla:  Alan_Bean birthPlace Wheeler,_Texas Alan_Bean nationality United_States Alan_Bean occupation Test_pilot
# actual:  Il pilota collaudatore Alan Bean è nato a Wheeler, Texas, USA.
# predicted:  Alan Bean è un cittadino statunitense nato a Wheeler, in Texas.  un pilota collaudatore.
#
#
# 958/999
# tripla:  Amsterdam_Airport_Schiphol runwayName "18C/36C 'Zwanenburgbaan'"
# actual:  Il nome della pista dell'aeroporto Schiphol di Amsterdam è 18C/36C Zwanenburgbaan.
# predicted:  18C/36C 'Zwanenburgbaan' è il nome della pista dell'aeroporto di Amsterdam Schiphol.
#
#
# 959/999
# tripla:  A_Glastonbury_Romance author John_Cowper_Powys John_Cowper_Powys birthPlace Shirley,_Derbyshire Weymouth_Sands followedBy Maiden_Castle_(novel) A_Glastonbury_Romance followedBy Weymouth_Sands
# actual:  A Glastonbury Romance è scritto da John Cowper Powys, nato a Shirley, nel Derbyshire. Il libro è seguito da Weymouth Sands e Maiden Castle.
# predicted:  John Cowper Powys, nato a Shirley, nel Derbyshire, è l'autore di A Glastonbury Romance e del romanzo Maiden Castle. A Glastonbury Romance è seguito da Weymouth Sands.
#
#
# 960/999
# tripla:  Ayam_penyet country Indonesia Ayam_penyet ingredient Fried_chicken
# actual:  L'ayam penyet è un piatto indonesiano che contiene pollo fritto.
# predicted:  Il pollo fritto è un ingrediente dell'Ayam penyet, originario dell'Indonesia.
#
#
# 961/999
# tripla:  Amatriciana_sauce country Italy
# actual:  L'Italia è il paese da cui proviene la salsa amatriciana.
# predicted:  La salsa amatriciana proviene dall'Italia.
#
#
# 962/999
# tripla:  A_Fortress_of_Grey_Ice country United_States United_States ethnicGroup African_Americans A_Fortress_of_Grey_Ice language English_language
# actual:  A Fortress of Grey Ice è scritto in inglese e proviene dagli Stati Uniti, dove vivono alcuni afroamericani.
# predicted:  Una fortezza di ghiaccio grigio proviene dagli Stati Uniti, dove gli afroamericani sono un gruppo etnico. Il libro è scritto in inglese.
#
#
# 963/999
# tripla:  Bibbo_Bibbowski creator Jerry_Ordway Bibbo_Bibbowski creator Marv_Wolfman Jerry_Ordway nationality Americans
# actual:  Bibbo Bibbowski è stato creato da Marv Wolfman e Jerry Ordway, un americano.
# predicted:  Marv Wolfman e Jerry Ordway sono i creatori di Bibbo Bibbowski. Ordway è un americano.
#
#
# 964/999
# tripla:  Al_Asad_Airbase location Iraq Al_Asad_Airbase operatingOrganisation United_States_Air_Force Al_Asad_Airbase runwayLength 3990.0 Al_Asad_Airbase runwayName "09L/27R"
# actual:  Operata dall'Aeronautica Militare degli Stati Uniti, la base aerea di Al Asad si trova in Iraq. Il nome della pista è 09L/27R e la lunghezza della pista è di 3990,0.
# predicted:  La base aerea di Al Asad, in Iraq, è gestita dall'aeronautica militare degli Stati Uniti e ha una pista lunga 3990,0 metri. Il nome della pista è 09L/27R.
#
#
# 965/999
# tripla:  Akron_Summit_Assault manager Denzil_Antonio Akron_Summit_Assault numberOfMembers 3000
# actual:  Denzil Antonio è il direttore dell'Akron Summit Assault, che conta 3000 membri.
# predicted:  Denzil Antonio è l'allenatore dell'Akron Summit Assault, che conta 3000 membri.
#
#
# 966/999
# tripla:  Bacon_sandwich alternativeName "Bacon butty, bacon sarnie, rasher sandwich, bacon sanger, piece 'n bacon, bacon cob, bacon barm, bacon muffin" Bacon_sandwich country United_Kingdom Bacon_sandwich ingredient Bacon
# actual:  Popolare nel Regno Unito, il panino al bacon include l'ingrediente pancetta e può essere conosciuto anche come bacon butty, bacon sarnie, rasher sandwich, bacon sanger, piece 'n bacon, bacon cob, bacon barm o bacon muffin.
# predicted:  Il panino al bacon è un piatto del Regno Unito che pu essere conosciuto anche come bacon butty, bacon sarnie, rasher sandwich, bacon sanger, piece 'n bacon, bacon cob, bacon barm o bacon muffin.
#
#
# 967/999
# tripla:  Amatriciana_sauce country Italy Amatriciana_sauce ingredient Guanciale
# actual:  Il guanciale è un ingrediente della tradizionale salsa amatriciana italiana.
# predicted:  Il guanciale è un ingrediente della salsa amatriciana, originaria dell'Italia.
#
#
# 968/999
# tripla:  AWH_Engineering_College academicStaffSize 250 AWH_Engineering_College country India India largestCity Mumbai India river Ganges
# actual:  L'AWH Engineering College (India) ha uno staff accademico di 250 persone. La città più grande dell'India è Mumbai e uno dei fiumi del Paese è il Gange.
# predicted:  L'AWH Engineering College si trova in India, dove la città più grande è Mumbai e il fiume Gange è uno dei suoi fiumi. Il college conta 250 membri del personale accademico.
#
#
# 969/999
# tripla:  Luciano_Spalletti club Virtus_Entella
# actual:  Luciano Spalletti era al club Virtus Entella.
# predicted:  Luciano Spalletti gioca per la Virtus Entella.
#
#
# 970/999
# tripla:  1634:_The_Bavarian_Crisis author Eric_Flint Eric_Flint birthPlace Burbank,_California 1634:_The_Bavarian_Crisis precededBy The_Grantville_Gazettes
# actual:  Eric Flint, nato a Burbank, California, è l'autore di 1634: The Bavarian Crisis, il seguito di The Grantville Gazettes.
# predicted:  Eric Flint, nato a Burbank, California, è l'autore di 1634: The Bavarian Crisis, preceduto da The Grantville Gazettes.
#
#
# 971/999
# tripla:  Ajoblanco alternativeName "Ajo blanco" Ajoblanco country Spain Ajoblanco ingredient Bread
# actual:  Dalla Spagna, l'Ajoblanco (conosciuto anche come Ajo blanco) ha come ingrediente il pane.
# predicted:  L'ajoblanco (nome alternativo: Ajo blanco) è un piatto tradizionale della Spagna che contiene pane.
#
#
# 972/999
# tripla:  Adisham_Hall architecturalStyle Tudor_Revival_architecture Adisham_Hall buildingStartDate "1927" Adisham_Hall completionDate 1931 Adisham_Hall location Sri_Lanka
# actual:  La costruzione dell'Adisham Hall in Sri Lanka iniziò nel 1927 e terminò nel 1931. È stata costruita in stile architettonico Tudor Revival.
# predicted:  La costruzione dell'Adisham Hall, in stile Tudor Revival, è iniziata nel 1927 ed è stata completata nel 1931. L'Adisham Hall si trova nello Sri Lanka.
#
#
# 973/999
# tripla:  Bacon_sandwich country United_Kingdom Bacon_sandwich dishVariation BLT Bacon_sandwich ingredient Condiment
# actual:  I panini al bacon sono una variante del BLT e provengono dal Regno Unito, dove si trovano anche i condimenti.
# predicted:  Il bacon sandwich è un piatto del Regno Unito che contiene condimenti ed è una variante del BLT.
#
#
# 974/999
# tripla:  A_Wizard_of_Mars publisher Harcourt_(publisher)
# actual:  Un mago di Marte è stato pubblicato da Harcourt.
# predicted:  Un mago di Marte è stato pubblicato da Harcourt.
#
#
# 975/999
# tripla:  Bananaman broadcastedBy "STV" Bananaman firstAired "1983-10-03" Bananaman starring Bill_Oddie
# actual:  Bill Oddie ha recitato in Bananaman, andato in onda per la prima volta il 3 ottobre 1983 e trasmesso da STV.
# predicted:  Bananaman, interpretato da Bill Oddie, è stato trasmesso per la prima volta il 3 ottobre 1983 da STV.
#
#
# 976/999
# tripla:  National_League_North champions Barrow_A.F.C. A.F.C._Fylde league National_League_North
# actual:  La squadra del Barrow A.F.C. ha vinto il campionato nella National League North, dove gioca anche l'A.F.C. Fylde.
# predicted:  L'AFC Fylde gioca nella National League North, il cui campion è l'A.F.C. Barrow.
#
#
# 977/999
# tripla:  William_Anders birthDate "1933-10-17" William_Anders birthPlace British_Hong_Kong William_Anders dateOfRetirement "1969-09-01" William_Anders nationality United_States
# actual:  William Anders è un cittadino statunitense nato nella Hong Kong britannica il 17 ottobre 1933 e andato in pensione il 1° gennaio 1969.
# predicted:  William Anders è nato nella britannica Hong Kong il 17 ottobre 1933 e si è ritirato il 1° settembre 1969.  cittadino statunitense.
#
#
# 978/999
# tripla:  Akita_Museum_of_Art floorArea 3746.66 (square metres) Akita_Museum_of_Art floorCount 3 Akita_Museum_of_Art inaugurationDate "2013-09-28"
# actual:  Il Museo d'Arte di Akita ha una superficie di 3746,66 metri quadrati su 3 piani ed è stato inaugurato il 28 settembre 2013.
# predicted:  Il Museo d'Arte di Akita ha 3 piani e una superficie di 3746,66 metri quadrati.  stato inaugurato il 28 settembre 2013.
#
#
# 979/999
# tripla:  Denmark language German_language
# actual:  Il tedesco è la lingua parlata in Danimarca.
# predicted:  Il tedesco è una delle lingue parlate in Danimarca.
#
#
# 980/999
# tripla:  Allama_Iqbal_International_Airport location Pakistan Allama_Iqbal_International_Airport runwayLength 3360.12 Allama_Iqbal_International_Airport runwayName "18L/36R"
# actual:  L'aeroporto internazionale Allama Iqbal, situato in Pakistan, ha una pista lunga 3360,12 metri. Il nome della pista è 18L/36R.
# predicted:  L'aeroporto internazionale Allama Iqbal si trova in Pakistan e ha una pista denominata 18L/36R, lunga 3360,12 metri.
#
#
# 981/999
# tripla:  3Arena location North_Wall,_Dublin 3Arena owner Live_Nation_Entertainment
# actual:  La 3Arena si trova a North Wall, Dublino, ed è di proprietà di Live Nation Entertainment.
# predicted:  La 3Arena si trova a North Wall, Dublino, ed è di proprietà di Live Nation Entertainment.
#
#
# 982/999
# tripla:  Baked_Alaska country United_States United_States ethnicGroup African_Americans United_States leaderTitle President_of_the_United_States
# actual:  Il Presidente è il leader degli Stati Uniti. Un gruppo etnico è quello degli afroamericani. Il dessert, l'omelette norvegese, è originario degli Stati Uniti.
# predicted:  L'omelette norvegese proviene dagli Stati Uniti, dove il leader è il Presidente e gli afroamericani sono un gruppo etnico.
#
#
# 983/999
# tripla:  Virginia country United_States Alan_B._Miller_Hall currentTenants Mason_School_of_Business Alan_B._Miller_Hall location Virginia Alan_B._Miller_Hall owner College_of_William_&_Mary
# actual:  L'Alan B Miller Hall, di proprietà del College of William and Mary, con la Mason School of Business come attuale inquilino, si trova in Virginia, Stati Uniti.
# predicted:  La Mason School of Business è l'attuale inquilino della Alan B Miller Hall, situata in Virginia, Stati Uniti, e di proprietà del College of William and Mary.
#
#
# 984/999
# tripla:  Adisham_Hall address "St. Benedict's Monastery, Adisham, Haputhale, Sri Lanka" Adisham_Hall architecturalStyle Tudor_Revival_architecture Adisham_Hall buildingStartDate "1927" Adisham_Hall completionDate 1931 Adisham_Hall location Sri_Lanka
# actual:  La Adisham Hall è stata costruita tra il 1927 e il 1931 presso il monastero di San Benedetto, Adisham, Haputhale, Sri Lanka, in stile Tudor Revival.
# predicted:  La costruzione dell'Adisham Hall, in stile Tudor Revival, è iniziata nel 1927 ed è stata completata nel 1931. L'Adisham Hall si trova ad Adisham, Adisham, Haputhale, Sri Lanka. Il monastero di San Benedetto è l'indirizzo dell'Adisham Hall.
#
#
# 985/999
# tripla:  United_States leaderTitle President_of_the_United_States
# actual:  Il leader degli Stati Uniti è noto come Presidente degli Stati Uniti.
# predicted:  Il leader degli Stati Uniti è chiamato Presidente degli Stati Uniti.
#
#
# 986/999
# tripla:  Bandeja_paisa country Colombian_cuisine Bandeja_paisa ingredient Fried_egg
# actual:  La bandeja paisa è un piatto tipico della cucina colombiana e comprende un uovo fritto.
# predicted:  L'ovo fritto è un ingrediente della Bandeja paisa, un piatto colombiano.
#
#
# 987/999
# tripla:  Auburn,_Washington populationDensity 914.8 (inhabitants per square kilometre)
# actual:  Auburn, Washington, ha una densità di popolazione di 914,8 abitanti per chilometro quadrato.
# predicted:  Auburn, Washington, ha una densità di popolazione di 914,8 abitanti per chilometro quadrato.
#
#
# 988/999
# tripla:  Asam_pedas country Malaysia Malaysia ethnicGroup Malaysian_Malay Sumatra ethnicGroup Minangkabau_people Asam_pedas region Sumatra
# actual:  L'asam pedas è un alimento diffuso in Malesia e a Sumatra. La Malesia è un gruppo etnico della Malesia e Sumatra ha un gruppo etnico chiamato Minangkabau.
# predicted:  L'asam pedas è un piatto tradizionale di Sumatra, in Malesia. I malesi malesi sono un gruppo etnico di Sumatra, dove i minangkabau sono un gruppo etnico.
#
#
# 989/999
# tripla:  AZAL_Arena location Azerbaijan
# actual:  L'AZAL Arena si trova in Azerbaigian.
# predicted:  L'AZAL Arena si trova in Azerbaigian.
#
#
# 990/999
# tripla:  Alan_B._Miller_Hall architecturalStyle Georgian_architecture Alan_B._Miller_Hall location Williamsburg,_Virginia Alan_B._Miller_Hall owner College_of_William_&_Mary
# actual:  Il College of William and Mary è proprietario della Alan B. Miller Hall in stile georgiano a Williamsburg, Virginia.
# predicted:  La Alan B. Miller Hall, di proprietà del College of William and Mary, si trova a Williamsburg, in Virginia, ed è in stile architettonico georgiano.
#
#
# 991/999
# tripla:  Bandeja_paisa country Colombian_cuisine Bandeja_paisa ingredient Hogao Bandeja_paisa region Antioquia_Department
# actual:  La bandeja paisa include l'hogao come ingrediente ed è un piatto colombiano della regione del dipartimento di Antioquia.
# predicted:  La bandeja paisa è un piatto colombiano della regione del dipartimento di Antioquia e contiene l'hogao.
#
#
# 992/999
# tripla:  Asterix_(comicsCharacter) alternativeName "Astérix" Asterix_(comicsCharacter) creator René_Goscinny Asterix_(comicsCharacter) creator Albert_Uderzo
# actual:  Il personaggio dei fumetti Asterix è stato creato da René Goscinny e Albert Uderzo.
# predicted:  Il personaggio dei fumetti Asterix, con il nome alternativo di Astérix, è stato creato da René Goscinny e Albert Uderzo.
#
#
# 993/999
# tripla:  Gus_Poyet club Real_Zaragoza AEK_Athens_F.C. manager Gus_Poyet
# actual:  L'AEK Atene è gestito da Gus Poyet, che è nel club Real Zaragoza.
# predicted:  Gus Poyet è l'allenatore dell'AEK Athens FC e gioca per il Real Zaragoza.
#
#
# 994/999
# tripla:  1634:_The_Bavarian_Crisis author "Virginia DeMarce and Eric Flint" 1634:_The_Bavarian_Crisis precededBy Grantville_Gazette_II Grantville_Gazette_II precededBy The_Grantville_Gazette
# actual:  Scritto da Virginia DeMarce ed Eric Flint, 1634: The Bavarian Crisis è stato preceduto da Grantville Gazette II, a sua volta preceduto da The Grantville Gazette.
# predicted:  1634: The Bavarian Crisis è stato scritto da Virginia DeMarce ed Eric Flint ed è stato preceduto da Grantville Gazette II e The Grantville Gazette.
#
#
# 995/999
# tripla:  300_North_LaSalle floorCount 60
# actual:  Al 300 North LaSalle ci sono 60 piani.
# predicted:  Il 300 North LaSalle ha 60 piani.
#
#
# 996/999
# tripla:  United_States leader Joe_Biden
# actual:  Joe Biden è il leader degli Stati Uniti.
# predicted:  Joe Biden è un leader degli Stati Uniti.
#
#
# 997/999
# tripla:  United_States leaderTitle President_of_the_United_States
# actual:  Il leader degli Stati Uniti è noto come Presidente degli Stati Uniti.
# predicted:  Il leader degli Stati Uniti è chiamato Presidente degli Stati Uniti.
#
#
# 998/999
# tripla:  Chicago country United_States Chicago isPartOf DuPage_County,_Illinois 300_North_LaSalle location Chicago
# actual:  300 North LaSalle si trova a Chicago, nella Contea di Dupage, Illinois, Stati Uniti.
# predicted:  300 North LaSalle si trova a Chicago, nella contea di DuPage, Illinois, Stati Uniti.
#
#
# 999/999
# tripla:  Illinois country United_States 300_North_LaSalle location Illinois
# actual:  300 North LaSalle si trova in Illinois, negli Stati Uniti.
# predicted:  300 North LaSalle si trova in Illinois, negli Stati Uniti.
