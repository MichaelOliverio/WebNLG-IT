# %%
#utils
import pandas as pd
import os
import numpy as np
from nltk.tokenize import word_tokenize

# %%
dataset_names = [
    'test_0',
]

# %% [markdown]
# ## FUNCTIONS

# %%
def merge_dicts(dict1, dict2):
    #print(f'START MERGE_DICTS')
    merged_dict = {}
    for key, value in dict1.items():
        merged_dict[key] = dict1[key]

        if key in dict2:
            for triple in value:
                flag = True
                for key, value in merged_dict.items():
                    if triple in value:
                        flag = False
                        break

                if flag:
                    merged_dict[key].insert(0, triple)
        else:
            merged_dict[key] = value

    keys = list(merged_dict.keys())
    values = list(merged_dict.values())
    keys = [str(i) for i in range(len(keys))]
    merged_dict = dict(zip(keys, values))

    #print(f'END MERGE_DICTS')
    return merged_dict

def split_mixed(triples):
    subject_dict = {}
    object_dict = {}
    #print(f'START SPLIT_MIXED')
    for triple in triples:
        triple = triple.split(' ')

        if len(triple) > 1:
            # sibling
            subject = triple[0]

            if subject in subject_dict:
                subject_dict[subject].append(triple)
            else:
                subject_dict[subject] = [triple]

            # chain
            object = triple[0]

            for triple in triples:
                triple = triple.split(' ')

                if len(triple) > 1:
                    if triple[2] == object:
                        if object in object_dict:
                            object_dict[object].append(triple)
                        else:
                            object_dict[object] = [triple]

    #print(f'subject_dict: {subject_dict}')
    #print(f'object_dict: {object_dict}')

    merged_dict = merge_dicts(subject_dict, object_dict)

    #print(f'END SPLIT_MIXED')
    return merged_dict

# %%
#splitta il dizionario in gruppi di 3 nel caso ci fossero chiavi con piu di 3 valori
def split_dict(dict_to_split):
    new_dict = {}
    for key, value in dict_to_split.items():
        num_chunks = (len(value) + 2) // 3  # Calcoliamo il numero di chunk necessari
        for i in range(num_chunks):
            new_key = f"{key}_{i}" if i > 0 else key  # Creiamo una nuova chiave con indice se necessario
            start = i * 3
            end = min((i + 1) * 3, len(value))
            new_dict[new_key] = value[start:end]  # Aggiungiamo i valori corrispondenti
    return new_dict

# %%
def create_dict_with_max_values(array, max_values_per_key):
    array = [triple for triple in array if triple.strip()]  # Rimuovi le stringhe vuote
    result_dict = {}
    current_key_index = 0
    current_key_values = []
    for triple in array:
        current_key_values.append(triple.split(' '))
        if len(current_key_values) == max_values_per_key:
            result_dict[current_key_index] = current_key_values
            current_key_index += 1
            current_key_values = []
    # Aggiungi eventuali valori rimanenti
    if current_key_values:
        result_dict[current_key_index] = current_key_values
    return result_dict

# %% [markdown]
# ## MAIN

# %%
for dataset_name in dataset_names:
    print(f'Processing {dataset_name}')
    full_dataset = pd.read_csv(f'{dataset_name}.csv')
    dataset = full_dataset

    triples_dict = {}
    j = 0
    for i in range(len(dataset)):
        triples = dataset['data_unit'][i].split(' | ')

        if (dataset['shape_type'][i] == 'mixed' or dataset['shape_type'][i] == 'NA' or dataset['shape_type'][i] == 'unknown') and dataset['size'][i] > 3:
            dictionary = split_mixed(triples)
            dictionary = split_dict(dictionary)
        else:
            dictionary = create_dict_with_max_values(triples, 3)
            
        print(f'index: {i}')
        print(f'triples: {triples}')
        print(f'dictionary: {dictionary}')

        if dataset['size'][i] > 3:
            for key, value in dictionary.items():
                value_text = ''
                for triple in value:
                    value_text += ' '.join(triple) + ' '

                triples_dict[j] = {
                    'eid': dataset['eid'][i],
                    'category': dataset['category'][i],
                    'global_size': dataset['size'][i],
                    'local_size': len(value),
                    'global_shape_type': dataset['shape_type'][i],
                    'global_data_unit': dataset['data_unit'][i],
                    'local_data_unit': value_text,
                    'actual_sentences': dataset['sentence'][i],
                }

                j += 1

    triples_df = pd.DataFrame.from_dict(triples_dict, "index")
    triples_df.to_csv(f'test_1.csv', index=False)

    triples_df.head()
# Out:
# Processing test_0
# index: 0
# triples: ['Brandon_Carter knownFor Doomsday_argument']
# dictionary: {0: [['Brandon_Carter', 'knownFor', 'Doomsday_argument']]}
# index: 1
# triples: ['Piotr_Hallmann birthPlace Gdynia,_Poland', 'Gdynia,_Poland timeZone Central_European_Time', 'Piotr_Hallmann weight 70.308']
# dictionary: {0: [['Piotr_Hallmann', 'birthPlace', 'Gdynia,_Poland'], ['Gdynia,_Poland', 'timeZone', 'Central_European_Time'], ['Piotr_Hallmann', 'weight', '70.308']]}
# index: 2
# triples: ['Darinka_Dentcheva influencedBy Andrzej_Piotr_Ruszczyński', 'Darinka_Dentcheva professionalField Mathematical_optimization']
# dictionary: {0: [['Darinka_Dentcheva', 'influencedBy', 'Andrzej_Piotr_Ruszczyński'], ['Darinka_Dentcheva', 'professionalField', 'Mathematical_optimization']]}
# index: 3
# triples: ['Istanbul utcOffset +2']
# dictionary: {0: [['Istanbul', 'utcOffset', '+2']]}
# index: 4
# triples: ['Nie_Haisheng birthDate 1964-10-13', "Nie_Haisheng nationality People's_Republic_of_China"]
# dictionary: {0: [['Nie_Haisheng', 'birthDate', '1964-10-13'], ['Nie_Haisheng', 'nationality', "People's_Republic_of_China"]]}
# index: 5
# triples: ['Ciudad_Ayala country Mexico', 'Ciudad_Ayala governmentType Council-manager_government', 'Ciudad_Ayala leaderTitle "City Manager"', 'Ciudad_Ayala populationDensity 1604.0', 'Ciudad_Ayala populationMetro 1777539', 'Ciudad_Ayala type City', 'Ciudad_Ayala utcOffset −6']
# dictionary: {0: [['Ciudad_Ayala', 'country', 'Mexico'], ['Ciudad_Ayala', 'governmentType', 'Council-manager_government'], ['Ciudad_Ayala', 'leaderTitle', '"City', 'Manager"']], 1: [['Ciudad_Ayala', 'populationDensity', '1604.0'], ['Ciudad_Ayala', 'populationMetro', '1777539'], ['Ciudad_Ayala', 'type', 'City']], 2: [['Ciudad_Ayala', 'utcOffset', '−6']]}
# index: 6
# triples: ['Olga_Bondareva almaMater Leningrad_State_University', 'Olga_Bondareva birthDate 1937-04-27', 'Olga_Bondareva birthName "Olga Nikolaevna Bondareva"', 'Olga_Bondareva birthPlace Leningrad,_USSR', 'Olga_Bondareva knownFor Bondareva–Shapley_theorem']
# dictionary: {0: [['Olga_Bondareva', 'almaMater', 'Leningrad_State_University'], ['Olga_Bondareva', 'birthDate', '1937-04-27'], ['Olga_Bondareva', 'birthName', '"Olga', 'Nikolaevna', 'Bondareva"']], 1: [['Olga_Bondareva', 'birthPlace', 'Leningrad,_USSR'], ['Olga_Bondareva', 'knownFor', 'Bondareva–Shapley_theorem']]}
# index: 7
# triples: ['Alan_B._Miller_Hall address "101 Ukrop Way"', 'Mason_School_of_Business country United_States', 'Alan_B._Miller_Hall currentTenants Mason_School_of_Business', 'Alan_B._Miller_Hall location Virginia']
# dictionary: {'0': [['Alan_B._Miller_Hall', 'address', '"101', 'Ukrop', 'Way"'], ['Alan_B._Miller_Hall', 'currentTenants', 'Mason_School_of_Business'], ['Alan_B._Miller_Hall', 'location', 'Virginia']], '1': [['Mason_School_of_Business', 'country', 'United_States']]}
# index: 8
# triples: ['Bedford_Aerodrome elevationAboveTheSeaLevel 83.2104', 'Bedford_Aerodrome runwayLength 1095.0']
# dictionary: {0: [['Bedford_Aerodrome', 'elevationAboveTheSeaLevel', '83.2104'], ['Bedford_Aerodrome', 'runwayLength', '1095.0']]}
# index: 9
# triples: ['Nie_Haisheng birthDate 1964-10-13', "Nie_Haisheng nationality People's_Republic_of_China", 'Nie_Haisheng occupation Fighter_pilot']
# dictionary: {0: [['Nie_Haisheng', 'birthDate', '1964-10-13'], ['Nie_Haisheng', 'nationality', "People's_Republic_of_China"], ['Nie_Haisheng', 'occupation', 'Fighter_pilot']]}
# index: 10
# triples: ['Abraham_A._Ribicoff birthPlace United_States', 'Abraham_A._Ribicoff nationality American', 'Abraham_A._Ribicoff office "United States Secretary of Health, Education, and Welfare"', 'Abraham_A._Ribicoff spouse "Ruth Ribicoff"']
# dictionary: {0: [['Abraham_A._Ribicoff', 'birthPlace', 'United_States'], ['Abraham_A._Ribicoff', 'nationality', 'American'], ['Abraham_A._Ribicoff', 'office', '"United', 'States', 'Secretary', 'of', 'Health,', 'Education,', 'and', 'Welfare"']], 1: [['Abraham_A._Ribicoff', 'spouse', '"Ruth', 'Ribicoff"']]}
# index: 11
# triples: ['Andrew_Rayel associatedBand/associatedMusicalArtist Armin_van_Buuren', 'Andrew_Rayel genre Trance_music']
# dictionary: {0: [['Andrew_Rayel', 'associatedBand/associatedMusicalArtist', 'Armin_van_Buuren'], ['Andrew_Rayel', 'genre', 'Trance_music']]}
# index: 12
# triples: ['Reşadiye isPartOf Tokat_Province']
# dictionary: {0: [['Reşadiye', 'isPartOf', 'Tokat_Province']]}
# index: 13
# triples: ['ENAIRE city Madrid', 'Madrid country Spain', 'Adolfo_Suárez_Madrid–Barajas_Airport location Alcobendas', 'Adolfo_Suárez_Madrid–Barajas_Airport operatingOrganisation ENAIRE', 'Adolfo_Suárez_Madrid–Barajas_Airport runwayLength 4349.0', 'Adolfo_Suárez_Madrid–Barajas_Airport runwayName "14L/32R"']
# dictionary: {'0': [['ENAIRE', 'city', 'Madrid']], '1': [['Madrid', 'country', 'Spain']], '2': [['Adolfo_Suárez_Madrid–Barajas_Airport', 'location', 'Alcobendas'], ['Adolfo_Suárez_Madrid–Barajas_Airport', 'operatingOrganisation', 'ENAIRE'], ['Adolfo_Suárez_Madrid–Barajas_Airport', 'runwayLength', '4349.0']], '2_1': [['Adolfo_Suárez_Madrid–Barajas_Airport', 'runwayName', '"14L/32R"']]}
# index: 14
# triples: ['Nicholas_Brodszky background non_performing_personnel', 'English_Without_Tears musicComposer Nicholas_Brodszky', 'English_Without_Tears producer Anatole_de_Grunwald', 'English_Without_Tears releaseDate 1944-07-28']
# dictionary: {'0': [['Nicholas_Brodszky', 'background', 'non_performing_personnel']], '1': [['English_Without_Tears', 'musicComposer', 'Nicholas_Brodszky'], ['English_Without_Tears', 'producer', 'Anatole_de_Grunwald'], ['English_Without_Tears', 'releaseDate', '1944-07-28']]}
# index: 15
# triples: ['India leaderTitle President']
# dictionary: {0: [['India', 'leaderTitle', 'President']]}
# index: 16
# triples: ['ALCO_RS-3 buildDate "May 1950 - August 1956"', 'ALCO_RS-3 builder American_Locomotive_Company', 'ALCO_RS-3 length 17068.8 (millimetres)', 'ALCO_RS-3 totalProduction 1418']
# dictionary: {0: [['ALCO_RS-3', 'buildDate', '"May', '1950', '-', 'August', '1956"'], ['ALCO_RS-3', 'builder', 'American_Locomotive_Company'], ['ALCO_RS-3', 'length', '17068.8', '(millimetres)']], 1: [['ALCO_RS-3', 'totalProduction', '1418']]}
# index: 17
# triples: ['Mermaid_(Train_song) recordLabel Sony_Music_Entertainment']
# dictionary: {0: [['Mermaid_(Train_song)', 'recordLabel', 'Sony_Music_Entertainment']]}
# index: 18
# triples: ['La_Crosse,_Wisconsin leaderTitle Mayor']
# dictionary: {0: [['La_Crosse,_Wisconsin', 'leaderTitle', 'Mayor']]}
# index: 19
# triples: ['McVeagh_of_the_South_Seas distributor Alliance_Films_Corporation']
# dictionary: {0: [['McVeagh_of_the_South_Seas', 'distributor', 'Alliance_Films_Corporation']]}
# index: 20
# triples: ['The_Velvet_Underground associatedBand/associatedMusicalArtist Theatre_of_Eternal_Music']
# dictionary: {0: [['The_Velvet_Underground', 'associatedBand/associatedMusicalArtist', 'Theatre_of_Eternal_Music']]}
# index: 21
# triples: ['Expect_a_Miracle artist Brian_Kelly_(composer_&_pianist)', 'Expect_a_Miracle precededBy Pools_of_Light_(Brian_Kelly_album)', 'Expect_a_Miracle runtime 54.56', 'Expect_a_Miracle type Compilation_Album']
# dictionary: {0: [['Expect_a_Miracle', 'artist', 'Brian_Kelly_(composer_&_pianist)'], ['Expect_a_Miracle', 'precededBy', 'Pools_of_Light_(Brian_Kelly_album)'], ['Expect_a_Miracle', 'runtime', '54.56']], 1: [['Expect_a_Miracle', 'type', 'Compilation_Album']]}
# index: 22
# triples: ['Brandon_Carter almaMater University_of_Cambridge', 'Brandon_Carter birthDate 1942-01-01', 'Brandon_Carter professionalField General_relativity']
# dictionary: {0: [['Brandon_Carter', 'almaMater', 'University_of_Cambridge'], ['Brandon_Carter', 'birthDate', '1942-01-01'], ['Brandon_Carter', 'professionalField', 'General_relativity']]}
# index: 23
# triples: ['Agremiação_Sportiva_Arapiraquense league Campeonato_Brasileiro_Série_C', 'Agremiação_Sportiva_Arapiraquense season 2015_Campeonato_Brasileiro_Série_C']
# dictionary: {0: [['Agremiação_Sportiva_Arapiraquense', 'league', 'Campeonato_Brasileiro_Série_C'], ['Agremiação_Sportiva_Arapiraquense', 'season', '2015_Campeonato_Brasileiro_Série_C']]}
# index: 24
# triples: ['Big_Hero_6_(film) distributor Walt_Disney_Studios_Motion_Pictures', 'Baymax series Big_Hero_6_(film)']
# dictionary: {0: [['Big_Hero_6_(film)', 'distributor', 'Walt_Disney_Studios_Motion_Pictures'], ['Baymax', 'series', 'Big_Hero_6_(film)']]}
# index: 25
# triples: ['McVeagh_of_the_South_Seas distributor Alliance_Films_Corporation', 'McVeagh_of_the_South_Seas imdbId 0004319', 'McVeagh_of_the_South_Seas producer The_Progressive_Motion_Picture_Company', 'McVeagh_of_the_South_Seas starring Harry_Carey_(actor_born_1878)', 'McVeagh_of_the_South_Seas writer Harry_Carey_(actor_born_1878)']
# dictionary: {0: [['McVeagh_of_the_South_Seas', 'distributor', 'Alliance_Films_Corporation'], ['McVeagh_of_the_South_Seas', 'imdbId', '0004319'], ['McVeagh_of_the_South_Seas', 'producer', 'The_Progressive_Motion_Picture_Company']], 1: [['McVeagh_of_the_South_Seas', 'starring', 'Harry_Carey_(actor_born_1878)'], ['McVeagh_of_the_South_Seas', 'writer', 'Harry_Carey_(actor_born_1878)']]}
# index: 26
# triples: ['Imagine_(John_Lennon_song) certification FIMI']
# dictionary: {0: [['Imagine_(John_Lennon_song)', 'certification', 'FIMI']]}
# index: 27
# triples: ['University_of_Burgundy numberOfStudents 27400']
# dictionary: {0: [['University_of_Burgundy', 'numberOfStudents', '27400']]}
# index: 28
# triples: ['Turn_Me_On_(album) artist The_Honeymoon_Killers_(American_band)', 'Turn_Me_On_(album) precededBy Let_It_Breed', 'Turn_Me_On_(album) producer The_Honeymoon_Killers_(American_band)', 'Turn_Me_On_(album) runtime 35.1']
# dictionary: {0: [['Turn_Me_On_(album)', 'artist', 'The_Honeymoon_Killers_(American_band)'], ['Turn_Me_On_(album)', 'precededBy', 'Let_It_Breed'], ['Turn_Me_On_(album)', 'producer', 'The_Honeymoon_Killers_(American_band)']], 1: [['Turn_Me_On_(album)', 'runtime', '35.1']]}
# index: 29
# triples: ['Piotr_Hallmann birthDate 1987-08-25', 'Piotr_Hallmann birthPlace Gdynia,_Poland']
# dictionary: {0: [['Piotr_Hallmann', 'birthDate', '1987-08-25'], ['Piotr_Hallmann', 'birthPlace', 'Gdynia,_Poland']]}
# index: 30
# triples: ['The_Two_Towers precededBy The_Fellowship_of_the_Ring']
# dictionary: {0: [['The_Two_Towers', 'precededBy', 'The_Fellowship_of_the_Ring']]}
# index: 31
# triples: ['Super_Capers budget 2000000.0', 'Super_Capers distributor Roadside_Attractions', 'Super_Capers distributor Lionsgate', 'Super_Capers editing Stacy_Katzman', 'Super_Capers language English_language', 'Super_Capers runtime 98.0', 'Super_Capers writer Ray_Griggs_(director)']
# dictionary: {0: [['Super_Capers', 'budget', '2000000.0'], ['Super_Capers', 'distributor', 'Roadside_Attractions'], ['Super_Capers', 'distributor', 'Lionsgate']], 1: [['Super_Capers', 'editing', 'Stacy_Katzman'], ['Super_Capers', 'language', 'English_language'], ['Super_Capers', 'runtime', '98.0']], 2: [['Super_Capers', 'writer', 'Ray_Griggs_(director)']]}
# index: 32
# triples: ['Liselotte_Grschebina birthDate 1908-05-02', 'Liselotte_Grschebina birthPlace Karlsruhe', 'Liselotte_Grschebina birthPlace German_Empire', 'Liselotte_Grschebina deathDate 1994-06-14', 'Liselotte_Grschebina deathPlace Israel', 'Liselotte_Grschebina nationality Israel']
# dictionary: {0: [['Liselotte_Grschebina', 'birthDate', '1908-05-02'], ['Liselotte_Grschebina', 'birthPlace', 'Karlsruhe'], ['Liselotte_Grschebina', 'birthPlace', 'German_Empire']], 1: [['Liselotte_Grschebina', 'deathDate', '1994-06-14'], ['Liselotte_Grschebina', 'deathPlace', 'Israel'], ['Liselotte_Grschebina', 'nationality', 'Israel']]}
# index: 33
# triples: ['Ciudad_Ayala country Mexico', 'Ciudad_Ayala elevationAboveTheSeaLevel 1147.0', 'Ciudad_Ayala isPartOf Morelos', 'Ciudad_Ayala leaderTitle Governator', 'Ciudad_Ayala populationDensity 1604.0', 'Ciudad_Ayala timeZone Pacific_Daylight_Time', 'Ciudad_Ayala type City']
# dictionary: {0: [['Ciudad_Ayala', 'country', 'Mexico'], ['Ciudad_Ayala', 'elevationAboveTheSeaLevel', '1147.0'], ['Ciudad_Ayala', 'isPartOf', 'Morelos']], 1: [['Ciudad_Ayala', 'leaderTitle', 'Governator'], ['Ciudad_Ayala', 'populationDensity', '1604.0'], ['Ciudad_Ayala', 'timeZone', 'Pacific_Daylight_Time']], 2: [['Ciudad_Ayala', 'type', 'City']]}
# index: 34
# triples: ['11th_Mississippi_Infantry_Monument category Contributing_property', '11th_Mississippi_Infantry_Monument country "United States"', 'Adams_County,_Pennsylvania hasToItsSoutheast Carroll_County,_Maryland', '11th_Mississippi_Infantry_Monument location Adams_County,_Pennsylvania']
# dictionary: {'0': [['11th_Mississippi_Infantry_Monument', 'category', 'Contributing_property'], ['11th_Mississippi_Infantry_Monument', 'country', '"United', 'States"'], ['11th_Mississippi_Infantry_Monument', 'location', 'Adams_County,_Pennsylvania']], '1': [['Adams_County,_Pennsylvania', 'hasToItsSoutheast', 'Carroll_County,_Maryland']]}
# index: 35
# triples: ['Mermaid_(Train_song) followedBy Imagine_(John_Lennon_song)', 'Mermaid_(Train_song) genre Pop_rock', 'Mermaid_(Train_song) genre Reggae', "Mermaid_(Train_song) precededBy This'll_Be_My_Year", 'Mermaid_(Train_song) producer Espionage_(production_team)', 'Mermaid_(Train_song) releaseDate 2012-12-27', 'Mermaid_(Train_song) runtime 3.16']
# dictionary: {0: [['Mermaid_(Train_song)', 'followedBy', 'Imagine_(John_Lennon_song)'], ['Mermaid_(Train_song)', 'genre', 'Pop_rock'], ['Mermaid_(Train_song)', 'genre', 'Reggae']], 1: [['Mermaid_(Train_song)', 'precededBy', "This'll_Be_My_Year"], ['Mermaid_(Train_song)', 'producer', 'Espionage_(production_team)'], ['Mermaid_(Train_song)', 'releaseDate', '2012-12-27']], 2: [['Mermaid_(Train_song)', 'runtime', '3.16']]}
# index: 36
# triples: ['Turn_Me_On_(album) genre Noise_rock']
# dictionary: {0: [['Turn_Me_On_(album)', 'genre', 'Noise_rock']]}
# index: 37
# triples: ['Piotr_Hallmann birthPlace Gdynia,_Poland', 'Piotr_Hallmann weight 70.308']
# dictionary: {0: [['Piotr_Hallmann', 'birthPlace', 'Gdynia,_Poland'], ['Piotr_Hallmann', 'weight', '70.308']]}
# index: 38
# triples: ['Israel longName "State of Israel"']
# dictionary: {0: [['Israel', 'longName', '"State', 'of', 'Israel"']]}
# index: 39
# triples: ['Nord_(Year_of_No_Light_album) genre Sludge_metal', 'Nord_(Year_of_No_Light_album) genre Post-metal', 'Nord_(Year_of_No_Light_album) releaseDate 2006-09-06']
# dictionary: {0: [['Nord_(Year_of_No_Light_album)', 'genre', 'Sludge_metal'], ['Nord_(Year_of_No_Light_album)', 'genre', 'Post-metal'], ['Nord_(Year_of_No_Light_album)', 'releaseDate', '2006-09-06']]}
# index: 40
# triples: ['Mermaid_(Train_song) genre Pop_rock', 'Mermaid_(Train_song) musicalBand Train_(band)', 'Mermaid_(Train_song) recordLabel Columbia_Records']
# dictionary: {0: [['Mermaid_(Train_song)', 'genre', 'Pop_rock'], ['Mermaid_(Train_song)', 'musicalBand', 'Train_(band)'], ['Mermaid_(Train_song)', 'recordLabel', 'Columbia_Records']]}
# index: 41
# triples: ['Acharya_Institute_of_Technology campus "In Soldevanahalli, Acharya Dr. Sarvapalli Radhakrishnan Road, Hessarghatta Main Road, Bangalore – 560090."', 'Acharya_Institute_of_Technology city Bangalore', 'Acharya_Institute_of_Technology director "Dr. G. P. Prabhukumar"', 'Acharya_Institute_of_Technology established 2000', 'All_India_Council_for_Technical_Education location Mumbai', 'Acharya_Institute_of_Technology wasGivenTheTechnicalCampusStatusBy All_India_Council_for_Technical_Education']
# dictionary: {'0': [['Acharya_Institute_of_Technology', 'campus', '"In', 'Soldevanahalli,', 'Acharya', 'Dr.', 'Sarvapalli', 'Radhakrishnan', 'Road,', 'Hessarghatta', 'Main', 'Road,', 'Bangalore', '–', '560090."'], ['Acharya_Institute_of_Technology', 'city', 'Bangalore'], ['Acharya_Institute_of_Technology', 'director', '"Dr.', 'G.', 'P.', 'Prabhukumar"']], '0_1': [['Acharya_Institute_of_Technology', 'established', '2000'], ['Acharya_Institute_of_Technology', 'wasGivenTheTechnicalCampusStatusBy', 'All_India_Council_for_Technical_Education']], '1': [['All_India_Council_for_Technical_Education', 'location', 'Mumbai']]}
# index: 42
# triples: ['Liselotte_Grschebina birthPlace Karlsruhe', 'Karlsruhe country Germany', 'Israel language Modern_Hebrew', 'Liselotte_Grschebina nationality Israel', 'Liselotte_Grschebina training School_of_Applied_Arts_in_Stuttgart']
# dictionary: {'0': [['Liselotte_Grschebina', 'birthPlace', 'Karlsruhe'], ['Liselotte_Grschebina', 'nationality', 'Israel'], ['Liselotte_Grschebina', 'training', 'School_of_Applied_Arts_in_Stuttgart']], '1': [['Karlsruhe', 'country', 'Germany']], '2': [['Israel', 'language', 'Modern_Hebrew']]}
# index: 43
# triples: ['Death_on_a_Factory_Farm editor Geof_Bartz', 'Death_on_a_Factory_Farm musicComposer Jamie_Lawrence', 'Death_on_a_Factory_Farm producer Tom_Simon', 'Death_on_a_Factory_Farm runtime 83.0']
# dictionary: {0: [['Death_on_a_Factory_Farm', 'editor', 'Geof_Bartz'], ['Death_on_a_Factory_Farm', 'musicComposer', 'Jamie_Lawrence'], ['Death_on_a_Factory_Farm', 'producer', 'Tom_Simon']], 1: [['Death_on_a_Factory_Farm', 'runtime', '83.0']]}
# index: 44
# triples: ['Liselotte_Grschebina nationality Israel']
# dictionary: {0: [['Liselotte_Grschebina', 'nationality', 'Israel']]}
# index: 45
# triples: ['Liselotte_Grschebina birthDate 1908-05-02', 'Liselotte_Grschebina deathDate 1994-06-14', 'Liselotte_Grschebina deathPlace Israel']
# dictionary: {0: [['Liselotte_Grschebina', 'birthDate', '1908-05-02'], ['Liselotte_Grschebina', 'deathDate', '1994-06-14'], ['Liselotte_Grschebina', 'deathPlace', 'Israel']]}
# index: 46
# triples: ['Acharya_Institute_of_Technology campus "In Soldevanahalli, Acharya Dr. Sarvapalli Radhakrishnan Road, Hessarghatta Main Road, Bangalore – 560090."', 'Acharya_Institute_of_Technology city Bangalore', 'Acharya_Institute_of_Technology director "Dr. G. P. Prabhukumar"', 'Bangalore founder Kempe_Gowda_I', 'All_India_Council_for_Technical_Education location Mumbai', 'Acharya_Institute_of_Technology numberOfPostgraduateStudents 700', 'Acharya_Institute_of_Technology wasGivenTheTechnicalCampusStatusBy All_India_Council_for_Technical_Education']
# dictionary: {'0': [['Acharya_Institute_of_Technology', 'campus', '"In', 'Soldevanahalli,', 'Acharya', 'Dr.', 'Sarvapalli', 'Radhakrishnan', 'Road,', 'Hessarghatta', 'Main', 'Road,', 'Bangalore', '–', '560090."'], ['Acharya_Institute_of_Technology', 'city', 'Bangalore'], ['Acharya_Institute_of_Technology', 'director', '"Dr.', 'G.', 'P.', 'Prabhukumar"']], '0_1': [['Acharya_Institute_of_Technology', 'numberOfPostgraduateStudents', '700'], ['Acharya_Institute_of_Technology', 'wasGivenTheTechnicalCampusStatusBy', 'All_India_Council_for_Technical_Education']], '1': [['Bangalore', 'founder', 'Kempe_Gowda_I']], '2': [['All_India_Council_for_Technical_Education', 'location', 'Mumbai']]}
# index: 47
# triples: ['Darlington populationTotal 106000']
# dictionary: {0: [['Darlington', 'populationTotal', '106000']]}
# index: 48
# triples: ['Pontiac_Rageous assembly Michigan', 'Pontiac_Rageous productionEndYear 1997', 'Pontiac_Rageous productionStartYear 1997']
# dictionary: {0: [['Pontiac_Rageous', 'assembly', 'Michigan'], ['Pontiac_Rageous', 'productionEndYear', '1997'], ['Pontiac_Rageous', 'productionStartYear', '1997']]}
# index: 49
# triples: ['Alan_Shepard award Distinguished_Service_Medal_(United_States_Navy)', 'Alan_Shepard birthDate "1923-11-18"', 'Alan_Shepard birthPlace New_Hampshire', 'Alan_Shepard deathPlace California', 'Alan_Shepard nationality United_States', 'Alan_Shepard occupation Test_pilot', 'Alan_Shepard servedAsChiefOfTheAstronautOfficeIn 1963']
# dictionary: {0: [['Alan_Shepard', 'award', 'Distinguished_Service_Medal_(United_States_Navy)'], ['Alan_Shepard', 'birthDate', '"1923-11-18"'], ['Alan_Shepard', 'birthPlace', 'New_Hampshire']], 1: [['Alan_Shepard', 'deathPlace', 'California'], ['Alan_Shepard', 'nationality', 'United_States'], ['Alan_Shepard', 'occupation', 'Test_pilot']], 2: [['Alan_Shepard', 'servedAsChiefOfTheAstronautOfficeIn', '1963']]}
# index: 50
# triples: ['Agremiação_Sportiva_Arapiraquense chairmanTitle "President"', 'Campeonato_Brasileiro_Série_C champions Vila_Nova_Futebol_Clube', 'Campeonato_Brasileiro_Série_C country Brazil', 'Agremiação_Sportiva_Arapiraquense ground Estádio_Municipal_Coaracy_da_Mata_Fonseca', 'Agremiação_Sportiva_Arapiraquense league Campeonato_Brasileiro_Série_C', 'Estádio_Municipal_Coaracy_da_Mata_Fonseca location Arapiraca', 'Agremiação_Sportiva_Arapiraquense numberOfMembers 17000']
# dictionary: {'0': [['Agremiação_Sportiva_Arapiraquense', 'chairmanTitle', '"President"'], ['Agremiação_Sportiva_Arapiraquense', 'ground', 'Estádio_Municipal_Coaracy_da_Mata_Fonseca'], ['Agremiação_Sportiva_Arapiraquense', 'league', 'Campeonato_Brasileiro_Série_C']], '0_1': [['Agremiação_Sportiva_Arapiraquense', 'numberOfMembers', '17000']], '1': [['Campeonato_Brasileiro_Série_C', 'champions', 'Vila_Nova_Futebol_Clube'], ['Campeonato_Brasileiro_Série_C', 'country', 'Brazil']], '2': [['Estádio_Municipal_Coaracy_da_Mata_Fonseca', 'location', 'Arapiraca']]}
# index: 51
# triples: ['Gdynia,_Poland leaderTitle Mayor']
# dictionary: {0: [['Gdynia,_Poland', 'leaderTitle', 'Mayor']]}
# index: 52
# triples: ['Bananaman broadcastedBy BBC', 'Bananaman lastAired "1986-04-15"']
# dictionary: {0: [['Bananaman', 'broadcastedBy', 'BBC'], ['Bananaman', 'lastAired', '"1986-04-15"']]}
# index: 53
# triples: ['Ciudad_Ayala governmentType Council-manager_government', 'Ciudad_Ayala populationDensity 1604.0', 'Ciudad_Ayala populationMetro 1777539', 'Ciudad_Ayala utcOffset −6']
# dictionary: {0: [['Ciudad_Ayala', 'governmentType', 'Council-manager_government'], ['Ciudad_Ayala', 'populationDensity', '1604.0'], ['Ciudad_Ayala', 'populationMetro', '1777539']], 1: [['Ciudad_Ayala', 'utcOffset', '−6']]}
# index: 54
# triples: ['Mermaid_(Train_song) followedBy Imagine_(John_Lennon_song)', "Mermaid_(Train_song) precededBy This'll_Be_My_Year", 'Mermaid_(Train_song) releaseDate 2012-12-27', 'Mermaid_(Train_song) runtime 3.16', 'Mermaid_(Train_song) writer Espen_Lind', 'Mermaid_(Train_song) writer Amund_Bjørklund']
# dictionary: {0: [['Mermaid_(Train_song)', 'followedBy', 'Imagine_(John_Lennon_song)'], ['Mermaid_(Train_song)', 'precededBy', "This'll_Be_My_Year"], ['Mermaid_(Train_song)', 'releaseDate', '2012-12-27']], 1: [['Mermaid_(Train_song)', 'runtime', '3.16'], ['Mermaid_(Train_song)', 'writer', 'Espen_Lind'], ['Mermaid_(Train_song)', 'writer', 'Amund_Bjørklund']]}
# index: 55
# triples: ['Train_(band) recordLabel Warner_Music_Group']
# dictionary: {0: [['Train_(band)', 'recordLabel', 'Warner_Music_Group']]}
# index: 56
# triples: ['Bootleg_Series_Volume_1:_The_Quine_Tapes genre Rock_music', 'Bootleg_Series_Volume_1:_The_Quine_Tapes producer The_Velvet_Underground', 'Bootleg_Series_Volume_1:_The_Quine_Tapes recordedIn United_States', 'Bootleg_Series_Volume_1:_The_Quine_Tapes recordedIn St._Louis,_Missouri']
# dictionary: {0: [['Bootleg_Series_Volume_1:_The_Quine_Tapes', 'genre', 'Rock_music'], ['Bootleg_Series_Volume_1:_The_Quine_Tapes', 'producer', 'The_Velvet_Underground'], ['Bootleg_Series_Volume_1:_The_Quine_Tapes', 'recordedIn', 'United_States']], 1: [['Bootleg_Series_Volume_1:_The_Quine_Tapes', 'recordedIn', 'St._Louis,_Missouri']]}
# index: 57
# triples: ['English_Without_Tears director Harold_French', 'English_Without_Tears editing Alan_Jaggs', 'English_Without_Tears producer Anatole_de_Grunwald', 'English_Without_Tears runtime 89.0']
# dictionary: {0: [['English_Without_Tears', 'director', 'Harold_French'], ['English_Without_Tears', 'editing', 'Alan_Jaggs'], ['English_Without_Tears', 'producer', 'Anatole_de_Grunwald']], 1: [['English_Without_Tears', 'runtime', '89.0']]}
# index: 58
# triples: ['ALCO_RS-3 buildDate "May 1950 - August 1956"', 'ALCO_RS-3 cylinderCount 12', 'ALCO_RS-3 engine V12_engine', 'ALCO_RS-3 length 17068.8 (millimetres)']
# dictionary: {0: [['ALCO_RS-3', 'buildDate', '"May', '1950', '-', 'August', '1956"'], ['ALCO_RS-3', 'cylinderCount', '12'], ['ALCO_RS-3', 'engine', 'V12_engine']], 1: [['ALCO_RS-3', 'length', '17068.8', '(millimetres)']]}
# index: 59
# triples: ['Bootleg_Series_Volume_1:_The_Quine_Tapes artist The_Velvet_Underground', 'Bootleg_Series_Volume_1:_The_Quine_Tapes producer The_Velvet_Underground', 'Bootleg_Series_Volume_1:_The_Quine_Tapes recordedIn United_States', 'Bootleg_Series_Volume_1:_The_Quine_Tapes recordedIn St._Louis,_Missouri', 'Bootleg_Series_Volume_1:_The_Quine_Tapes runtime 230.05']
# dictionary: {0: [['Bootleg_Series_Volume_1:_The_Quine_Tapes', 'artist', 'The_Velvet_Underground'], ['Bootleg_Series_Volume_1:_The_Quine_Tapes', 'producer', 'The_Velvet_Underground'], ['Bootleg_Series_Volume_1:_The_Quine_Tapes', 'recordedIn', 'United_States']], 1: [['Bootleg_Series_Volume_1:_The_Quine_Tapes', 'recordedIn', 'St._Louis,_Missouri'], ['Bootleg_Series_Volume_1:_The_Quine_Tapes', 'runtime', '230.05']]}
# index: 60
# triples: ['Buzz_Aldrin almaMater "Massachusetts Institute of Technology, Sc.D. 1963"', 'Buzz_Aldrin mission Apollo_11']
# dictionary: {0: [['Buzz_Aldrin', 'almaMater', '"Massachusetts', 'Institute', 'of', 'Technology,', 'Sc.D.', '1963"'], ['Buzz_Aldrin', 'mission', 'Apollo_11']]}
# index: 61
# triples: ['The_Fellowship_of_the_Ring author J._R._R._Tolkien', 'The_Fellowship_of_the_Ring publisher George_Allen_&_Unwin']
# dictionary: {0: [['The_Fellowship_of_the_Ring', 'author', 'J._R._R._Tolkien'], ['The_Fellowship_of_the_Ring', 'publisher', 'George_Allen_&_Unwin']]}
# index: 62
# triples: ['Pontiac_Rageous assembly Michigan', 'Pontiac_Rageous assembly Detroit', 'Pontiac_Rageous productionEndYear 1997']
# dictionary: {0: [['Pontiac_Rageous', 'assembly', 'Michigan'], ['Pontiac_Rageous', 'assembly', 'Detroit'], ['Pontiac_Rageous', 'productionEndYear', '1997']]}
# index: 63
# triples: ['Olga_Bondareva almaMater Leningrad_State_University', 'Olga_Bondareva deathPlace Saint_Petersburg', 'Saint_Petersburg foundingDate 1703-05-27']
# dictionary: {0: [['Olga_Bondareva', 'almaMater', 'Leningrad_State_University'], ['Olga_Bondareva', 'deathPlace', 'Saint_Petersburg'], ['Saint_Petersburg', 'foundingDate', '1703-05-27']]}
# index: 64
# triples: ['Death_on_a_Factory_Farm director Tom_Simon', 'Death_on_a_Factory_Farm editor Geof_Bartz', 'Death_on_a_Factory_Farm musicComposer Jamie_Lawrence', 'Death_on_a_Factory_Farm runtime 83.0']
# dictionary: {0: [['Death_on_a_Factory_Farm', 'director', 'Tom_Simon'], ['Death_on_a_Factory_Farm', 'editor', 'Geof_Bartz'], ['Death_on_a_Factory_Farm', 'musicComposer', 'Jamie_Lawrence']], 1: [['Death_on_a_Factory_Farm', 'runtime', '83.0']]}
# index: 65
# triples: ['1147_Stavropolis orbitalPeriod 1249.6', '1147_Stavropolis periapsis 260855000000.0', '1147_Stavropolis rotationPeriod 20378.5']
# dictionary: {0: [['1147_Stavropolis', 'orbitalPeriod', '1249.6'], ['1147_Stavropolis', 'periapsis', '260855000000.0'], ['1147_Stavropolis', 'rotationPeriod', '20378.5']]}
# index: 66
# triples: ['Adolfo_Suárez_Madrid–Barajas_Airport location Madrid', 'Adolfo_Suárez_Madrid–Barajas_Airport operatingOrganisation ENAIRE', 'Adolfo_Suárez_Madrid–Barajas_Airport runwayLength 3500.0']
# dictionary: {0: [['Adolfo_Suárez_Madrid–Barajas_Airport', 'location', 'Madrid'], ['Adolfo_Suárez_Madrid–Barajas_Airport', 'operatingOrganisation', 'ENAIRE'], ['Adolfo_Suárez_Madrid–Barajas_Airport', 'runwayLength', '3500.0']]}
# index: 67
# triples: ["It's_Great_to_Be_Young_(1956_film) cinematography Gilbert_Taylor", "It's_Great_to_Be_Young_(1956_film) director Cyril_Frankel", "It's_Great_to_Be_Young_(1956_film) gross 282838.0", "It's_Great_to_Be_Young_(1956_film) musicComposer Louis_Levy", "It's_Great_to_Be_Young_(1956_film) runtime 94.0", "It's_Great_to_Be_Young_(1956_film) starring John_Mills", "It's_Great_to_Be_Young_(1956_film) writer Ted_Willis"]
# dictionary: {0: [["It's_Great_to_Be_Young_(1956_film)", 'cinematography', 'Gilbert_Taylor'], ["It's_Great_to_Be_Young_(1956_film)", 'director', 'Cyril_Frankel'], ["It's_Great_to_Be_Young_(1956_film)", 'gross', '282838.0']], 1: [["It's_Great_to_Be_Young_(1956_film)", 'musicComposer', 'Louis_Levy'], ["It's_Great_to_Be_Young_(1956_film)", 'runtime', '94.0'], ["It's_Great_to_Be_Young_(1956_film)", 'starring', 'John_Mills']], 2: [["It's_Great_to_Be_Young_(1956_film)", 'writer', 'Ted_Willis']]}
# index: 68
# triples: ['Death_on_a_Factory_Farm broadcastedBy HBO', 'Death_on_a_Factory_Farm director Tom_Simon', 'Death_on_a_Factory_Farm musicComposer Jamie_Lawrence', 'Death_on_a_Factory_Farm producer Tom_Simon']
# dictionary: {0: [['Death_on_a_Factory_Farm', 'broadcastedBy', 'HBO'], ['Death_on_a_Factory_Farm', 'director', 'Tom_Simon'], ['Death_on_a_Factory_Farm', 'musicComposer', 'Jamie_Lawrence']], 1: [['Death_on_a_Factory_Farm', 'producer', 'Tom_Simon']]}
# index: 69
# triples: ['Mermaid_(Train_song) album California_37_(Train_album)', 'Mermaid_(Train_song) followedBy Imagine_(John_Lennon_song)', 'Mermaid_(Train_song) producer Espionage_(production_team)']
# dictionary: {0: [['Mermaid_(Train_song)', 'album', 'California_37_(Train_album)'], ['Mermaid_(Train_song)', 'followedBy', 'Imagine_(John_Lennon_song)'], ['Mermaid_(Train_song)', 'producer', 'Espionage_(production_team)']]}
# index: 70
# triples: ['Bedford_Aerodrome icaoLocationIdentifier EGBF', 'Bedford_Aerodrome location Thurleigh']
# dictionary: {0: [['Bedford_Aerodrome', 'icaoLocationIdentifier', 'EGBF'], ['Bedford_Aerodrome', 'location', 'Thurleigh']]}
# index: 71
# triples: ['Bedford_Aerodrome elevationAboveTheSeaLevel 83.2104', 'Bedford_Aerodrome runwayName "08/26"', 'Bedford_Aerodrome runwaySurfaceType Concrete']
# dictionary: {0: [['Bedford_Aerodrome', 'elevationAboveTheSeaLevel', '83.2104'], ['Bedford_Aerodrome', 'runwayName', '"08/26"'], ['Bedford_Aerodrome', 'runwaySurfaceType', 'Concrete']]}
# index: 72
# triples: ['1147_Stavropolis absoluteMagnitude 11.5', '1147_Stavropolis apoapsis 418476000000.0', '1147_Stavropolis discovered 1929-06-11', '1147_Stavropolis rotationPeriod 20378.5']
# dictionary: {0: [['1147_Stavropolis', 'absoluteMagnitude', '11.5'], ['1147_Stavropolis', 'apoapsis', '418476000000.0'], ['1147_Stavropolis', 'discovered', '1929-06-11']], 1: [['1147_Stavropolis', 'rotationPeriod', '20378.5']]}
# index: 73
# triples: ['1147_Stavropolis apoapsis 418476000000.0', '1147_Stavropolis discoverer Grigory_Neujmin', '1147_Stavropolis orbitalPeriod 1249.6', '1147_Stavropolis rotationPeriod 20378.5']
# dictionary: {0: [['1147_Stavropolis', 'apoapsis', '418476000000.0'], ['1147_Stavropolis', 'discoverer', 'Grigory_Neujmin'], ['1147_Stavropolis', 'orbitalPeriod', '1249.6']], 1: [['1147_Stavropolis', 'rotationPeriod', '20378.5']]}
# index: 74
# triples: ['Noise_rock derivative Post-hardcore']
# dictionary: {0: [['Noise_rock', 'derivative', 'Post-hardcore']]}
# index: 75
# triples: ['Acharya_Institute_of_Technology campus "In Soldevanahalli, Acharya Dr. Sarvapalli Radhakrishnan Road, Hessarghatta Main Road, Bangalore – 560090."', 'Acharya_Institute_of_Technology city Bangalore', 'Acharya_Institute_of_Technology director "Dr. G. P. Prabhukumar"', 'All_India_Council_for_Technical_Education location Mumbai', 'Acharya_Institute_of_Technology wasGivenTheTechnicalCampusStatusBy All_India_Council_for_Technical_Education']
# dictionary: {'0': [['Acharya_Institute_of_Technology', 'campus', '"In', 'Soldevanahalli,', 'Acharya', 'Dr.', 'Sarvapalli', 'Radhakrishnan', 'Road,', 'Hessarghatta', 'Main', 'Road,', 'Bangalore', '–', '560090."'], ['Acharya_Institute_of_Technology', 'city', 'Bangalore'], ['Acharya_Institute_of_Technology', 'director', '"Dr.', 'G.', 'P.', 'Prabhukumar"']], '0_1': [['Acharya_Institute_of_Technology', 'wasGivenTheTechnicalCampusStatusBy', 'All_India_Council_for_Technical_Education']], '1': [['All_India_Council_for_Technical_Education', 'location', 'Mumbai']]}
# index: 76
# triples: ['Bionico course Dessert', 'Bionico region Jalisco']
# dictionary: {0: [['Bionico', 'course', 'Dessert'], ['Bionico', 'region', 'Jalisco']]}
# index: 77
# triples: ['1147_Stavropolis epoch 31 July 2016 (JD2457600.5)', '1147_Stavropolis orbitalPeriod 1249.6', '1147_Stavropolis periapsis 260855000000.0']
# dictionary: {0: [['1147_Stavropolis', 'epoch', '31', 'July', '2016', '(JD2457600.5)'], ['1147_Stavropolis', 'orbitalPeriod', '1249.6'], ['1147_Stavropolis', 'periapsis', '260855000000.0']]}
# index: 78
# triples: ['Bootleg_Series_Volume_1:_The_Quine_Tapes precededBy Squeeze_(The_Velvet_Underground_album)', 'Bootleg_Series_Volume_1:_The_Quine_Tapes recordedIn San_Francisco', 'Bootleg_Series_Volume_1:_The_Quine_Tapes releaseDate 2001-10-16', 'Bootleg_Series_Volume_1:_The_Quine_Tapes runtime 230.05']
# dictionary: {0: [['Bootleg_Series_Volume_1:_The_Quine_Tapes', 'precededBy', 'Squeeze_(The_Velvet_Underground_album)'], ['Bootleg_Series_Volume_1:_The_Quine_Tapes', 'recordedIn', 'San_Francisco'], ['Bootleg_Series_Volume_1:_The_Quine_Tapes', 'releaseDate', '2001-10-16']], 1: [['Bootleg_Series_Volume_1:_The_Quine_Tapes', 'runtime', '230.05']]}
# index: 79
# triples: ['Agremiação_Sportiva_Arapiraquense league Campeonato_Brasileiro_Série_C', 'Agremiação_Sportiva_Arapiraquense nickname "Asa Gigante \'\'"']
# dictionary: {0: [['Agremiação_Sportiva_Arapiraquense', 'league', 'Campeonato_Brasileiro_Série_C'], ['Agremiação_Sportiva_Arapiraquense', 'nickname', '"Asa', 'Gigante', '\'\'"']]}
# index: 80
# triples: ['Lady_Anne_Monson deathDate 1776-02-18', 'Lady_Anne_Monson nationality Kingdom_of_England', 'Lady_Anne_Monson residence India', 'Lady_Anne_Monson spouse George_Monson']
# dictionary: {0: [['Lady_Anne_Monson', 'deathDate', '1776-02-18'], ['Lady_Anne_Monson', 'nationality', 'Kingdom_of_England'], ['Lady_Anne_Monson', 'residence', 'India']], 1: [['Lady_Anne_Monson', 'spouse', 'George_Monson']]}
# index: 81
# triples: ['Lady_Anne_Monson birthDate 1726-01-01', 'Lady_Anne_Monson birthPlace Darlington', 'Lady_Anne_Monson birthPlace Kingdom_of_England', 'Lady_Anne_Monson deathDate 1776-02-18', 'Lady_Anne_Monson residence India']
# dictionary: {0: [['Lady_Anne_Monson', 'birthDate', '1726-01-01'], ['Lady_Anne_Monson', 'birthPlace', 'Darlington'], ['Lady_Anne_Monson', 'birthPlace', 'Kingdom_of_England']], 1: [['Lady_Anne_Monson', 'deathDate', '1776-02-18'], ['Lady_Anne_Monson', 'residence', 'India']]}
# index: 82
# triples: ['Israel ethnicGroup Arab_citizens_of_Israel']
# dictionary: {0: [['Israel', 'ethnicGroup', 'Arab_citizens_of_Israel']]}
# index: 83
# triples: ['Alan_B._Miller_Hall address "101 Ukrop Way"', 'Alan_B._Miller_Hall architect Robert_A._M._Stern', 'Alan_B._Miller_Hall architecturalStyle Georgian_architecture', 'Alan_B._Miller_Hall buildingStartDate "30 March 2007"', 'Alan_B._Miller_Hall currentTenants Mason_School_of_Business', 'Alan_B._Miller_Hall location Virginia', 'Alan_B._Miller_Hall owner College_of_William_&_Mary']
# dictionary: {0: [['Alan_B._Miller_Hall', 'address', '"101', 'Ukrop', 'Way"'], ['Alan_B._Miller_Hall', 'architect', 'Robert_A._M._Stern'], ['Alan_B._Miller_Hall', 'architecturalStyle', 'Georgian_architecture']], 1: [['Alan_B._Miller_Hall', 'buildingStartDate', '"30', 'March', '2007"'], ['Alan_B._Miller_Hall', 'currentTenants', 'Mason_School_of_Business'], ['Alan_B._Miller_Hall', 'location', 'Virginia']], 2: [['Alan_B._Miller_Hall', 'owner', 'College_of_William_&_Mary']]}
# index: 84
# triples: ['The_Fellowship_of_the_Ring author J._R._R._Tolkien', 'The_Fellowship_of_the_Ring followedBy The_Two_Towers', 'The_Fellowship_of_the_Ring literaryGenre Fantasy_(genre)', 'The_Fellowship_of_the_Ring publisher George_Allen_&_Unwin']
# dictionary: {0: [['The_Fellowship_of_the_Ring', 'author', 'J._R._R._Tolkien'], ['The_Fellowship_of_the_Ring', 'followedBy', 'The_Two_Towers'], ['The_Fellowship_of_the_Ring', 'literaryGenre', 'Fantasy_(genre)']], 1: [['The_Fellowship_of_the_Ring', 'publisher', 'George_Allen_&_Unwin']]}
# index: 85
# triples: ['English_Without_Tears director Harold_French', 'English_Without_Tears editing Alan_Jaggs', 'English_Without_Tears musicComposer Nicholas_Brodszky', 'English_Without_Tears releaseDate 1944-07-28', 'English_Without_Tears runtime 89.0', 'English_Without_Tears writer Anatole_de_Grunwald']
# dictionary: {0: [['English_Without_Tears', 'director', 'Harold_French'], ['English_Without_Tears', 'editing', 'Alan_Jaggs'], ['English_Without_Tears', 'musicComposer', 'Nicholas_Brodszky']], 1: [['English_Without_Tears', 'releaseDate', '1944-07-28'], ['English_Without_Tears', 'runtime', '89.0'], ['English_Without_Tears', 'writer', 'Anatole_de_Grunwald']]}
# index: 86
# triples: ['Expect_a_Miracle artist Brian_Kelly_(composer_&_pianist)', 'Expect_a_Miracle followedBy Afterplay_(Brian_Kelly_album)', 'Expect_a_Miracle precededBy Pools_of_Light_(Brian_Kelly_album)', 'Expect_a_Miracle producer Brian_Kelly_(composer_&_pianist)', 'Expect_a_Miracle runtime 54.56', 'Expect_a_Miracle type Compilation_Album']
# dictionary: {0: [['Expect_a_Miracle', 'artist', 'Brian_Kelly_(composer_&_pianist)'], ['Expect_a_Miracle', 'followedBy', 'Afterplay_(Brian_Kelly_album)'], ['Expect_a_Miracle', 'precededBy', 'Pools_of_Light_(Brian_Kelly_album)']], 1: [['Expect_a_Miracle', 'producer', 'Brian_Kelly_(composer_&_pianist)'], ['Expect_a_Miracle', 'runtime', '54.56'], ['Expect_a_Miracle', 'type', 'Compilation_Album']]}
# index: 87
# triples: ['11th_Mississippi_Infantry_Monument category Contributing_property', '11th_Mississippi_Infantry_Monument country "United States"', '11th_Mississippi_Infantry_Monument established 2000', 'Adams_County,_Pennsylvania hasToItsNorth Cumberland_County,_Pennsylvania', '11th_Mississippi_Infantry_Monument location Adams_County,_Pennsylvania']
# dictionary: {'0': [['11th_Mississippi_Infantry_Monument', 'category', 'Contributing_property'], ['11th_Mississippi_Infantry_Monument', 'country', '"United', 'States"'], ['11th_Mississippi_Infantry_Monument', 'established', '2000']], '0_1': [['11th_Mississippi_Infantry_Monument', 'location', 'Adams_County,_Pennsylvania']], '1': [['Adams_County,_Pennsylvania', 'hasToItsNorth', 'Cumberland_County,_Pennsylvania']]}
# index: 88
# triples: ['Campeonato_Brasileiro_Série_C champions Vila_Nova_Futebol_Clube', 'Campeonato_Brasileiro_Série_C country Brazil', 'Agremiação_Sportiva_Arapiraquense fullName "Agremiação Sportiva Arapiraquense"', 'Agremiação_Sportiva_Arapiraquense ground Estádio_Municipal_Coaracy_da_Mata_Fonseca', 'Agremiação_Sportiva_Arapiraquense league Campeonato_Brasileiro_Série_C', 'Estádio_Municipal_Coaracy_da_Mata_Fonseca location Arapiraca', 'Agremiação_Sportiva_Arapiraquense season 2015']
# dictionary: {'0': [['Campeonato_Brasileiro_Série_C', 'champions', 'Vila_Nova_Futebol_Clube'], ['Campeonato_Brasileiro_Série_C', 'country', 'Brazil']], '1': [['Agremiação_Sportiva_Arapiraquense', 'fullName', '"Agremiação', 'Sportiva', 'Arapiraquense"'], ['Agremiação_Sportiva_Arapiraquense', 'ground', 'Estádio_Municipal_Coaracy_da_Mata_Fonseca'], ['Agremiação_Sportiva_Arapiraquense', 'league', 'Campeonato_Brasileiro_Série_C']], '1_1': [['Agremiação_Sportiva_Arapiraquense', 'season', '2015']], '2': [['Estádio_Municipal_Coaracy_da_Mata_Fonseca', 'location', 'Arapiraca']]}
# index: 89
# triples: ['Bedford_Aerodrome operatingOrganisation MotorSport_Vision', 'Bedford_Aerodrome runwayLength 1095.0']
# dictionary: {0: [['Bedford_Aerodrome', 'operatingOrganisation', 'MotorSport_Vision'], ['Bedford_Aerodrome', 'runwayLength', '1095.0']]}
# index: 90
# triples: ['Ciudad_Ayala leaderTitle Governator', 'Ciudad_Ayala populationDensity 1604.0', 'Ciudad_Ayala populationMetro 1777539', 'Ciudad_Ayala timeZone Pacific_Daylight_Time']
# dictionary: {0: [['Ciudad_Ayala', 'leaderTitle', 'Governator'], ['Ciudad_Ayala', 'populationDensity', '1604.0'], ['Ciudad_Ayala', 'populationMetro', '1777539']], 1: [['Ciudad_Ayala', 'timeZone', 'Pacific_Daylight_Time']]}
# index: 91
# triples: ['Nord_(Year_of_No_Light_album) followedBy Live_at_Roadburn_2008_(Year_of_No_Light_album)', 'Nord_(Year_of_No_Light_album) genre Sludge_metal', 'Nord_(Year_of_No_Light_album) producer Year_of_No_Light', 'Nord_(Year_of_No_Light_album) releaseDate 2006-09-06']
# dictionary: {0: [['Nord_(Year_of_No_Light_album)', 'followedBy', 'Live_at_Roadburn_2008_(Year_of_No_Light_album)'], ['Nord_(Year_of_No_Light_album)', 'genre', 'Sludge_metal'], ['Nord_(Year_of_No_Light_album)', 'producer', 'Year_of_No_Light']], 1: [['Nord_(Year_of_No_Light_album)', 'releaseDate', '2006-09-06']]}
# index: 92
# triples: ['Alan_B._Miller_Hall address "101 Ukrop Way"', 'Alan_B._Miller_Hall architect Robert_A._M._Stern', 'Alan_B._Miller_Hall currentTenants Mason_School_of_Business', 'Alan_B._Miller_Hall owner College_of_William_&_Mary']
# dictionary: {0: [['Alan_B._Miller_Hall', 'address', '"101', 'Ukrop', 'Way"'], ['Alan_B._Miller_Hall', 'architect', 'Robert_A._M._Stern'], ['Alan_B._Miller_Hall', 'currentTenants', 'Mason_School_of_Business']], 1: [['Alan_B._Miller_Hall', 'owner', 'College_of_William_&_Mary']]}
# index: 93
# triples: ['Darinka_Dentcheva birthDate 1958-01-01', 'Darinka_Dentcheva influencedBy Andrzej_Piotr_Ruszczyński']
# dictionary: {0: [['Darinka_Dentcheva', 'birthDate', '1958-01-01'], ['Darinka_Dentcheva', 'influencedBy', 'Andrzej_Piotr_Ruszczyński']]}
# index: 94
# triples: ['Al_Asad_Airbase operatingOrganisation United_States_Air_Force', 'Al_Asad_Airbase runwayName "09R/27L"']
# dictionary: {0: [['Al_Asad_Airbase', 'operatingOrganisation', 'United_States_Air_Force'], ['Al_Asad_Airbase', 'runwayName', '"09R/27L"']]}
# index: 95
# triples: ['Rock_music musicSubgenre Proto-punk']
# dictionary: {0: [['Rock_music', 'musicSubgenre', 'Proto-punk']]}
# index: 96
# triples: ['11th_Mississippi_Infantry_Monument country "United States"', '11th_Mississippi_Infantry_Monument established 2000']
# dictionary: {0: [['11th_Mississippi_Infantry_Monument', 'country', '"United', 'States"'], ['11th_Mississippi_Infantry_Monument', 'established', '2000']]}
# index: 97
# triples: ['Campeonato_Brasileiro_Série_C country Brazil', 'Agremiação_Sportiva_Arapiraquense league Campeonato_Brasileiro_Série_C', 'Agremiação_Sportiva_Arapiraquense nickname "\'\'Alvinegro"']
# dictionary: {0: [['Campeonato_Brasileiro_Série_C', 'country', 'Brazil'], ['Agremiação_Sportiva_Arapiraquense', 'league', 'Campeonato_Brasileiro_Série_C'], ['Agremiação_Sportiva_Arapiraquense', 'nickname', '"\'\'Alvinegro"']]}
# index: 98
# triples: ['The_Fellowship_of_the_Ring followedBy The_Two_Towers', 'The_Fellowship_of_the_Ring literaryGenre Fantasy_(genre)', 'The_Fellowship_of_the_Ring publisher George_Allen_&_Unwin']
# dictionary: {0: [['The_Fellowship_of_the_Ring', 'followedBy', 'The_Two_Towers'], ['The_Fellowship_of_the_Ring', 'literaryGenre', 'Fantasy_(genre)'], ['The_Fellowship_of_the_Ring', 'publisher', 'George_Allen_&_Unwin']]}
# index: 99
# triples: ['Alan_Shepard birthDate "1923-11-18"', 'Alan_Shepard birthPlace New_Hampshire', 'Alan_Shepard deathDate "1998-07-21"', 'Alan_Shepard deathPlace California', 'Alan_Shepard nationality United_States']
# dictionary: {0: [['Alan_Shepard', 'birthDate', '"1923-11-18"'], ['Alan_Shepard', 'birthPlace', 'New_Hampshire'], ['Alan_Shepard', 'deathDate', '"1998-07-21"']], 1: [['Alan_Shepard', 'deathPlace', 'California'], ['Alan_Shepard', 'nationality', 'United_States']]}
# index: 100
# triples: ['McVeagh_of_the_South_Seas director Cyril_Bruce', 'McVeagh_of_the_South_Seas director Harry_Carey_(actor_born_1878)', 'McVeagh_of_the_South_Seas imdbId 0004319', 'McVeagh_of_the_South_Seas writer Harry_Carey_(actor_born_1878)']
# dictionary: {0: [['McVeagh_of_the_South_Seas', 'director', 'Cyril_Bruce'], ['McVeagh_of_the_South_Seas', 'director', 'Harry_Carey_(actor_born_1878)'], ['McVeagh_of_the_South_Seas', 'imdbId', '0004319']], 1: [['McVeagh_of_the_South_Seas', 'writer', 'Harry_Carey_(actor_born_1878)']]}
# index: 101
# triples: ['India areaTotal 3287590000000.0']
# dictionary: {0: [['India', 'areaTotal', '3287590000000.0']]}
# index: 102
# triples: ['The_Two_Towers publisher George_Allen_&_Unwin']
# dictionary: {0: [['The_Two_Towers', 'publisher', 'George_Allen_&_Unwin']]}
# index: 103
# triples: ['India areaTotal 3287590000000.0', 'India leader Pranab_Mukherjee', 'Lady_Anne_Monson nationality Kingdom_of_England', 'Lady_Anne_Monson residence India']
# dictionary: {'0': [['India', 'areaTotal', '3287590000000.0'], ['India', 'leader', 'Pranab_Mukherjee']], '1': [['Lady_Anne_Monson', 'nationality', 'Kingdom_of_England'], ['Lady_Anne_Monson', 'residence', 'India']]}
# index: 104
# triples: ['Alan_Shepard almaMater "NWC, M.A. 1957"', 'Alan_Shepard birthDate "1923-11-18"', 'Alan_Shepard birthPlace New_Hampshire', 'Alan_Shepard deathPlace California']
# dictionary: {0: [['Alan_Shepard', 'almaMater', '"NWC,', 'M.A.', '1957"'], ['Alan_Shepard', 'birthDate', '"1923-11-18"'], ['Alan_Shepard', 'birthPlace', 'New_Hampshire']], 1: [['Alan_Shepard', 'deathPlace', 'California']]}
# index: 105
# triples: ['Alan_Shepard birthPlace New_Hampshire', 'Alan_Shepard dateOfRetirement "1974-08-01"', 'Alan_Shepard deathPlace California']
# dictionary: {0: [['Alan_Shepard', 'birthPlace', 'New_Hampshire'], ['Alan_Shepard', 'dateOfRetirement', '"1974-08-01"'], ['Alan_Shepard', 'deathPlace', 'California']]}
# index: 106
# triples: ['United_States areaTotal 9833520000000.0', 'Bootleg_Series_Volume_1:_The_Quine_Tapes recordedIn San_Francisco', 'Bootleg_Series_Volume_1:_The_Quine_Tapes recordedIn United_States', 'San_Francisco utcOffset &minus;7']
# dictionary: {'0': [['United_States', 'areaTotal', '9833520000000.0']], '1': [['Bootleg_Series_Volume_1:_The_Quine_Tapes', 'recordedIn', 'San_Francisco'], ['Bootleg_Series_Volume_1:_The_Quine_Tapes', 'recordedIn', 'United_States']], '2': [['San_Francisco', 'utcOffset', '&minus;7']]}
# index: 107
# triples: ['McVeagh_of_the_South_Seas director Harry_Carey_(actor_born_1878)', 'McVeagh_of_the_South_Seas director Gregory_Allen', 'McVeagh_of_the_South_Seas distributor Alliance_Films_Corporation', 'McVeagh_of_the_South_Seas imdbId 0004319']
# dictionary: {0: [['McVeagh_of_the_South_Seas', 'director', 'Harry_Carey_(actor_born_1878)'], ['McVeagh_of_the_South_Seas', 'director', 'Gregory_Allen'], ['McVeagh_of_the_South_Seas', 'distributor', 'Alliance_Films_Corporation']], 1: [['McVeagh_of_the_South_Seas', 'imdbId', '0004319']]}
# index: 108
# triples: ['Hypermarcas numberOfEmployees 10252']
# dictionary: {0: [['Hypermarcas', 'numberOfEmployees', '10252']]}
# index: 109
# triples: ['Hypermarcas industry Pharmaceuticals', 'Hypermarcas location Brazil']
# dictionary: {0: [['Hypermarcas', 'industry', 'Pharmaceuticals'], ['Hypermarcas', 'location', 'Brazil']]}
# index: 110
# triples: ['Lady_Anne_Monson birthDate 1726-01-01', 'Lady_Anne_Monson birthPlace Darlington', 'Lady_Anne_Monson birthPlace Kingdom_of_England', 'Lady_Anne_Monson deathDate 1776-02-18', 'Lady_Anne_Monson professionalField Botany']
# dictionary: {0: [['Lady_Anne_Monson', 'birthDate', '1726-01-01'], ['Lady_Anne_Monson', 'birthPlace', 'Darlington'], ['Lady_Anne_Monson', 'birthPlace', 'Kingdom_of_England']], 1: [['Lady_Anne_Monson', 'deathDate', '1776-02-18'], ['Lady_Anne_Monson', 'professionalField', 'Botany']]}
# index: 111
# triples: ['Pontiac_Rageous manufacturer Pontiac', 'Pontiac_Rageous productionEndYear 1997', 'Pontiac_Rageous productionStartYear 1997']
# dictionary: {0: [['Pontiac_Rageous', 'manufacturer', 'Pontiac'], ['Pontiac_Rageous', 'productionEndYear', '1997'], ['Pontiac_Rageous', 'productionStartYear', '1997']]}
# index: 112
# triples: ['Imagine_(John_Lennon_song) followedBy Happy_Xmas_(War_Is_Over)', 'Mermaid_(Train_song) followedBy Imagine_(John_Lennon_song)', 'Mermaid_(Train_song) genre Reggae', 'Imagine_(John_Lennon_song) genre Pop_music']
# dictionary: {'0': [['Imagine_(John_Lennon_song)', 'followedBy', 'Happy_Xmas_(War_Is_Over)'], ['Imagine_(John_Lennon_song)', 'genre', 'Pop_music']], '1': [['Mermaid_(Train_song)', 'followedBy', 'Imagine_(John_Lennon_song)'], ['Mermaid_(Train_song)', 'genre', 'Reggae']]}
# index: 113
# triples: ['Acharya_Institute_of_Technology affiliation Visvesvaraya_Technological_University', 'Acharya_Institute_of_Technology campus "In Soldevanahalli, Acharya Dr. Sarvapalli Radhakrishnan Road, Hessarghatta Main Road, Bangalore – 560090."', 'All_India_Council_for_Technical_Education location Mumbai', 'Acharya_Institute_of_Technology president "B.M. Reddy"', 'Acharya_Institute_of_Technology wasGivenTheTechnicalCampusStatusBy All_India_Council_for_Technical_Education']
# ...
# dictionary: {'0': [['Acharya_Institute_of_Technology', 'affiliation', 'Visvesvaraya_Technological_University'], ['Acharya_Institute_of_Technology', 'campus', '"In', 'Soldevanahalli,', 'Acharya', 'Dr.', 'Sarvapalli', 'Radhakrishnan', 'Road,', 'Hessarghatta', 'Main', 'Road,', 'Bangalore', '–', '560090."'], ['Acharya_Institute_of_Technology', 'country', '"India"']], '0_1': [['Acharya_Institute_of_Technology', 'director', '"Dr.', 'G.', 'P.', 'Prabhukumar"'], ['Acharya_Institute_of_Technology', 'wasGivenTheTechnicalCampusStatusBy', 'All_India_Council_for_Technical_Education']], '1': [['All_India_Council_for_Technical_Education', 'location', 'Mumbai']]}
# index: 1736
# triples: ['Piotr_Hallmann height 175.26']
# dictionary: {0: [['Piotr_Hallmann', 'height', '175.26']]}
# index: 1737
# triples: ['Piotr_Hallmann birthPlace Gdynia,_Poland', 'Piotr_Hallmann height 175.26']
# dictionary: {0: [['Piotr_Hallmann', 'birthPlace', 'Gdynia,_Poland'], ['Piotr_Hallmann', 'height', '175.26']]}
# index: 1738
# triples: ['Bedford_Aerodrome runwayLength 1095.0']
# dictionary: {0: [['Bedford_Aerodrome', 'runwayLength', '1095.0']]}
# index: 1739
# triples: ['Adams_County,_Pennsylvania hasToItsWest Franklin_County,_Pennsylvania', '11th_Mississippi_Infantry_Monument location Adams_County,_Pennsylvania']
# dictionary: {0: [['Adams_County,_Pennsylvania', 'hasToItsWest', 'Franklin_County,_Pennsylvania'], ['11th_Mississippi_Infantry_Monument', 'location', 'Adams_County,_Pennsylvania']]}
# index: 1740
# triples: ['Swords,_Dublin leaderTitle "County Manager"', 'Trane location Swords,_Dublin']
# dictionary: {0: [['Swords,_Dublin', 'leaderTitle', '"County', 'Manager"'], ['Trane', 'location', 'Swords,_Dublin']]}
# index: 1741
# triples: ['Nie_Haisheng birthPlace Zaoyang', 'Nie_Haisheng birthPlace Hubei', 'Nie_Haisheng mission Shenzhou_10', 'Nie_Haisheng mission Shenzhou_6']
# dictionary: {0: [['Nie_Haisheng', 'birthPlace', 'Zaoyang'], ['Nie_Haisheng', 'birthPlace', 'Hubei'], ['Nie_Haisheng', 'mission', 'Shenzhou_10']], 1: [['Nie_Haisheng', 'mission', 'Shenzhou_6']]}
# index: 1742
# triples: ['Alan_Shepard award Distinguished_Service_Medal_(United_States_Navy)', 'Alan_Shepard birthDate "1923-11-18"', 'Alan_Shepard birthPlace New_Hampshire', 'Alan_Shepard deathPlace California', 'Alan_Shepard mission Apollo_14', 'Alan_Shepard nationality United_States', 'Alan_Shepard servedAsChiefOfTheAstronautOfficeIn 1963']
# dictionary: {0: [['Alan_Shepard', 'award', 'Distinguished_Service_Medal_(United_States_Navy)'], ['Alan_Shepard', 'birthDate', '"1923-11-18"'], ['Alan_Shepard', 'birthPlace', 'New_Hampshire']], 1: [['Alan_Shepard', 'deathPlace', 'California'], ['Alan_Shepard', 'mission', 'Apollo_14'], ['Alan_Shepard', 'nationality', 'United_States']], 2: [['Alan_Shepard', 'servedAsChiefOfTheAstronautOfficeIn', '1963']]}
# index: 1743
# triples: ['Super_Capers starring Michael_Rooker', 'Super_Capers starring Tom_Sizemore']
# dictionary: {0: [['Super_Capers', 'starring', 'Michael_Rooker'], ['Super_Capers', 'starring', 'Tom_Sizemore']]}
# index: 1744
# triples: ['The_Fellowship_of_the_Ring literaryGenre Fantasy_(genre)', 'The_Fellowship_of_the_Ring publisher George_Allen_&_Unwin']
# dictionary: {0: [['The_Fellowship_of_the_Ring', 'literaryGenre', 'Fantasy_(genre)'], ['The_Fellowship_of_the_Ring', 'publisher', 'George_Allen_&_Unwin']]}
# index: 1745
# triples: ['Pontiac_Rageous manufacturer Pontiac']
# dictionary: {0: [['Pontiac_Rageous', 'manufacturer', 'Pontiac']]}
# index: 1746
# triples: ['United_States demonym American']
# dictionary: {0: [['United_States', 'demonym', 'American']]}
# index: 1747
# triples: ['Olga_Bondareva almaMater Leningrad_State_University']
# dictionary: {0: [['Olga_Bondareva', 'almaMater', 'Leningrad_State_University']]}
# index: 1748
# triples: ["It's_Great_to_Be_Young_(1956_film) cinematography Gilbert_Taylor", "It's_Great_to_Be_Young_(1956_film) director Cyril_Frankel", "It's_Great_to_Be_Young_(1956_film) gross 282838.0", "It's_Great_to_Be_Young_(1956_film) runtime 94.0"]
# dictionary: {0: [["It's_Great_to_Be_Young_(1956_film)", 'cinematography', 'Gilbert_Taylor'], ["It's_Great_to_Be_Young_(1956_film)", 'director', 'Cyril_Frankel'], ["It's_Great_to_Be_Young_(1956_film)", 'gross', '282838.0']], 1: [["It's_Great_to_Be_Young_(1956_film)", 'runtime', '94.0']]}
# index: 1749
# triples: ['Lady_Anne_Monson birthDate 1726-01-01', 'Lady_Anne_Monson birthPlace Darlington', 'Lady_Anne_Monson nationality Kingdom_of_England']
# dictionary: {0: [['Lady_Anne_Monson', 'birthDate', '1726-01-01'], ['Lady_Anne_Monson', 'birthPlace', 'Darlington'], ['Lady_Anne_Monson', 'nationality', 'Kingdom_of_England']]}
# index: 1750
# triples: ['Darinka_Dentcheva knownFor Stochastic_programming']
# dictionary: {0: [['Darinka_Dentcheva', 'knownFor', 'Stochastic_programming']]}
# index: 1751
# triples: ['Campeonato_Brasileiro_Série_C champions Vila_Nova_Futebol_Clube', 'Agremiação_Sportiva_Arapiraquense ground Estádio_Municipal_Coaracy_da_Mata_Fonseca', 'Agremiação_Sportiva_Arapiraquense league Campeonato_Brasileiro_Série_C', 'Estádio_Municipal_Coaracy_da_Mata_Fonseca location Arapiraca', 'Agremiação_Sportiva_Arapiraquense numberOfMembers 17000', 'Agremiação_Sportiva_Arapiraquense season 2015_Campeonato_Brasileiro_Série_C']
# dictionary: {'0': [['Campeonato_Brasileiro_Série_C', 'champions', 'Vila_Nova_Futebol_Clube']], '1': [['Agremiação_Sportiva_Arapiraquense', 'ground', 'Estádio_Municipal_Coaracy_da_Mata_Fonseca'], ['Agremiação_Sportiva_Arapiraquense', 'league', 'Campeonato_Brasileiro_Série_C'], ['Agremiação_Sportiva_Arapiraquense', 'numberOfMembers', '17000']], '1_1': [['Agremiação_Sportiva_Arapiraquense', 'season', '2015_Campeonato_Brasileiro_Série_C']], '2': [['Estádio_Municipal_Coaracy_da_Mata_Fonseca', 'location', 'Arapiraca']]}
# index: 1752
# triples: ['ALCO_RS-3 buildDate "May 1950 - August 1956"', 'ALCO_RS-3 engine V12_engine', 'ALCO_RS-3 length 17068.8 (millimetres)', 'ALCO_RS-3 powerType Diesel-electric_transmission']
# dictionary: {0: [['ALCO_RS-3', 'buildDate', '"May', '1950', '-', 'August', '1956"'], ['ALCO_RS-3', 'engine', 'V12_engine'], ['ALCO_RS-3', 'length', '17068.8', '(millimetres)']], 1: [['ALCO_RS-3', 'powerType', 'Diesel-electric_transmission']]}
# index: 1753
# triples: ['McVeagh_of_the_South_Seas director Cyril_Bruce', 'McVeagh_of_the_South_Seas director Harry_Carey_(actor_born_1878)', 'McVeagh_of_the_South_Seas distributor Alliance_Films_Corporation', 'McVeagh_of_the_South_Seas producer The_Progressive_Motion_Picture_Company', 'McVeagh_of_the_South_Seas writer Harry_Carey_(actor_born_1878)']
# dictionary: {0: [['McVeagh_of_the_South_Seas', 'director', 'Cyril_Bruce'], ['McVeagh_of_the_South_Seas', 'director', 'Harry_Carey_(actor_born_1878)'], ['McVeagh_of_the_South_Seas', 'distributor', 'Alliance_Films_Corporation']], 1: [['McVeagh_of_the_South_Seas', 'producer', 'The_Progressive_Motion_Picture_Company'], ['McVeagh_of_the_South_Seas', 'writer', 'Harry_Carey_(actor_born_1878)']]}
# index: 1754
# triples: ['John_Mills spouse Aileen_Raymond', 'John_Mills spouse Mary_Hayley_Bell', "It's_Great_to_Be_Young_(1956_film) starring John_Mills", "It's_Great_to_Be_Young_(1956_film) starring Cecil_Parker"]
# dictionary: {'0': [['John_Mills', 'spouse', 'Aileen_Raymond'], ['John_Mills', 'spouse', 'Mary_Hayley_Bell']], '1': [["It's_Great_to_Be_Young_(1956_film)", 'starring', 'John_Mills'], ["It's_Great_to_Be_Young_(1956_film)", 'starring', 'Cecil_Parker']]}
# index: 1755
# triples: ['Super_Capers budget 2000000.0', 'Super_Capers director Ray_Griggs_(director)', 'Super_Capers starring Adam_West', 'Super_Capers writer Ray_Griggs_(director)']
# dictionary: {0: [['Super_Capers', 'budget', '2000000.0'], ['Super_Capers', 'director', 'Ray_Griggs_(director)'], ['Super_Capers', 'starring', 'Adam_West']], 1: [['Super_Capers', 'writer', 'Ray_Griggs_(director)']]}
# index: 1756
# triples: ['Acharya_Institute_of_Technology affiliation Visvesvaraya_Technological_University', 'Acharya_Institute_of_Technology campus "In Soldevanahalli, Acharya Dr. Sarvapalli Radhakrishnan Road, Hessarghatta Main Road, Bangalore – 560090."', 'Acharya_Institute_of_Technology director "Dr. G. P. Prabhukumar"', 'All_India_Council_for_Technical_Education location Mumbai', 'Acharya_Institute_of_Technology numberOfPostgraduateStudents 700', 'Acharya_Institute_of_Technology wasGivenTheTechnicalCampusStatusBy All_India_Council_for_Technical_Education']
# dictionary: {'0': [['Acharya_Institute_of_Technology', 'affiliation', 'Visvesvaraya_Technological_University'], ['Acharya_Institute_of_Technology', 'campus', '"In', 'Soldevanahalli,', 'Acharya', 'Dr.', 'Sarvapalli', 'Radhakrishnan', 'Road,', 'Hessarghatta', 'Main', 'Road,', 'Bangalore', '–', '560090."'], ['Acharya_Institute_of_Technology', 'director', '"Dr.', 'G.', 'P.', 'Prabhukumar"']], '0_1': [['Acharya_Institute_of_Technology', 'numberOfPostgraduateStudents', '700'], ['Acharya_Institute_of_Technology', 'wasGivenTheTechnicalCampusStatusBy', 'All_India_Council_for_Technical_Education']], '1': [['All_India_Council_for_Technical_Education', 'location', 'Mumbai']]}
# index: 1757
# triples: ['Ciudad_Ayala governmentType Council-manager_government', 'Ciudad_Ayala populationDensity 1604.0', 'Ciudad_Ayala type City']
# dictionary: {0: [['Ciudad_Ayala', 'governmentType', 'Council-manager_government'], ['Ciudad_Ayala', 'populationDensity', '1604.0'], ['Ciudad_Ayala', 'type', 'City']]}
# index: 1758
# triples: ['Brandon_Carter almaMater University_of_Cambridge', 'Brandon_Carter birthDate 1942-01-01', 'University_of_Cambridge chancellor David_Sainsbury,_Baron_Sainsbury_of_Turville', 'Brandon_Carter doctoralAdvisor Dennis_William_Sciama']
# dictionary: {'0': [['Brandon_Carter', 'almaMater', 'University_of_Cambridge'], ['Brandon_Carter', 'birthDate', '1942-01-01'], ['Brandon_Carter', 'doctoralAdvisor', 'Dennis_William_Sciama']], '1': [['University_of_Cambridge', 'chancellor', 'David_Sainsbury,_Baron_Sainsbury_of_Turville']]}
# index: 1759
# triples: ['McVeagh_of_the_South_Seas director Harry_Carey_(actor_born_1878)', 'McVeagh_of_the_South_Seas producer The_Progressive_Motion_Picture_Company', 'McVeagh_of_the_South_Seas writer Harry_Carey_(actor_born_1878)']
# dictionary: {0: [['McVeagh_of_the_South_Seas', 'director', 'Harry_Carey_(actor_born_1878)'], ['McVeagh_of_the_South_Seas', 'producer', 'The_Progressive_Motion_Picture_Company'], ['McVeagh_of_the_South_Seas', 'writer', 'Harry_Carey_(actor_born_1878)']]}
# index: 1760
# triples: ['John_Mills child Hayley_Mills']
# dictionary: {0: [['John_Mills', 'child', 'Hayley_Mills']]}
# index: 1761
# triples: ['University_of_Burgundy campus Dijon', 'University_of_Burgundy numberOfDoctoralStudents 1299', 'University_of_Burgundy numberOfStudents 27400']
# dictionary: {0: [['University_of_Burgundy', 'campus', 'Dijon'], ['University_of_Burgundy', 'numberOfDoctoralStudents', '1299'], ['University_of_Burgundy', 'numberOfStudents', '27400']]}
# index: 1762
# triples: ['Mermaid_(Train_song) genre Reggae', 'Train_(band) genre Pop_rock', 'Mermaid_(Train_song) musicalBand Train_(band)']
# dictionary: {0: [['Mermaid_(Train_song)', 'genre', 'Reggae'], ['Train_(band)', 'genre', 'Pop_rock'], ['Mermaid_(Train_song)', 'musicalBand', 'Train_(band)']]}
# index: 1763
# triples: ['Lionsgate keyPerson Jon_Feltheimer']
# dictionary: {0: [['Lionsgate', 'keyPerson', 'Jon_Feltheimer']]}
# index: 1764
# triples: ['Alan_B._Miller_Hall completionDate 2009-06-01', 'Alan_B._Miller_Hall owner College_of_William_&_Mary']
# dictionary: {0: [['Alan_B._Miller_Hall', 'completionDate', '2009-06-01'], ['Alan_B._Miller_Hall', 'owner', 'College_of_William_&_Mary']]}
# index: 1765
# triples: ['Bedford_Aerodrome icaoLocationIdentifier EGBF', 'Bedford_Aerodrome operatingOrganisation MotorSport_Vision', 'Bedford_Aerodrome runwayLength 1095.0']
# dictionary: {0: [['Bedford_Aerodrome', 'icaoLocationIdentifier', 'EGBF'], ['Bedford_Aerodrome', 'operatingOrganisation', 'MotorSport_Vision'], ['Bedford_Aerodrome', 'runwayLength', '1095.0']]}
# index: 1766
# triples: ['Alan_Shepard award Distinguished_Service_Medal_(United_States_Navy)', 'Alan_Shepard birthDate "1923-11-18"', 'Alan_Shepard birthPlace New_Hampshire', 'Alan_Shepard deathPlace California', 'Alan_Shepard servedAsChiefOfTheAstronautOfficeIn 1963']
# dictionary: {0: [['Alan_Shepard', 'award', 'Distinguished_Service_Medal_(United_States_Navy)'], ['Alan_Shepard', 'birthDate', '"1923-11-18"'], ['Alan_Shepard', 'birthPlace', 'New_Hampshire']], 1: [['Alan_Shepard', 'deathPlace', 'California'], ['Alan_Shepard', 'servedAsChiefOfTheAstronautOfficeIn', '1963']]}
# index: 1767
# triples: ['Imagine_(John_Lennon_song) precededBy Power_to_the_People_(song)']
# dictionary: {0: [['Imagine_(John_Lennon_song)', 'precededBy', 'Power_to_the_People_(song)']]}
# index: 1768
# triples: ['Imagine_(John_Lennon_song) followedBy Happy_Xmas_(War_Is_Over)', 'Mermaid_(Train_song) followedBy Imagine_(John_Lennon_song)', 'Mermaid_(Train_song) recordLabel Columbia_Records', 'Mermaid_(Train_song) recordLabel Sony_Music_Entertainment']
# dictionary: {'0': [['Imagine_(John_Lennon_song)', 'followedBy', 'Happy_Xmas_(War_Is_Over)']], '1': [['Mermaid_(Train_song)', 'followedBy', 'Imagine_(John_Lennon_song)'], ['Mermaid_(Train_song)', 'recordLabel', 'Columbia_Records'], ['Mermaid_(Train_song)', 'recordLabel', 'Sony_Music_Entertainment']]}
# index: 1769
# triples: ['Super_Capers runtime 98.0', 'Super_Capers starring Danielle_Harris', 'Super_Capers writer Ray_Griggs_(director)']
# dictionary: {0: [['Super_Capers', 'runtime', '98.0'], ['Super_Capers', 'starring', 'Danielle_Harris'], ['Super_Capers', 'writer', 'Ray_Griggs_(director)']]}
# index: 1770
# triples: ['Nord_(Year_of_No_Light_album) artist Year_of_No_Light', 'Nord_(Year_of_No_Light_album) producer Year_of_No_Light', 'Nord_(Year_of_No_Light_album) recordLabel Crucial_Blast', 'Nord_(Year_of_No_Light_album) releaseDate 2006-09-06']
# dictionary: {0: [['Nord_(Year_of_No_Light_album)', 'artist', 'Year_of_No_Light'], ['Nord_(Year_of_No_Light_album)', 'producer', 'Year_of_No_Light'], ['Nord_(Year_of_No_Light_album)', 'recordLabel', 'Crucial_Blast']], 1: [['Nord_(Year_of_No_Light_album)', 'releaseDate', '2006-09-06']]}
# index: 1771
# triples: ['English_Without_Tears writer Terence_Rattigan']
# dictionary: {0: [['English_Without_Tears', 'writer', 'Terence_Rattigan']]}
# index: 1772
# triples: ['Anatole_de_Grunwald birthPlace Saint_Petersburg']
# dictionary: {0: [['Anatole_de_Grunwald', 'birthPlace', 'Saint_Petersburg']]}
# index: 1773
# triples: ['Liselotte_Grschebina birthPlace Karlsruhe', 'Karlsruhe postalCode 76131–76229', 'Liselotte_Grschebina professionalField Photographer']
# dictionary: {0: [['Liselotte_Grschebina', 'birthPlace', 'Karlsruhe'], ['Karlsruhe', 'postalCode', '76131–76229'], ['Liselotte_Grschebina', 'professionalField', 'Photographer']]}
# index: 1774
# triples: ["It's_Great_to_Be_Young_(1956_film) editing Max_Benedict", "It's_Great_to_Be_Young_(1956_film) starring Cecil_Parker", "It's_Great_to_Be_Young_(1956_film) writer Ted_Willis"]
# dictionary: {0: [["It's_Great_to_Be_Young_(1956_film)", 'editing', 'Max_Benedict'], ["It's_Great_to_Be_Young_(1956_film)", 'starring', 'Cecil_Parker'], ["It's_Great_to_Be_Young_(1956_film)", 'writer', 'Ted_Willis']]}
# index: 1775
# triples: ['Karlsruhe elevationAboveTheSeaLevel 115.0']
# dictionary: {0: [['Karlsruhe', 'elevationAboveTheSeaLevel', '115.0']]}
# index: 1776
# triples: ['Bananaman broadcastedBy BBC', 'BBC foundedBy John_Reith,_1st_Baron_Reith']
# dictionary: {0: [['Bananaman', 'broadcastedBy', 'BBC'], ['BBC', 'foundedBy', 'John_Reith,_1st_Baron_Reith']]}
# index: 1777
# triples: ['Shenzhou_10 cosparId 2013-029A']
# dictionary: {0: [['Shenzhou_10', 'cosparId', '2013-029A']]}
# index: 1778
# triples: ['ALCO_RS-3 buildDate "May 1950 - August 1956"', 'ALCO_RS-3 length 17068.8 (millimetres)', 'ALCO_RS-3 powerType Diesel-electric_transmission']
# dictionary: {0: [['ALCO_RS-3', 'buildDate', '"May', '1950', '-', 'August', '1956"'], ['ALCO_RS-3', 'length', '17068.8', '(millimetres)'], ['ALCO_RS-3', 'powerType', 'Diesel-electric_transmission']]}

# %%
'''def split_dict(dict_to_split):
    new_dict = {}
    for key, value in dict_to_split.items():
        num_chunks = (len(value) + 2) // 3  # Calcoliamo il numero di chunk necessari
        for i in range(num_chunks):
            new_key = f"{key}_{i}" if i > 0 else key  # Creiamo una nuova chiave con indice se necessario
            start = i * 3
            end = min((i + 1) * 3, len(value))
            new_dict[new_key] = value[start:end]  # Aggiungiamo i valori corrispondenti
    return new_dict

dict_to_split = {'0': [['William_Anders', 'mission', 'Apollo_8'], ['Apollo_8', 'crew1Up', 'Frank_Borman'], ['Apollo_8', 'crew2Up', 'Buzz_Aldrin'], ['Apollo_8', 'operator', 'NASA']]}

split_dict_result = split_dict(dict_to_split)

for key, value in split_dict_result.items():
    print(f"{key}: {value}")'''
# Out:
# 'def split_dict(dict_to_split):\n    new_dict = {}\n    for key, value in dict_to_split.items():\n        num_chunks = (len(value) + 2) // 3  # Calcoliamo il numero di chunk necessari\n        for i in range(num_chunks):\n            new_key = f"{key}_{i}" if i > 0 else key  # Creiamo una nuova chiave con indice se necessario\n            start = i * 3\n            end = min((i + 1) * 3, len(value))\n            new_dict[new_key] = value[start:end]  # Aggiungiamo i valori corrispondenti\n    return new_dict\n\ndict_to_split = {\'0\': [[\'William_Anders\', \'mission\', \'Apollo_8\'], [\'Apollo_8\', \'crew1Up\', \'Frank_Borman\'], [\'Apollo_8\', \'crew2Up\', \'Buzz_Aldrin\'], [\'Apollo_8\', \'operator\', \'NASA\']]}\n\nsplit_dict_result = split_dict(dict_to_split)\n\nfor key, value in split_dict_result.items():\n    print(f"{key}: {value}")'
