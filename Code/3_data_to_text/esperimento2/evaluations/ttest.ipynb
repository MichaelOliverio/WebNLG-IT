# %%
import numpy as np
from scipy.stats import ttest_rel
import pickle

# %%
with open('bleu_scores-exp2.pkl', 'rb') as f:
    bleu_scores = pickle.load(f)

with open('meteor_scores-exp2.pkl', 'rb') as f:
    meteor_scores = pickle.load(f)

with open('chrf_scores-exp2.pkl', 'rb') as f:
    chrf_scores = pickle.load(f)

with open('bertscore_scores-exp2.pkl', 'rb') as f:
    bertscore_scores = pickle.load(f)

# %%
def ttest(metric_scores):
    alpha = 0.05  # Soglia per la significatività statistica

    for lang in metric_scores:
        print(f"\n### Language: {lang} ###")

        scores = metric_scores[lang]

        # Calcolare i punteggi medi per ogni modello
        mean_scores = {model: np.mean(scores[model]) for model in scores}
        print("\nPunteggi medi:")
        for model, mean in mean_scores.items():
            print(f" - {model}: {mean:.4f}")

        # Estrarre le liste di punteggi medi per il t-test
        model_names = list(scores.keys())
        model_data = {model: np.mean(np.array(scores[model]), axis=1) for model in model_names}

        # Confronto tra tutti i modelli
        print("\nT-test risultati:")
        for i in range(len(model_names)):
            for j in range(i + 1, len(model_names)):
                model_a, model_b = model_names[i], model_names[j]
                t_stat, p_val = ttest_rel(model_data[model_a], model_data[model_b])

                print(f" - {model_a} vs {model_b}: t = {t_stat:.4f}, p = {p_val:.4f}")

                # Interpretazione del p-value
                if p_val < alpha:
                    print(f"   → Differenza significativa tra {model_a} e {model_b}.")
                else:
                    print(f"   → Nessuna differenza significativa tra {model_a} e {model_b}.")

        print("\n" + "#" * 40)  # Separatore per le lingue

# %%
print('BLEU')
ttest(bleu_scores)
print()

print('METEOR')
ttest(meteor_scores)
print()

print('CHRF')
ttest(chrf_scores)
print()

print('BERTScore')
ttest(bertscore_scores)
# Out:
# BLEU
#
# ### Language: en ###
#
# Punteggi medi:
#  - Llama-3.1-8B-Instruct-en: 0.6402
#  - Mistral-Nemo-Instruct-2407-en: 0.6362
#  - Qwen2.5-7B-Instruct-en: 0.6014
#
# T-test risultati:
#  - Llama-3.1-8B-Instruct-en vs Mistral-Nemo-Instruct-2407-en: t = 4.9523, p = 0.0384
#    → Differenza significativa tra Llama-3.1-8B-Instruct-en e Mistral-Nemo-Instruct-2407-en.
#  - Llama-3.1-8B-Instruct-en vs Qwen2.5-7B-Instruct-en: t = 20.4292, p = 0.0024
#    → Differenza significativa tra Llama-3.1-8B-Instruct-en e Qwen2.5-7B-Instruct-en.
#  - Mistral-Nemo-Instruct-2407-en vs Qwen2.5-7B-Instruct-en: t = 12.9994, p = 0.0059
#    → Differenza significativa tra Mistral-Nemo-Instruct-2407-en e Qwen2.5-7B-Instruct-en.
#
# ########################################
#
# ### Language: it ###
#
# Punteggi medi:
#  - Llama-3.1-8B-Instruct-it: 0.6177
#  - Mistral-Nemo-Instruct-2407-it: 0.6297
#  - Qwen2.5-7B-Instruct-it: 0.5627
#
# T-test risultati:
#  - Llama-3.1-8B-Instruct-it vs Mistral-Nemo-Instruct-2407-it: t = -8.8831, p = 0.0124
#    → Differenza significativa tra Llama-3.1-8B-Instruct-it e Mistral-Nemo-Instruct-2407-it.
#  - Llama-3.1-8B-Instruct-it vs Qwen2.5-7B-Instruct-it: t = 56.7699, p = 0.0003
#    → Differenza significativa tra Llama-3.1-8B-Instruct-it e Qwen2.5-7B-Instruct-it.
#  - Mistral-Nemo-Instruct-2407-it vs Qwen2.5-7B-Instruct-it: t = 71.2748, p = 0.0002
#    → Differenza significativa tra Mistral-Nemo-Instruct-2407-it e Qwen2.5-7B-Instruct-it.
#
# ########################################
#
# ### Language: ge ###
#
# Punteggi medi:
#  - Llama-3.1-8B-Instruct-ge: 0.5407
#  - Mistral-Nemo-Instruct-2407-ge: 0.5510
#  - Qwen2.5-7B-Instruct-ge: 0.5017
#
# T-test risultati:
#  - Llama-3.1-8B-Instruct-ge vs Mistral-Nemo-Instruct-2407-ge: t = -6.9883, p = 0.0199
#    → Differenza significativa tra Llama-3.1-8B-Instruct-ge e Mistral-Nemo-Instruct-2407-ge.
#  - Llama-3.1-8B-Instruct-ge vs Qwen2.5-7B-Instruct-ge: t = 10.7229, p = 0.0086
#    → Differenza significativa tra Llama-3.1-8B-Instruct-ge e Qwen2.5-7B-Instruct-ge.
#  - Mistral-Nemo-Instruct-2407-ge vs Qwen2.5-7B-Instruct-ge: t = 22.5510, p = 0.0020
#    → Differenza significativa tra Mistral-Nemo-Instruct-2407-ge e Qwen2.5-7B-Instruct-ge.
#
# ########################################
#
# ### Language: ru ###
#
# Punteggi medi:
#  - Llama-3.1-8B-Instruct-ru: 0.4560
#  - Mistral-Nemo-Instruct-2407-ru: 0.4781
#  - Qwen2.5-7B-Instruct-ru: 0.4335
#
# T-test risultati:
#  - Llama-3.1-8B-Instruct-ru vs Mistral-Nemo-Instruct-2407-ru: t = -9.6141, p = 0.0106
#    → Differenza significativa tra Llama-3.1-8B-Instruct-ru e Mistral-Nemo-Instruct-2407-ru.
#  - Llama-3.1-8B-Instruct-ru vs Qwen2.5-7B-Instruct-ru: t = 4.5760, p = 0.0446
#    → Differenza significativa tra Llama-3.1-8B-Instruct-ru e Qwen2.5-7B-Instruct-ru.
#  - Mistral-Nemo-Instruct-2407-ru vs Qwen2.5-7B-Instruct-ru: t = 15.1565, p = 0.0043
#    → Differenza significativa tra Mistral-Nemo-Instruct-2407-ru e Qwen2.5-7B-Instruct-ru.
#
# ########################################
#
# METEOR
#
# ### Language: en ###
#
# Punteggi medi:
#  - Llama-3.1-8B-Instruct-en: 0.8317
#  - Mistral-Nemo-Instruct-2407-en: 0.8342
#  - Qwen2.5-7B-Instruct-en: 0.8196
#
# T-test risultati:
#  - Llama-3.1-8B-Instruct-en vs Mistral-Nemo-Instruct-2407-en: t = -7.6303, p = 0.0167
#    → Differenza significativa tra Llama-3.1-8B-Instruct-en e Mistral-Nemo-Instruct-2407-en.
#  - Llama-3.1-8B-Instruct-en vs Qwen2.5-7B-Instruct-en: t = 19.6582, p = 0.0026
#    → Differenza significativa tra Llama-3.1-8B-Instruct-en e Qwen2.5-7B-Instruct-en.
#  - Mistral-Nemo-Instruct-2407-en vs Qwen2.5-7B-Instruct-en: t = 45.4744, p = 0.0005
#    → Differenza significativa tra Mistral-Nemo-Instruct-2407-en e Qwen2.5-7B-Instruct-en.
#
# ########################################
#
# ### Language: it ###
#
# Punteggi medi:
#  - Llama-3.1-8B-Instruct-it: 0.8002
#  - Mistral-Nemo-Instruct-2407-it: 0.8029
#  - Qwen2.5-7B-Instruct-it: 0.7746
#
# T-test risultati:
#  - Llama-3.1-8B-Instruct-it vs Mistral-Nemo-Instruct-2407-it: t = -5.7434, p = 0.0290
#    → Differenza significativa tra Llama-3.1-8B-Instruct-it e Mistral-Nemo-Instruct-2407-it.
#  - Llama-3.1-8B-Instruct-it vs Qwen2.5-7B-Instruct-it: t = 71.7898, p = 0.0002
#    → Differenza significativa tra Llama-3.1-8B-Instruct-it e Qwen2.5-7B-Instruct-it.
#  - Mistral-Nemo-Instruct-2407-it vs Qwen2.5-7B-Instruct-it: t = 184.5733, p = 0.0000
#    → Differenza significativa tra Mistral-Nemo-Instruct-2407-it e Qwen2.5-7B-Instruct-it.
#
# ########################################
#
# ### Language: ge ###
#
# Punteggi medi:
#  - Llama-3.1-8B-Instruct-ge: 0.7579
#  - Mistral-Nemo-Instruct-2407-ge: 0.7582
#  - Qwen2.5-7B-Instruct-ge: 0.7450
#
# T-test risultati:
#  - Llama-3.1-8B-Instruct-ge vs Mistral-Nemo-Instruct-2407-ge: t = -0.6129, p = 0.6023
#    → Nessuna differenza significativa tra Llama-3.1-8B-Instruct-ge e Mistral-Nemo-Instruct-2407-ge.
#  - Llama-3.1-8B-Instruct-ge vs Qwen2.5-7B-Instruct-ge: t = 16.2432, p = 0.0038
#    → Differenza significativa tra Llama-3.1-8B-Instruct-ge e Qwen2.5-7B-Instruct-ge.
#  - Mistral-Nemo-Instruct-2407-ge vs Qwen2.5-7B-Instruct-ge: t = 63.0533, p = 0.0003
#    → Differenza significativa tra Mistral-Nemo-Instruct-2407-ge e Qwen2.5-7B-Instruct-ge.
#
# ########################################
#
# ### Language: ru ###
#
# Punteggi medi:
#  - Llama-3.1-8B-Instruct-ru: 0.7064
#  - Mistral-Nemo-Instruct-2407-ru: 0.7257
#  - Qwen2.5-7B-Instruct-ru: 0.6919
#
# T-test risultati:
#  - Llama-3.1-8B-Instruct-ru vs Mistral-Nemo-Instruct-2407-ru: t = -14.6284, p = 0.0046
#    → Differenza significativa tra Llama-3.1-8B-Instruct-ru e Mistral-Nemo-Instruct-2407-ru.
#  - Llama-3.1-8B-Instruct-ru vs Qwen2.5-7B-Instruct-ru: t = 23.9407, p = 0.0017
#    → Differenza significativa tra Llama-3.1-8B-Instruct-ru e Qwen2.5-7B-Instruct-ru.
#  - Mistral-Nemo-Instruct-2407-ru vs Qwen2.5-7B-Instruct-ru: t = 27.2493, p = 0.0013
#    → Differenza significativa tra Mistral-Nemo-Instruct-2407-ru e Qwen2.5-7B-Instruct-ru.
#
# ########################################
#
# CHRF
#
# ### Language: en ###
#
# Punteggi medi:
#  - Llama-3.1-8B-Instruct-en: 70.8162
#  - Mistral-Nemo-Instruct-2407-en: 71.1122
#  - Qwen2.5-7B-Instruct-en: 69.6613
#
# T-test risultati:
#  - Llama-3.1-8B-Instruct-en vs Mistral-Nemo-Instruct-2407-en: t = -7.4618, p = 0.0175
#    → Differenza significativa tra Llama-3.1-8B-Instruct-en e Mistral-Nemo-Instruct-2407-en.
#  - Llama-3.1-8B-Instruct-en vs Qwen2.5-7B-Instruct-en: t = 16.2932, p = 0.0037
#    → Differenza significativa tra Llama-3.1-8B-Instruct-en e Qwen2.5-7B-Instruct-en.
#  - Mistral-Nemo-Instruct-2407-en vs Qwen2.5-7B-Instruct-en: t = 45.3500, p = 0.0005
#    → Differenza significativa tra Mistral-Nemo-Instruct-2407-en e Qwen2.5-7B-Instruct-en.
#
# ########################################
#
# ### Language: it ###
#
# Punteggi medi:
#  - Llama-3.1-8B-Instruct-it: 69.7375
#  - Mistral-Nemo-Instruct-2407-it: 70.3626
#  - Qwen2.5-7B-Instruct-it: 68.1303
#
# T-test risultati:
#  - Llama-3.1-8B-Instruct-it vs Mistral-Nemo-Instruct-2407-it: t = -13.6773, p = 0.0053
#    → Differenza significativa tra Llama-3.1-8B-Instruct-it e Mistral-Nemo-Instruct-2407-it.
#  - Llama-3.1-8B-Instruct-it vs Qwen2.5-7B-Instruct-it: t = 18.3399, p = 0.0030
#    → Differenza significativa tra Llama-3.1-8B-Instruct-it e Qwen2.5-7B-Instruct-it.
#  - Mistral-Nemo-Instruct-2407-it vs Qwen2.5-7B-Instruct-it: t = 48.2621, p = 0.0004
#    → Differenza significativa tra Mistral-Nemo-Instruct-2407-it e Qwen2.5-7B-Instruct-it.
#
# ########################################
#
# ### Language: ge ###
#
# Punteggi medi:
#  - Llama-3.1-8B-Instruct-ge: 64.1106
#  - Mistral-Nemo-Instruct-2407-ge: 64.2181
#  - Qwen2.5-7B-Instruct-ge: 62.4520
#
# T-test risultati:
#  - Llama-3.1-8B-Instruct-ge vs Mistral-Nemo-Instruct-2407-ge: t = -2.3188, p = 0.1463
#    → Nessuna differenza significativa tra Llama-3.1-8B-Instruct-ge e Mistral-Nemo-Instruct-2407-ge.
#  - Llama-3.1-8B-Instruct-ge vs Qwen2.5-7B-Instruct-ge: t = 16.4945, p = 0.0037
#    → Differenza significativa tra Llama-3.1-8B-Instruct-ge e Qwen2.5-7B-Instruct-ge.
#  - Mistral-Nemo-Instruct-2407-ge vs Qwen2.5-7B-Instruct-ge: t = 32.0244, p = 0.0010
#    → Differenza significativa tra Mistral-Nemo-Instruct-2407-ge e Qwen2.5-7B-Instruct-ge.
#
# ########################################
#
# ### Language: ru ###
#
# Punteggi medi:
#  - Llama-3.1-8B-Instruct-ru: 60.8830
#  - Mistral-Nemo-Instruct-2407-ru: 62.1085
#  - Qwen2.5-7B-Instruct-ru: 59.4568
#
# T-test risultati:
#  - Llama-3.1-8B-Instruct-ru vs Mistral-Nemo-Instruct-2407-ru: t = -17.0001, p = 0.0034
#    → Differenza significativa tra Llama-3.1-8B-Instruct-ru e Mistral-Nemo-Instruct-2407-ru.
#  - Llama-3.1-8B-Instruct-ru vs Qwen2.5-7B-Instruct-ru: t = 17.5316, p = 0.0032
#    → Differenza significativa tra Llama-3.1-8B-Instruct-ru e Qwen2.5-7B-Instruct-ru.
#  - Mistral-Nemo-Instruct-2407-ru vs Qwen2.5-7B-Instruct-ru: t = 37.4812, p = 0.0007
#    → Differenza significativa tra Mistral-Nemo-Instruct-2407-ru e Qwen2.5-7B-Instruct-ru.
#
# ########################################
#
# BERTScore
#
# ### Language: en ###
#
# Punteggi medi:
#  - Llama-3.1-8B-Instruct-en: 0.9708
#  - Mistral-Nemo-Instruct-2407-en: 0.9707
#  - Qwen2.5-7B-Instruct-en: 0.9668
#
# T-test risultati:
#  - Llama-3.1-8B-Instruct-en vs Mistral-Nemo-Instruct-2407-en: t = 2.2183, p = 0.1568
#    → Nessuna differenza significativa tra Llama-3.1-8B-Instruct-en e Mistral-Nemo-Instruct-2407-en.
#  - Llama-3.1-8B-Instruct-en vs Qwen2.5-7B-Instruct-en: t = 53.4796, p = 0.0003
#    → Differenza significativa tra Llama-3.1-8B-Instruct-en e Qwen2.5-7B-Instruct-en.
#  - Mistral-Nemo-Instruct-2407-en vs Qwen2.5-7B-Instruct-en: t = 59.7764, p = 0.0003
#    → Differenza significativa tra Mistral-Nemo-Instruct-2407-en e Qwen2.5-7B-Instruct-en.
#
# ########################################
#
# ### Language: it ###
#
# Punteggi medi:
#  - Llama-3.1-8B-Instruct-it: 0.9322
#  - Mistral-Nemo-Instruct-2407-it: 0.9345
#  - Qwen2.5-7B-Instruct-it: 0.9250
#
# T-test risultati:
#  - Llama-3.1-8B-Instruct-it vs Mistral-Nemo-Instruct-2407-it: t = -13.7267, p = 0.0053
#    → Differenza significativa tra Llama-3.1-8B-Instruct-it e Mistral-Nemo-Instruct-2407-it.
#  - Llama-3.1-8B-Instruct-it vs Qwen2.5-7B-Instruct-it: t = 88.6055, p = 0.0001
#    → Differenza significativa tra Llama-3.1-8B-Instruct-it e Qwen2.5-7B-Instruct-it.
#  - Mistral-Nemo-Instruct-2407-it vs Qwen2.5-7B-Instruct-it: t = 104.2197, p = 0.0001
#    → Differenza significativa tra Mistral-Nemo-Instruct-2407-it e Qwen2.5-7B-Instruct-it.
#
# ########################################
#
# ### Language: ge ###
#
# Punteggi medi:
#  - Llama-3.1-8B-Instruct-ge: 0.9155
#  - Mistral-Nemo-Instruct-2407-ge: 0.9145
#  - Qwen2.5-7B-Instruct-ge: 0.9082
#
# T-test risultati:
#  - Llama-3.1-8B-Instruct-ge vs Mistral-Nemo-Instruct-2407-ge: t = 2.8390, p = 0.1049
#    → Nessuna differenza significativa tra Llama-3.1-8B-Instruct-ge e Mistral-Nemo-Instruct-2407-ge.
#  - Llama-3.1-8B-Instruct-ge vs Qwen2.5-7B-Instruct-ge: t = 23.0770, p = 0.0019
#    → Differenza significativa tra Llama-3.1-8B-Instruct-ge e Qwen2.5-7B-Instruct-ge.
#  - Mistral-Nemo-Instruct-2407-ge vs Qwen2.5-7B-Instruct-ge: t = 75.8926, p = 0.0002
#    → Differenza significativa tra Mistral-Nemo-Instruct-2407-ge e Qwen2.5-7B-Instruct-ge.
#
# ########################################
#
# ### Language: ru ###
#
# Punteggi medi:
#  - Llama-3.1-8B-Instruct-ru: 0.9138
#  - Mistral-Nemo-Instruct-2407-ru: 0.9176
#  - Qwen2.5-7B-Instruct-ru: 0.9043
#
# T-test risultati:
#  - Llama-3.1-8B-Instruct-ru vs Mistral-Nemo-Instruct-2407-ru: t = -9.3928, p = 0.0111
#    → Differenza significativa tra Llama-3.1-8B-Instruct-ru e Mistral-Nemo-Instruct-2407-ru.
#  - Llama-3.1-8B-Instruct-ru vs Qwen2.5-7B-Instruct-ru: t = 100.2043, p = 0.0001
#    → Differenza significativa tra Llama-3.1-8B-Instruct-ru e Qwen2.5-7B-Instruct-ru.
#  - Mistral-Nemo-Instruct-2407-ru vs Qwen2.5-7B-Instruct-ru: t = 42.5575, p = 0.0006
#    → Differenza significativa tra Mistral-Nemo-Instruct-2407-ru e Qwen2.5-7B-Instruct-ru.
#
# ########################################
