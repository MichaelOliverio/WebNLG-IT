# %%
import numpy as np
import pickle
from scipy.stats import wilcoxon
from itertools import combinations

# %%
with open('bleu_scores-exp2.pkl', 'rb') as f:
    bleu_scores = pickle.load(f)

with open('meteor_scores-exp2.pkl', 'rb') as f:
    meteor_scores = pickle.load(f)

with open('chrf_scores-exp2.pkl', 'rb') as f:
    chrf_scores = pickle.load(f)

with open('bertscore_scores-exp2.pkl', 'rb') as f:
    bertscore_scores = pickle.load(f)

# %%
def averageScores(scores):
    for lang in scores:
        for model in scores[lang]:
            averages = []
            for i in range(len(scores[lang][model][0])):
                average = (scores[lang][model][0][i] + scores[lang][model][1][i] + scores[lang][model][2][i]) / 3
                averages.append(average)
            scores[lang][model] = averages
    return scores

bleu_scores = averageScores(bleu_scores)
meteor_scores = averageScores(meteor_scores)
chrf_scores = averageScores(chrf_scores)
bertscore_scores = averageScores(bertscore_scores)

# %%
def statistical_tests(metric_scores):
    alpha = 0.05  # Soglia di significatività
    print("\n===== STATISTICAL TESTS =====")

    for lang in metric_scores:
        print(f"\n### Language: {lang} ###")
        scores = metric_scores[lang]
        model_names = list(scores.keys())
        model_data = {model: np.array(scores[model]) for model in model_names}

        # calcola la media
        for model in model_names:
            print(f" - {model}: {model_data[model].mean():.4f}")


        # Test post-hoc Wilcoxon
        for model_a, model_b in combinations(model_names, 2):
            stat, p_val = wilcoxon(model_data[model_a], model_data[model_b])
            print(f" - {model_a} vs {model_b}: Wilcoxon statistic={stat:.4f}, p-value={p_val:.4f}")

            if p_val < alpha:
                print(f"   → Differenza significativa tra {model_a} e {model_b}.")
            else:
                print(f"   → Nessuna differenza significativa tra {model_a} e {model_b}.\n")
       
        print("\n" + "#" * 40)  # Separatore per le lingue

# %%
print('BLEU')
statistical_tests(bleu_scores)
print()

print('METEOR')
statistical_tests(meteor_scores)
print()

print('CHRF')
statistical_tests(chrf_scores)
print()

print('BERTScore')
statistical_tests(bertscore_scores)
# Out:
# BLEU
#
# ===== STATISTICAL TESTS =====
#
# ### Language: en ###
#  - Llama-3.1-8B-Instruct-en: 0.6402
#  - Mistral-Nemo-Instruct-2407-en: 0.6362
#  - Qwen2.5-7B-Instruct-en: 0.6014
#  - Llama-3.1-8B-Instruct-en vs Mistral-Nemo-Instruct-2407-en: Wilcoxon statistic=14438.0000, p-value=0.8954
#    → Nessuna differenza significativa tra Llama-3.1-8B-Instruct-en e Mistral-Nemo-Instruct-2407-en.
#
#  - Llama-3.1-8B-Instruct-en vs Qwen2.5-7B-Instruct-en: Wilcoxon statistic=15355.0000, p-value=0.0001
#    → Differenza significativa tra Llama-3.1-8B-Instruct-en e Qwen2.5-7B-Instruct-en.
#  - Mistral-Nemo-Instruct-2407-en vs Qwen2.5-7B-Instruct-en: Wilcoxon statistic=16187.5000, p-value=0.0003
#    → Differenza significativa tra Mistral-Nemo-Instruct-2407-en e Qwen2.5-7B-Instruct-en.
#
# ########################################
#
# ### Language: it ###
#  - Llama-3.1-8B-Instruct-it: 0.6177
#  - Mistral-Nemo-Instruct-2407-it: 0.6297
#  - Qwen2.5-7B-Instruct-it: 0.5627
#  - Llama-3.1-8B-Instruct-it vs Mistral-Nemo-Instruct-2407-it: Wilcoxon statistic=16293.0000, p-value=0.8121
#    → Nessuna differenza significativa tra Llama-3.1-8B-Instruct-it e Mistral-Nemo-Instruct-2407-it.
#
#  - Llama-3.1-8B-Instruct-it vs Qwen2.5-7B-Instruct-it: Wilcoxon statistic=15143.0000, p-value=0.0000
#    → Differenza significativa tra Llama-3.1-8B-Instruct-it e Qwen2.5-7B-Instruct-it.
#  - Mistral-Nemo-Instruct-2407-it vs Qwen2.5-7B-Instruct-it: Wilcoxon statistic=13131.0000, p-value=0.0000
#    → Differenza significativa tra Mistral-Nemo-Instruct-2407-it e Qwen2.5-7B-Instruct-it.
#
# ########################################
#
# ### Language: ge ###
#  - Llama-3.1-8B-Instruct-ge: 0.5407
#  - Mistral-Nemo-Instruct-2407-ge: 0.5510
#  - Qwen2.5-7B-Instruct-ge: 0.5017
#  - Llama-3.1-8B-Instruct-ge vs Mistral-Nemo-Instruct-2407-ge: Wilcoxon statistic=15423.0000, p-value=0.0960
#    → Nessuna differenza significativa tra Llama-3.1-8B-Instruct-ge e Mistral-Nemo-Instruct-2407-ge.
#
#  - Llama-3.1-8B-Instruct-ge vs Qwen2.5-7B-Instruct-ge: Wilcoxon statistic=17462.0000, p-value=0.0050
#    → Differenza significativa tra Llama-3.1-8B-Instruct-ge e Qwen2.5-7B-Instruct-ge.
#  - Mistral-Nemo-Instruct-2407-ge vs Qwen2.5-7B-Instruct-ge: Wilcoxon statistic=13148.0000, p-value=0.0000
#    → Differenza significativa tra Mistral-Nemo-Instruct-2407-ge e Qwen2.5-7B-Instruct-ge.
#
# ########################################
#
# ### Language: ru ###
#  - Llama-3.1-8B-Instruct-ru: 0.4560
#  - Mistral-Nemo-Instruct-2407-ru: 0.4781
#  - Qwen2.5-7B-Instruct-ru: 0.4335
#  - Llama-3.1-8B-Instruct-ru vs Mistral-Nemo-Instruct-2407-ru: Wilcoxon statistic=16474.0000, p-value=0.0718
#    → Nessuna differenza significativa tra Llama-3.1-8B-Instruct-ru e Mistral-Nemo-Instruct-2407-ru.
#
#  - Llama-3.1-8B-Instruct-ru vs Qwen2.5-7B-Instruct-ru: Wilcoxon statistic=16199.5000, p-value=0.0081
#    → Differenza significativa tra Llama-3.1-8B-Instruct-ru e Qwen2.5-7B-Instruct-ru.
#  - Mistral-Nemo-Instruct-2407-ru vs Qwen2.5-7B-Instruct-ru: Wilcoxon statistic=13744.0000, p-value=0.0001
#    → Differenza significativa tra Mistral-Nemo-Instruct-2407-ru e Qwen2.5-7B-Instruct-ru.
#
# ########################################
#
# METEOR
#
# ===== STATISTICAL TESTS =====
#
# ### Language: en ###
#  - Llama-3.1-8B-Instruct-en: 0.8317
#  - Mistral-Nemo-Instruct-2407-en: 0.8342
#  - Qwen2.5-7B-Instruct-en: 0.8196
#  - Llama-3.1-8B-Instruct-en vs Mistral-Nemo-Instruct-2407-en: Wilcoxon statistic=15827.0000, p-value=0.6005
#    → Nessuna differenza significativa tra Llama-3.1-8B-Instruct-en e Mistral-Nemo-Instruct-2407-en.
#
#  - Llama-3.1-8B-Instruct-en vs Qwen2.5-7B-Instruct-en: Wilcoxon statistic=19021.0000, p-value=0.0087
#    → Differenza significativa tra Llama-3.1-8B-Instruct-en e Qwen2.5-7B-Instruct-en.
#  - Mistral-Nemo-Instruct-2407-en vs Qwen2.5-7B-Instruct-en: Wilcoxon statistic=17596.0000, p-value=0.0004
#    → Differenza significativa tra Mistral-Nemo-Instruct-2407-en e Qwen2.5-7B-Instruct-en.
#
# ########################################
#
# ### Language: it ###
#  - Llama-3.1-8B-Instruct-it: 0.8002
#  - Mistral-Nemo-Instruct-2407-it: 0.8029
#  - Qwen2.5-7B-Instruct-it: 0.7746
#  - Llama-3.1-8B-Instruct-it vs Mistral-Nemo-Instruct-2407-it: Wilcoxon statistic=17492.0000, p-value=0.6023
#    → Nessuna differenza significativa tra Llama-3.1-8B-Instruct-it e Mistral-Nemo-Instruct-2407-it.
#
#  - Llama-3.1-8B-Instruct-it vs Qwen2.5-7B-Instruct-it: Wilcoxon statistic=18632.0000, p-value=0.0004
#    → Differenza significativa tra Llama-3.1-8B-Instruct-it e Qwen2.5-7B-Instruct-it.
#  - Mistral-Nemo-Instruct-2407-it vs Qwen2.5-7B-Instruct-it: Wilcoxon statistic=16897.5000, p-value=0.0000
#    → Differenza significativa tra Mistral-Nemo-Instruct-2407-it e Qwen2.5-7B-Instruct-it.
#
# ########################################
#
# ### Language: ge ###
#  - Llama-3.1-8B-Instruct-ge: 0.7579
#  - Mistral-Nemo-Instruct-2407-ge: 0.7582
#  - Qwen2.5-7B-Instruct-ge: 0.7450
#  - Llama-3.1-8B-Instruct-ge vs Mistral-Nemo-Instruct-2407-ge: Wilcoxon statistic=20358.0000, p-value=0.5379
#    → Nessuna differenza significativa tra Llama-3.1-8B-Instruct-ge e Mistral-Nemo-Instruct-2407-ge.
#
#  - Llama-3.1-8B-Instruct-ge vs Qwen2.5-7B-Instruct-ge: Wilcoxon statistic=23383.0000, p-value=0.1949
#    → Nessuna differenza significativa tra Llama-3.1-8B-Instruct-ge e Qwen2.5-7B-Instruct-ge.
#
#  - Mistral-Nemo-Instruct-2407-ge vs Qwen2.5-7B-Instruct-ge: Wilcoxon statistic=20991.0000, p-value=0.0600
#    → Nessuna differenza significativa tra Mistral-Nemo-Instruct-2407-ge e Qwen2.5-7B-Instruct-ge.
#
#
# ########################################
#
# ### Language: ru ###
#  - Llama-3.1-8B-Instruct-ru: 0.7064
#  - Mistral-Nemo-Instruct-2407-ru: 0.7257
#  - Qwen2.5-7B-Instruct-ru: 0.6919
#  - Llama-3.1-8B-Instruct-ru vs Mistral-Nemo-Instruct-2407-ru: Wilcoxon statistic=22417.0000, p-value=0.0882
#    → Nessuna differenza significativa tra Llama-3.1-8B-Instruct-ru e Mistral-Nemo-Instruct-2407-ru.
#
#  - Llama-3.1-8B-Instruct-ru vs Qwen2.5-7B-Instruct-ru: Wilcoxon statistic=22118.0000, p-value=0.0100
#    → Differenza significativa tra Llama-3.1-8B-Instruct-ru e Qwen2.5-7B-Instruct-ru.
#  - Mistral-Nemo-Instruct-2407-ru vs Qwen2.5-7B-Instruct-ru: Wilcoxon statistic=18575.0000, p-value=0.0000
#    → Differenza significativa tra Mistral-Nemo-Instruct-2407-ru e Qwen2.5-7B-Instruct-ru.
#
# ########################################
#
# CHRF
#
# ===== STATISTICAL TESTS =====
#
# ### Language: en ###
#  - Llama-3.1-8B-Instruct-en: 70.8162
#  - Mistral-Nemo-Instruct-2407-en: 71.1122
#  - Qwen2.5-7B-Instruct-en: 69.6613
#  - Llama-3.1-8B-Instruct-en vs Mistral-Nemo-Instruct-2407-en: Wilcoxon statistic=15531.0000, p-value=0.1673
#    → Nessuna differenza significativa tra Llama-3.1-8B-Instruct-en e Mistral-Nemo-Instruct-2407-en.
#
#  - Llama-3.1-8B-Instruct-en vs Qwen2.5-7B-Instruct-en: Wilcoxon statistic=19037.0000, p-value=0.0018
#    → Differenza significativa tra Llama-3.1-8B-Instruct-en e Qwen2.5-7B-Instruct-en.
#  - Mistral-Nemo-Instruct-2407-en vs Qwen2.5-7B-Instruct-en: Wilcoxon statistic=17314.0000, p-value=0.0000
#    → Differenza significativa tra Mistral-Nemo-Instruct-2407-en e Qwen2.5-7B-Instruct-en.
#
# ########################################
#
# ### Language: it ###
#  - Llama-3.1-8B-Instruct-it: 69.7375
#  - Mistral-Nemo-Instruct-2407-it: 70.3626
#  - Qwen2.5-7B-Instruct-it: 68.1303
#  - Llama-3.1-8B-Instruct-it vs Mistral-Nemo-Instruct-2407-it: Wilcoxon statistic=20051.0000, p-value=0.6631
#    → Nessuna differenza significativa tra Llama-3.1-8B-Instruct-it e Mistral-Nemo-Instruct-2407-it.
#
#  - Llama-3.1-8B-Instruct-it vs Qwen2.5-7B-Instruct-it: Wilcoxon statistic=19539.0000, p-value=0.0001
#    → Differenza significativa tra Llama-3.1-8B-Instruct-it e Qwen2.5-7B-Instruct-it.
#  - Mistral-Nemo-Instruct-2407-it vs Qwen2.5-7B-Instruct-it: Wilcoxon statistic=16341.0000, p-value=0.0000
#    → Differenza significativa tra Mistral-Nemo-Instruct-2407-it e Qwen2.5-7B-Instruct-it.
#
# ########################################
#
# ### Language: ge ###
#  - Llama-3.1-8B-Instruct-ge: 64.1106
#  - Mistral-Nemo-Instruct-2407-ge: 64.2181
#  - Qwen2.5-7B-Instruct-ge: 62.4520
#  - Llama-3.1-8B-Instruct-ge vs Mistral-Nemo-Instruct-2407-ge: Wilcoxon statistic=21173.0000, p-value=0.4027
#    → Nessuna differenza significativa tra Llama-3.1-8B-Instruct-ge e Mistral-Nemo-Instruct-2407-ge.
#
#  - Llama-3.1-8B-Instruct-ge vs Qwen2.5-7B-Instruct-ge: Wilcoxon statistic=21130.0000, p-value=0.0007
#    → Differenza significativa tra Llama-3.1-8B-Instruct-ge e Qwen2.5-7B-Instruct-ge.
#  - Mistral-Nemo-Instruct-2407-ge vs Qwen2.5-7B-Instruct-ge: Wilcoxon statistic=17858.0000, p-value=0.0000
#    → Differenza significativa tra Mistral-Nemo-Instruct-2407-ge e Qwen2.5-7B-Instruct-ge.
#
# ########################################
#
# ### Language: ru ###
#  - Llama-3.1-8B-Instruct-ru: 60.8830
#  - Mistral-Nemo-Instruct-2407-ru: 62.1085
#  - Qwen2.5-7B-Instruct-ru: 59.4568
#  - Llama-3.1-8B-Instruct-ru vs Mistral-Nemo-Instruct-2407-ru: Wilcoxon statistic=22796.0000, p-value=0.0150
#    → Differenza significativa tra Llama-3.1-8B-Instruct-ru e Mistral-Nemo-Instruct-2407-ru.
#  - Llama-3.1-8B-Instruct-ru vs Qwen2.5-7B-Instruct-ru: Wilcoxon statistic=21167.0000, p-value=0.0001
#    → Differenza significativa tra Llama-3.1-8B-Instruct-ru e Qwen2.5-7B-Instruct-ru.
#  - Mistral-Nemo-Instruct-2407-ru vs Qwen2.5-7B-Instruct-ru: Wilcoxon statistic=17444.0000, p-value=0.0000
#    → Differenza significativa tra Mistral-Nemo-Instruct-2407-ru e Qwen2.5-7B-Instruct-ru.
#
# ########################################
#
# BERTScore
#
# ===== STATISTICAL TESTS =====
#
# ### Language: en ###
#  - Llama-3.1-8B-Instruct-en: 0.9708
#  - Mistral-Nemo-Instruct-2407-en: 0.9707
#  - Qwen2.5-7B-Instruct-en: 0.9668
#  - Llama-3.1-8B-Instruct-en vs Mistral-Nemo-Instruct-2407-en: Wilcoxon statistic=18485.0000, p-value=0.8689
#    → Nessuna differenza significativa tra Llama-3.1-8B-Instruct-en e Mistral-Nemo-Instruct-2407-en.
#
#  - Llama-3.1-8B-Instruct-en vs Qwen2.5-7B-Instruct-en: Wilcoxon statistic=15730.5000, p-value=0.0000
#    → Differenza significativa tra Llama-3.1-8B-Instruct-en e Qwen2.5-7B-Instruct-en.
#  - Mistral-Nemo-Instruct-2407-en vs Qwen2.5-7B-Instruct-en: Wilcoxon statistic=16968.5000, p-value=0.0000
#    → Differenza significativa tra Mistral-Nemo-Instruct-2407-en e Qwen2.5-7B-Instruct-en.
#
# ########################################
#
# ### Language: it ###
#  - Llama-3.1-8B-Instruct-it: 0.9322
#  - Mistral-Nemo-Instruct-2407-it: 0.9345
#  - Qwen2.5-7B-Instruct-it: 0.9250
#  - Llama-3.1-8B-Instruct-it vs Mistral-Nemo-Instruct-2407-it: Wilcoxon statistic=18556.0000, p-value=0.0754
#    → Nessuna differenza significativa tra Llama-3.1-8B-Instruct-it e Mistral-Nemo-Instruct-2407-it.
#
#  - Llama-3.1-8B-Instruct-it vs Qwen2.5-7B-Instruct-it: Wilcoxon statistic=21057.5000, p-value=0.0014
#    → Differenza significativa tra Llama-3.1-8B-Instruct-it e Qwen2.5-7B-Instruct-it.
#  - Mistral-Nemo-Instruct-2407-it vs Qwen2.5-7B-Instruct-it: Wilcoxon statistic=17767.0000, p-value=0.0000
#    → Differenza significativa tra Mistral-Nemo-Instruct-2407-it e Qwen2.5-7B-Instruct-it.
#
# ########################################
#
# ### Language: ge ###
#  - Llama-3.1-8B-Instruct-ge: 0.9155
#  - Mistral-Nemo-Instruct-2407-ge: 0.9145
#  - Qwen2.5-7B-Instruct-ge: 0.9082
#  - Llama-3.1-8B-Instruct-ge vs Mistral-Nemo-Instruct-2407-ge: Wilcoxon statistic=23288.0000, p-value=0.8985
#    → Nessuna differenza significativa tra Llama-3.1-8B-Instruct-ge e Mistral-Nemo-Instruct-2407-ge.
#
#  - Llama-3.1-8B-Instruct-ge vs Qwen2.5-7B-Instruct-ge: Wilcoxon statistic=21862.0000, p-value=0.0017
#    → Differenza significativa tra Llama-3.1-8B-Instruct-ge e Qwen2.5-7B-Instruct-ge.
#  - Mistral-Nemo-Instruct-2407-ge vs Qwen2.5-7B-Instruct-ge: Wilcoxon statistic=19989.5000, p-value=0.0019
#    → Differenza significativa tra Mistral-Nemo-Instruct-2407-ge e Qwen2.5-7B-Instruct-ge.
#
# ########################################
#
# ### Language: ru ###
#  - Llama-3.1-8B-Instruct-ru: 0.9138
#  - Mistral-Nemo-Instruct-2407-ru: 0.9176
#  - Qwen2.5-7B-Instruct-ru: 0.9043
#  - Llama-3.1-8B-Instruct-ru vs Mistral-Nemo-Instruct-2407-ru: Wilcoxon statistic=23999.0000, p-value=0.0831
#    → Nessuna differenza significativa tra Llama-3.1-8B-Instruct-ru e Mistral-Nemo-Instruct-2407-ru.
#
#  - Llama-3.1-8B-Instruct-ru vs Qwen2.5-7B-Instruct-ru: Wilcoxon statistic=19711.0000, p-value=0.0000
#    → Differenza significativa tra Llama-3.1-8B-Instruct-ru e Qwen2.5-7B-Instruct-ru.
#  - Mistral-Nemo-Instruct-2407-ru vs Qwen2.5-7B-Instruct-ru: Wilcoxon statistic=16564.0000, p-value=0.0000
#    → Differenza significativa tra Mistral-Nemo-Instruct-2407-ru e Qwen2.5-7B-Instruct-ru.
#
# ########################################
